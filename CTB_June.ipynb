# %% [markdown]
# ## CTB June

# %%
## importing required libraries

# %%
import pandas as pd
import openpyxl
import xlrd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from matplotlib import rcParams
import re
import calendar
import os
from natsort import natsorted

import warnings
warnings.filterwarnings('ignore')

# %%
# time range of analysis 
Startdate = "2020-01-01"
Enddate = "2021-07-01"
#Enddate = "2020-12-31

# %%
#getting granular level insights from date
def add_datepart(df, fldname, drop=True):
    
    fld = df[fldname]
    fld_dtype = fld.dtype
    if isinstance(fld_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        fld_dtype = np.datetime64

    if not np.issubdtype(fld_dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
        
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    
    attr = ['Year', 'Month', 'Week', 'Day','hour', 'Dayofweek', 'Dayofyear','weekofyear']
    
    for n in attr: 
        df[targ_pre + n] = getattr(fld.dt, n.lower())
    
    df[targ_pre + "MonthName"] = df[targ_pre + "Month"].astype(int).apply(lambda x: calendar.month_abbr[x])
    df[targ_pre + "MonthKey"] =  df[targ_pre + "Year"].astype(str)+"_"+df[targ_pre + "Month"].astype(str)
    df[targ_pre + "WeekKey"] =  df[targ_pre + "Year"].astype(str)+"_"+df[targ_pre + "Week"].astype(str)
        
    #if drop: 
        #df.drop(fldname, axis=1, inplace=True)

# %%
def select_date_range(dataset, datevariable, startdate, enddate):
    print("old shape:", dataset.shape)
    dataset = dataset[(dataset[datevariable]>Startdate) & (dataset[datevariable]<Enddate)]
    print("new shape:", dataset.shape)
    return dataset

# %%
def Trend_Analysis_gb(dataset, Variables, DateVariable, GroupbyVariable, TrendType):

    Trend = dataset[Variables].groupby(GroupbyVariable,as_index=False).count()
       
    if TrendType =="Monthly":
        #Trend['Month_name']= Trend[DateVariable].astype(int).apply(lambda x: calendar.month_abbr[x])
        pass
        
    if TrendType =="Weekly":    
        pass
    
    if TrendType =="Hourly":
        Hourly_Labels = ['22-24','0-2','0-2','2-4','2-4','4-6','4-6','6-8','6-8','8-10','8-10','10-12','10-12','12-14','12-14','14-16','14-16','16-18','16-18','18-20','18-20','20-22','20-22','22-24']
        interval_range = pd.interval_range(start=0, freq=2, end=24)
        Trend['Range'] = pd.cut(Trend[DateVariable], bins=interval_range)
        Trend['Range_name']= pd.DataFrame(Hourly_Labels)
        Trend_Hr_range = Trend[['ORDER_ID','Range_name']].groupby('Range_name',as_index=False).sum()
        Trend = Trend_Hr_range.copy()
        
        
    return Trend

# %%
def Trend_Analysis_pi(dataset, Variables, CountVariable,DateVariable, GroupbyVariable, TrendType):
    
    Trend = dataset[Variables].pivot_table(index=GroupbyVariable, columns=CountVariable, aggfunc=len, fill_value=0)
    Trend.reset_index(inplace=True)
        
    if TrendType =="Monthly":
        #Trend['Month_name']= Trend[DateVariable].astype(int).apply(lambda x: calendar.month_abbr[x])
        pass
        
    if TrendType =="Weekly":    
        pass
    
    if TrendType =="Hourly":
        Hourly_Labels = ['22-24','0-2','0-2','2-4','2-4','4-6','4-6','6-8','6-8','8-10','8-10','10-12','10-12','12-14','12-14','14-16','14-16','16-18','16-18','18-20','18-20','20-22','20-22','22-24']
        interval_range = pd.interval_range(start=0, freq=2, end=24)
        Trend['Range'] = pd.cut(Trend[DateVariable], bins=interval_range)
        Trend['Range_name']= pd.DataFrame(Hourly_Labels)
        Trend_Hr_range = Trend[['ORDER_ID','Range_name']].groupby('Range_name',as_index=False).sum()
        Trend = Trend_Hr_range.copy()
        
        
    return Trend

# %%
def Merge(left, left_on_var, right1, right1_on_var, right2, right2_on_var, how, ind, occurrence):
    merged1 = pd.merge(left, right1, left_on=left_on_var, right_on = right1_on_var, how = how,indicator=ind)
    if occurrence == 'double':
        merged1.drop(['_merge'], axis=1,inplace = True)
        merged2 = pd.merge(merged1, right2, left_on=left_on_var ,right_on = right2_on_var,how = how,indicator=ind)
        return merged2
    return merged1

# %%
CTB_New_columns = ['REGION_CODE', 'DELR_RGON_NAME', 'DEALER_ID', 'DEALER_NAME',
       'ASSIGNED_SALES_CONSULTANT', 'STATE', 'CITY', 'ORDER_ID', 'ORDER_DATE',
       'ORDER_STATUS', 'ORDER_STAGE', 'CONSULTANT_ASSISGN_Y_N',
       'CUSTOMER_NAME', 'CUSTOMER_MOBILE', 'CUSTOMER_EMAIL', 'MODEL', 'ENGINE',
       'VARIANT', 'INTERIOR_COLOR', 'EXTERIOR_COLOR', 'FINANCE', 'LOAN_TYPE',
       'FINANCE_STATUS', 'BOOKING', 'FINAL_PURCHASE_AMOUNT', 'BOOKING_AMOUNT',
       'BALANCE_AMOUNT', 'TRADE', 'DEALER_CODE', 'DEAL_CODE_VALUE',
       'BOOKING_DATE', 'INVC_CNFR_YN', 'PAY_AT_DELR_YN']
#33columns

# %%
#new data for march

# %%
ctb1 = pd.read_excel('ctb_ord140421.xls', sheet_name='Sheet 1')
print(ctb1.shape)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (64999, 33)

# %%
ctb2 = pd.read_excel('ctb_ord140421.xls', sheet_name='Sheet 2')
print(ctb2.shape)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (10637, 33)

# %%
frames = [ctb1,ctb2]
ctb_data=pd.concat(frames)
ctb_data.shape
# Out:
# (75636, 33)

# %%
# Assigning new column name
CTB_New_columns = ['REGION_CODE', 'DELR_RGON_NAME', 'DEALER_ID', 'DEALER_NAME',
       'ASSIGNED_SALES_CONSULTANT', 'STATE', 'CITY', 'ORDER_ID', 'ORDER_DATE',
       'ORDER_STATUS', 'ORDER_STAGE', 'CONSULTANT_ASSISGN_Y_N',
       'CUSTOMER_NAME', 'CUSTOMER_MOBILE', 'CUSTOMER_EMAIL', 'MODEL', 'ENGINE',
       'VARIANT', 'INTERIOR_COLOR', 'EXTERIOR_COLOR', 'FINANCE', 'LOAN_TYPE',
       'FINANCE_STATUS', 'BOOKING', 'FINAL_PURCHASE_AMOUNT', 'BOOKING_AMOUNT',
       'BALANCE_AMOUNT', 'TRADE', 'DEALER_CODE', 'DEAL_CODE_VALUE',
       'BOOKING_DATE', 'INVC_CNFR_YN', 'PAY_AT_DELR_YN']

# %%
# Mapping new columns name to the ctb dataframe
ctb_data.columns=CTB_New_columns

# %%
# adding date function to map "year","_","monthkey" on the date column

# %%
add_datepart(ctb_data,'ORDER_DATE',False)

# %%
print(ctb_data.shape)
print(ctb_data.columns)
ctb_data.head()
# Out:
# (75636, 44)
# Index(['REGION_CODE', 'DELR_RGON_NAME', 'DEALER_ID', 'DEALER_NAME',
#        'ASSIGNED_SALES_CONSULTANT', 'STATE', 'CITY', 'ORDER_ID', 'ORDER_DATE',
#        'ORDER_STATUS', 'ORDER_STAGE', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_NAME', 'CUSTOMER_MOBILE', 'CUSTOMER_EMAIL', 'MODEL', 'ENGINE',
#        'VARIANT', 'INTERIOR_COLOR', 'EXTERIOR_COLOR', 'FINANCE', 'LOAN_TYPE',
#        'FINANCE_STATUS', 'BOOKING', 'FINAL_PURCHASE_AMOUNT', 'BOOKING_AMOUNT',
#        'BALANCE_AMOUNT', 'TRADE', 'DEALER_CODE', 'DEAL_CODE_VALUE',
#        'BOOKING_DATE', 'INVC_CNFR_YN', 'PAY_AT_DELR_YN', 'ORDER_DATEYear',
#        'ORDER_DATEMonth', 'ORDER_DATEWeek', 'ORDER_DATEDay', 'ORDER_DATEhour',
#        'ORDER_DATEDayofweek', 'ORDER_DATEDayofyear', 'ORDER_DATEweekofyear',
#        'ORDER_DATEMonthName', 'ORDER_DATEMonthKey', 'ORDER_DATEWeekKey'],
#       dtype='object')
#   REGION_CODE DELR_RGON_NAME DEALER_ID       DEALER_NAME  \
# 0       C1101    Central RO1     N1A03   KONCEPT HYUNDAI
# 1       C1101    Central RO1     N1A03   KONCEPT HYUNDAI
# 2       C1101    Central RO1     N1220  FRONTIER HYUNDAI
# 3       C1101    Central RO1     N1223   HIMGIRI HYUNDAI
# 4       C1101    Central RO1     N1223   HIMGIRI HYUNDAI
#
#   ASSIGNED_SALES_CONSULTANT  STATE   CITY            ORDER_ID  \
# 0         Bhuvnesh Karnatak  Delhi  Delhi  ORD202012816276904
# 1         Bhuvnesh Karnatak  Delhi  Delhi   ORD20202642245061
# 2             Mandeep Singh  Delhi  Delhi  ORD202011413365197
# 3            Neeraj Singhal  Delhi  Delhi  ORD202011511731225
# 4            Neeraj Singhal  Delhi  Delhi  ORD202011550357047
#
#            ORDER_DATE  ORDER_STATUS  ... ORDER_DATEMonth ORDER_DATEWeek  \
# 0 2020-01-28 19:50:08  Cancellation  ...               1              5
# 1 2020-02-06 15:19:11  Cancellation  ...               2              6
# 2 2020-01-14 11:04:27  Cancellation  ...               1              3
# 3 2020-01-15 05:48:59  Cancellation  ...               1              3
# 4 2020-01-15 05:54:55  Cancellation  ...               1              3
#
#   ORDER_DATEDay  ORDER_DATEhour ORDER_DATEDayofweek ORDER_DATEDayofyear  \
# 0            28              19                   1                  28
# 1             6              15                   3                  37
# 2            14              11                   1                  14
# 3            15               5                   2                  15
# 4            15               5                   2                  15
#
#   ORDER_DATEweekofyear ORDER_DATEMonthName ORDER_DATEMonthKey  \
# 0                    5                 Jan             2020_1
# 1                    6                 Feb             2020_2
# 2                    3                 Jan             2020_1
# 3                    3                 Jan             2020_1
# 4                    3                 Jan             2020_1
#
#   ORDER_DATEWeekKey
# 0            2020_5
# 1            2020_6
# 2            2020_3
# 3            2020_3
# 4            2020_3
#
# [5 rows x 44 columns]

# %%
# missing value info 
ctb_data.isnull().sum()
# Out:
# REGION_CODE                      0
# DELR_RGON_NAME                   0
# DEALER_ID                        0
# DEALER_NAME                      0
# ASSIGNED_SALES_CONSULTANT        0
# STATE                            0
# CITY                             0
# ORDER_ID                         0
# ORDER_DATE                       0
# ORDER_STATUS                     0
# ORDER_STAGE                     77
# CONSULTANT_ASSISGN_Y_N          40
# CUSTOMER_NAME                    2
# CUSTOMER_MOBILE                  0
# CUSTOMER_EMAIL                   0
# MODEL                            0
# ENGINE                           0
# VARIANT                          0
# INTERIOR_COLOR               13384
# EXTERIOR_COLOR                   0
# FINANCE                          0
# LOAN_TYPE                        0
# FINANCE_STATUS                   0
# BOOKING                          0
# FINAL_PURCHASE_AMOUNT            0
# BOOKING_AMOUNT                   0
# BALANCE_AMOUNT                   0
# TRADE                            0
# DEALER_CODE                      0
# DEAL_CODE_VALUE                  0
# BOOKING_DATE                 73159
# INVC_CNFR_YN                     0
# PAY_AT_DELR_YN                   0
# ORDER_DATEYear                   0
# ORDER_DATEMonth                  0
# ORDER_DATEWeek                   0
# ORDER_DATEDay                    0
# ORDER_DATEhour                   0
# ORDER_DATEDayofweek              0
# ORDER_DATEDayofyear              0
# ORDER_DATEweekofyear             0
# ORDER_DATEMonthName              0
# ORDER_DATEMonthKey               0
# ORDER_DATEWeekKey                0
# dtype: int64

# %%
## Imputing Apr20 records

# %%
CTB_not4 = ctb_data.loc[(ctb_data['ORDER_DATEMonthKey'] !='2020_4')].sort_values('ORDER_DATEMonth')
CTB_not4.shape
# Out:
# (63803, 44)

# %%
CTB_4 = ctb_data.loc[(ctb_data['ORDER_DATEMonthKey'] =='2020_4')].sort_values('ORDER_DATEMonth')
CTB_4.shape
# Out:
# (11833, 44)

# %%
apr_remove = pd.read_excel("AprilAnalysis.xlsx", sheet_name=' 4 SC orders frm 1')
apr_remove.shape
# Out:
# (7782, 17)

# %%
apr_merged = pd.merge(CTB_4, apr_remove['_ORDER _ID'], left_on='ORDER_ID', right_on = '_ORDER _ID', how = 'outer',indicator=True)
apr_merged.shape
# Out:
# (11833, 46)

# %%
apr_merged['_merge'].value_counts()
# Out:
# both          7782
# left_only     4051
# right_only       0
# Name: _merge, dtype: int64

# %%
apr_custonly = apr_merged.loc[(apr_merged['_merge'] == 'left_only')]
print(apr_custonly.shape)
#apr_custonly.head(2)
# Out:
# (4051, 46)

# %%
CTB_april = apr_custonly.copy()
CTB_april.drop(['_merge'], axis=1,inplace = True)
print (CTB_april.shape)
# Out:
# (4051, 45)

# %%
frames = [CTB_not4,CTB_april]
CTB_sc_treat = pd.concat(frames)
print(CTB_sc_treat.shape)
CTB_sc_treat.columns
# Out:
# (67854, 45)
# Index(['ASSIGNED_SALES_CONSULTANT', 'BALANCE_AMOUNT', 'BOOKING',
#        'BOOKING_AMOUNT', 'BOOKING_DATE', 'CITY', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_EMAIL', 'CUSTOMER_MOBILE', 'CUSTOMER_NAME', 'DEALER_CODE',
#        'DEALER_ID', 'DEALER_NAME', 'DEAL_CODE_VALUE', 'DELR_RGON_NAME',
#        'ENGINE', 'EXTERIOR_COLOR', 'FINAL_PURCHASE_AMOUNT', 'FINANCE',
#        'FINANCE_STATUS', 'INTERIOR_COLOR', 'INVC_CNFR_YN', 'LOAN_TYPE',
#        'MODEL', 'ORDER_DATE', 'ORDER_DATEDay', 'ORDER_DATEDayofweek',
#        'ORDER_DATEDayofyear', 'ORDER_DATEMonth', 'ORDER_DATEMonthKey',
#        'ORDER_DATEMonthName', 'ORDER_DATEWeek', 'ORDER_DATEWeekKey',
#        'ORDER_DATEYear', 'ORDER_DATEhour', 'ORDER_DATEweekofyear', 'ORDER_ID',
#        'ORDER_STAGE', 'ORDER_STATUS', 'PAY_AT_DELR_YN', 'REGION_CODE', 'STATE',
#        'TRADE', 'VARIANT', '_ORDER _ID'],
#       dtype='object')

# %%
CTB_sc_treat_march = CTB_sc_treat[CTB_sc_treat['ORDER_DATEMonthKey']!='2021_4']
CTB_sc_treat_march.shape
# Out:
# (65792, 45)

# %%
## April Data

# %%
ctb_april = pd.read_excel("ctb_ord040521.xls")
# Out:
# WARNING *** file size (10110198) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
ctb_april.columns
# Out:
# Index(['_REGION _CODE', 'DELR_RGON_NAME', '_DEALER _ID', '_DEALER _NAME',
#        '_ASSIGNED _SALES _CONSULTANT', '_STATE', '_CITY', '_ORDER _ID',
#        '_ORDER _DATE', '_ORDER _STATUS', '_ORDER _STAGE',
#        '_CONSULTANT _ASSISGN (_Y/_N)', '_CUSTOMER _NAME', '_CUSTOMER _MOBILE',
#        '_CUSTOMER _EMAIL', '_MODEL', '_ENGINE', '_VARIANT', '_INTERIOR _COLOR',
#        '_EXTERIOR _COLOR', '_FINANCE (_Y/_N)', '_LOAN _TYPE',
#        '_FINANCE _STATUS', '_BOOKING (_Y/_N)', '_FINAL _PURCHASE _AMOUNT',
#        '_BOOKING _AMOUNT', '_BALANCE _AMOUNT', '_TRADE-IN (_Y/_N)',
#        '_DEALER _CODE (_Y/_N)', '_DEAL _CODE _VALUE', 'BOOKING_DATE',
#        'INVC_CNFR_YN', 'PAY_AT_DELR_YN'],
#       dtype='object')

# %%
ctb_april.columns=CTB_New_columns

# %%
ctb_april.isnull().sum()
# Out:
# REGION_CODE                      0
# DELR_RGON_NAME                   0
# DEALER_ID                        0
# DEALER_NAME                      0
# ASSIGNED_SALES_CONSULTANT        0
# STATE                            0
# CITY                             0
# ORDER_ID                         0
# ORDER_DATE                       0
# ORDER_STATUS                     0
# ORDER_STAGE                      0
# CONSULTANT_ASSISGN_Y_N           0
# CUSTOMER_NAME                    0
# CUSTOMER_MOBILE                  0
# CUSTOMER_EMAIL                   0
# MODEL                            0
# ENGINE                           0
# VARIANT                          0
# INTERIOR_COLOR                 690
# EXTERIOR_COLOR                   0
# FINANCE                          0
# LOAN_TYPE                        0
# FINANCE_STATUS                   0
# BOOKING                          0
# FINAL_PURCHASE_AMOUNT            0
# BOOKING_AMOUNT                   0
# BALANCE_AMOUNT                   0
# TRADE                            0
# DEALER_CODE                      0
# DEAL_CODE_VALUE                  0
# BOOKING_DATE                 17754
# INVC_CNFR_YN                     0
# PAY_AT_DELR_YN                   0
# dtype: int64

# %%
add_datepart(ctb_april,'ORDER_DATE')

# %%
CTB_sc_treat_april = ctb_april[ctb_april['ORDER_DATEMonthKey']=='2021_4']

# %%
CTB_sc_treat_april.ORDER_ID.count()
# Out:
# 3995

# %%
3995 - 3955
# Out:
# 40

# %%
3995 + 1966
# Out:
# 5961

# %%
5921 - 1966
# Out:
# 3955

# %%
CTB_sc_treat_april.drop_duplicates(subset='ORDER_ID', inplace=True)
CTB_sc_treat_april.shape
# Out:
# (3955, 44)

# %%
## May Data

# %%
ctb_may = pd.read_excel("ctb_ordfi040621.xls")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
ctb_may.isnull().sum()
# Out:
# _REGION _CODE                       0
# DELR_RGON_NAME                      0
# _DEALER _ID                         0
# _DEALER _NAME                       0
# _ASSIGNED _SALES _CONSULTANT        0
# _STATE                              0
# _CITY                               0
# _ORDER _ID                          0
# _ORDER _DATE                        0
# _ORDER _STATUS                      0
# _ORDER _STAGE                       0
# _CONSULTANT _ASSISGN (_Y/_N)        0
# _CUSTOMER _NAME                     0
# _CUSTOMER _MOBILE                   0
# _CUSTOMER _EMAIL                    0
# _MODEL                              0
# _ENGINE                             0
# _VARIANT                            0
# _INTERIOR _COLOR                  892
# _EXTERIOR _COLOR                    0
# _FINANCE (_Y/_N)                    0
# _LOAN _TYPE                         0
# _FINANCE _STATUS                    0
# _BOOKING (_Y/_N)                    0
# _FINAL _PURCHASE _AMOUNT            0
# _BOOKING _AMOUNT                    0
# _BALANCE _AMOUNT                    0
# _TRADE-IN (_Y/_N)                   0
# _DEALER _CODE (_Y/_N)               0
# _DEAL _CODE _VALUE                  0
# BOOKING_DATE                    21836
# INVC_CNFR_YN                        0
# PAY_AT_DELR_YN                      0
# CSTM_SLTN                        2441
# DATE_OF_BRTH                    22367
# DATE_OF_ANVR                    22375
# dtype: int64

# %%
ctb_may.columns
# Out:
# Index(['_REGION _CODE', 'DELR_RGON_NAME', '_DEALER _ID', '_DEALER _NAME',
#        '_ASSIGNED _SALES _CONSULTANT', '_STATE', '_CITY', '_ORDER _ID',
#        '_ORDER _DATE', '_ORDER _STATUS', '_ORDER _STAGE',
#        '_CONSULTANT _ASSISGN (_Y/_N)', '_CUSTOMER _NAME', '_CUSTOMER _MOBILE',
#        '_CUSTOMER _EMAIL', '_MODEL', '_ENGINE', '_VARIANT', '_INTERIOR _COLOR',
#        '_EXTERIOR _COLOR', '_FINANCE (_Y/_N)', '_LOAN _TYPE',
#        '_FINANCE _STATUS', '_BOOKING (_Y/_N)', '_FINAL _PURCHASE _AMOUNT',
#        '_BOOKING _AMOUNT', '_BALANCE _AMOUNT', '_TRADE-IN (_Y/_N)',
#        '_DEALER _CODE (_Y/_N)', '_DEAL _CODE _VALUE', 'BOOKING_DATE',
#        'INVC_CNFR_YN', 'PAY_AT_DELR_YN', 'CSTM_SLTN', 'DATE_OF_BRTH',
#        'DATE_OF_ANVR'],
#       dtype='object')

# %%
ctb_may.drop(['CSTM_SLTN','DATE_OF_BRTH','DATE_OF_ANVR'],axis=1,inplace=True)

# %%
ctb_may.columns=CTB_New_columns

# %%
#ctb_may.to_excel("CTB_MAY1.xlsx")

# %%
ctb_may.isnull().sum()
# Out:
# REGION_CODE                      0
# DELR_RGON_NAME                   0
# DEALER_ID                        0
# DEALER_NAME                      0
# ASSIGNED_SALES_CONSULTANT        0
# STATE                            0
# CITY                             0
# ORDER_ID                         0
# ORDER_DATE                       0
# ORDER_STATUS                     0
# ORDER_STAGE                      0
# CONSULTANT_ASSISGN_Y_N           0
# CUSTOMER_NAME                    0
# CUSTOMER_MOBILE                  0
# CUSTOMER_EMAIL                   0
# MODEL                            0
# ENGINE                           0
# VARIANT                          0
# INTERIOR_COLOR                 892
# EXTERIOR_COLOR                   0
# FINANCE                          0
# LOAN_TYPE                        0
# FINANCE_STATUS                   0
# BOOKING                          0
# FINAL_PURCHASE_AMOUNT            0
# BOOKING_AMOUNT                   0
# BALANCE_AMOUNT                   0
# TRADE                            0
# DEALER_CODE                      0
# DEAL_CODE_VALUE                  0
# BOOKING_DATE                 21836
# INVC_CNFR_YN                     0
# PAY_AT_DELR_YN                   0
# dtype: int64

# %%
add_datepart(ctb_may,'ORDER_DATE')

# %%
CTB_sc_treat_may = ctb_may[ctb_may['ORDER_DATEMonthKey']=='2021_5']

# %%
CTB_sc_treat_may.drop_duplicates(subset='ORDER_ID', inplace=True)
CTB_sc_treat_may.shape
# Out:
# (4192, 44)

# %%
CTB_sc_treat_may.shape
# Out:
# (4192, 44)

# %% [markdown]
# ## CTB JUNE

# %%
ctb_june = pd.read_excel("ctb_ord010721.xls")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
ctb_june.columns
# Out:
# Index(['_REGION _CODE', 'DELR_RGON_NAME', '_DEALER _ID', '_DEALER _NAME',
#        '_ASSIGNED _SALES _CONSULTANT', '_STATE', '_CITY', '_ORDER _ID',
#        '_ORDER _DATE', '_ORDER _STATUS', '_ORDER _STAGE',
#        '_CONSULTANT _ASSISGN (_Y/_N)', '_CUSTOMER _NAME', '_CUSTOMER _MOBILE',
#        '_CUSTOMER _EMAIL', '_MODEL', '_ENGINE', '_VARIANT', '_INTERIOR _COLOR',
#        '_EXTERIOR _COLOR', '_FINANCE (_Y/_N)', '_LOAN _TYPE',
#        '_FINANCE _STATUS', '_BOOKING (_Y/_N)', '_FINAL _PURCHASE _AMOUNT',
#        '_BOOKING _AMOUNT', '_BALANCE _AMOUNT', '_TRADE-IN (_Y/_N)',
#        '_DEALER _CODE (_Y/_N)', '_DEAL _CODE _VALUE', 'BOOKING_DATE',
#        'INVC_CNFR_YN', 'PAY_AT_DELR_YN', 'CSTM_SLTN', 'DATE_OF_BRTH',
#        'DATE_OF_ANVR'],
#       dtype='object')

# %%
ctb_june.drop(['CSTM_SLTN','DATE_OF_BRTH','DATE_OF_ANVR'],axis=1,inplace=True)

# %%
ctb_june.columns=CTB_New_columns

# %%
add_datepart(ctb_june,'ORDER_DATE')

# %%
CTB_sc_treat_june = ctb_june[ctb_june['ORDER_DATEMonthKey']=='2021_6']

# %%
CTB_sc_treat_june.drop_duplicates(subset='ORDER_ID', inplace=True)
CTB_sc_treat_june.shape
# Out:
# (7368, 44)

# %%
7368 +1077
# Out:
# 8445

# %%
81307+8192+610+1077
# Out:
# 91186

# %%
frames1 = [CTB_sc_treat_march,CTB_sc_treat_april,CTB_sc_treat_may,CTB_sc_treat_june]
ctb_data_raw = pd.concat(frames1)
ctb_data_raw.shape
# Out:
# (81307, 45)

# %%
#CTB_data = select_date_range(ctb_data_raw,"ORDER_DATE",Startdate,Enddate)

CTB_data = ctb_data_raw[(ctb_data_raw['ORDER_DATEMonthKey']>='2020_1')&(ctb_data_raw['ORDER_DATEMonthKey']<='2021_6')]
CTB_data.shape
# Out:
# (81307, 45)

# %%
CTB_data.drop_duplicates(subset='ORDER_ID',inplace=True)

# %%
CTB_data.shape
# Out:
# (81195, 45)

# %%
CTB_data.to_excel("CTB_ORD_June.xlsx")

# %%
CTB_data.isnull().sum()
# Out:
# ASSIGNED_SALES_CONSULTANT        0
# BALANCE_AMOUNT                   0
# BOOKING                          0
# BOOKING_AMOUNT                   0
# BOOKING_DATE                 77533
# CITY                             0
# CONSULTANT_ASSISGN_Y_N          40
# CUSTOMER_EMAIL                   0
# CUSTOMER_MOBILE                  0
# CUSTOMER_NAME                    2
# DEALER_CODE                      0
# DEALER_ID                        0
# DEALER_NAME                      0
# DEAL_CODE_VALUE                  0
# DELR_RGON_NAME                   0
# ENGINE                           0
# EXTERIOR_COLOR                   0
# FINAL_PURCHASE_AMOUNT            0
# FINANCE                          0
# FINANCE_STATUS                   0
# INTERIOR_COLOR               12801
# INVC_CNFR_YN                     0
# LOAN_TYPE                        0
# MODEL                            0
# ORDER_DATE                       0
# ORDER_DATEDay                    0
# ORDER_DATEDayofweek              0
# ORDER_DATEDayofyear              0
# ORDER_DATEMonth                  0
# ORDER_DATEMonthKey               0
# ORDER_DATEMonthName              0
# ORDER_DATEWeek                   0
# ORDER_DATEWeekKey                0
# ORDER_DATEYear                   0
# ORDER_DATEhour                   0
# ORDER_DATEweekofyear             0
# ORDER_ID                         0
# ORDER_STAGE                     77
# ORDER_STATUS                     0
# PAY_AT_DELR_YN                   0
# REGION_CODE                      0
# STATE                            0
# TRADE                            0
# VARIANT                          0
# _ORDER _ID                   81195
# dtype: int64

# %%
CTB_data.to_excel("CTB_data_till_Junw2021.xlsx")

# %%
# CTB Booking YES/NO

# %%
CTB_booking = CTB_data[CTB_data["BOOKING"]=="Y"]
print("CTB_booking : ", CTB_booking.shape)
CTB_booking_na = CTB_booking[CTB_booking["BOOKING_DATE"].notna()]
print("CTB_booking_na : ",CTB_booking_na.shape)
# Out:
# CTB_booking :  (3856, 45)
# CTB_booking_na :  (3469, 45)

# %%
3965 + 3550
# Out:
# 7515

# %%
add_datepart(CTB_booking_na,'BOOKING_DATE',False)

# %%
CTB_booking_na.columns
# Out:
# Index(['ASSIGNED_SALES_CONSULTANT', 'BALANCE_AMOUNT', 'BOOKING',
#        'BOOKING_AMOUNT', 'BOOKING_DATE', 'CITY', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_EMAIL', 'CUSTOMER_MOBILE', 'CUSTOMER_NAME', 'DEALER_CODE',
#        'DEALER_ID', 'DEALER_NAME', 'DEAL_CODE_VALUE', 'DELR_RGON_NAME',
#        'ENGINE', 'EXTERIOR_COLOR', 'FINAL_PURCHASE_AMOUNT', 'FINANCE',
#        'FINANCE_STATUS', 'INTERIOR_COLOR', 'INVC_CNFR_YN', 'LOAN_TYPE',
#        'MODEL', 'ORDER_DATE', 'ORDER_DATEDay', 'ORDER_DATEDayofweek',
#        'ORDER_DATEDayofyear', 'ORDER_DATEMonth', 'ORDER_DATEMonthKey',
#        'ORDER_DATEMonthName', 'ORDER_DATEWeek', 'ORDER_DATEWeekKey',
#        'ORDER_DATEYear', 'ORDER_DATEhour', 'ORDER_DATEweekofyear', 'ORDER_ID',
#        'ORDER_STAGE', 'ORDER_STATUS', 'PAY_AT_DELR_YN', 'REGION_CODE', 'STATE',
#        'TRADE', 'VARIANT', '_ORDER _ID', 'BOOKING_DATEYear',
#        'BOOKING_DATEMonth', 'BOOKING_DATEWeek', 'BOOKING_DATEDay',
#        'BOOKING_DATEhour', 'BOOKING_DATEDayofweek', 'BOOKING_DATEDayofyear',
#        'BOOKING_DATEweekofyear', 'BOOKING_DATEMonthName',
#        'BOOKING_DATEMonthKey', 'BOOKING_DATEWeekKey'],
#       dtype='object')

# %%
CTB_data.dtypes
# Out:
# ASSIGNED_SALES_CONSULTANT            object
# BALANCE_AMOUNT                        int64
# BOOKING                              object
# BOOKING_AMOUNT                        int64
# BOOKING_DATE                 datetime64[ns]
# CITY                                 object
# CONSULTANT_ASSISGN_Y_N               object
# CUSTOMER_EMAIL                       object
# CUSTOMER_MOBILE                       int64
# CUSTOMER_NAME                        object
# DEALER_CODE                          object
# DEALER_ID                            object
# DEALER_NAME                          object
# DEAL_CODE_VALUE                       int64
# DELR_RGON_NAME                       object
# ENGINE                               object
# EXTERIOR_COLOR                       object
# FINAL_PURCHASE_AMOUNT                 int64
# FINANCE                              object
# FINANCE_STATUS                       object
# INTERIOR_COLOR                       object
# INVC_CNFR_YN                         object
# LOAN_TYPE                            object
# MODEL                                object
# ORDER_DATE                   datetime64[ns]
# ORDER_DATEDay                         int64
# ORDER_DATEDayofweek                   int64
# ORDER_DATEDayofyear                   int64
# ORDER_DATEMonth                       int64
# ORDER_DATEMonthKey                   object
# ORDER_DATEMonthName                  object
# ORDER_DATEWeek                        int64
# ORDER_DATEWeekKey                    object
# ORDER_DATEYear                        int64
# ORDER_DATEhour                        int64
# ORDER_DATEweekofyear                  int64
# ORDER_ID                             object
# ORDER_STAGE                          object
# ORDER_STATUS                         object
# PAY_AT_DELR_YN                       object
# REGION_CODE                          object
# STATE                                object
# TRADE                                object
# VARIANT                              object
# _ORDER _ID                           object
# dtype: object

# %%
CTB_data.shape
# Out:
# (81195, 45)

# %% [markdown]
# ## READING GDMS DATASET

# %% [markdown]
# # March

# %%
GDMS_data_raw1 = pd.read_excel("ctb_gdms140421.xls",sheet_name='Sheet 1')
print(GDMS_data_raw1.shape)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (64999, 15)

# %%
GDMS_data_raw1.dtypes
# Out:
# CSPM_DLR_NAME       object
# EQRY_DLR_NO         object
# EQRY_ENQRY_NO       object
# EQRY_DATE            int64
# EQRY_STAT            int64
# EQRY_STATUS_NM      object
# EQCR_MODEL_CODE     object
# EQCR_MODEL_NAME     object
# EQRY_NEWCAR_YN      object
# EQRY_REF_NO         object
# CTB_BOOKING_Y       object
# RETAIL_DATE        float64
# INVC_CNFM_YN        object
# BKNG_NO             object
# BKNG_DATE          float64
# dtype: object

# %%
GDMS_data_raw1.head(2)
# Out:
#       CSPM_DLR_NAME EQRY_DLR_NO EQRY_ENQRY_NO  EQRY_DATE  EQRY_STAT  \
# 0    ROSHAN HYUNDAI       N4A06    E202041462   20201104         80
# 1  SAI AUTO HYUNDAI       W1210    E202039463   20201028         80
#
#    EQRY_STATUS_NM EQCR_MODEL_CODE EQCR_MODEL_NAME EQRY_NEWCAR_YN  \
# 0  Invoice Cancel              SV     All New i20              Y
# 1  Invoice Cancel              SV     All New i20              Y
#
#            EQRY_REF_NO CTB_BOOKING_Y  RETAIL_DATE INVC_CNFM_YN     BKNG_NO  \
# 0  ORD2020110413233196             Y          NaN          NaN  B202001236
# 1  ORD2020102811922815             Y          NaN          NaN  B202016328
#
#     BKNG_DATE
# 0  20201104.0
# 1  20201028.0

# %%
GDMS_data_raw2 = pd.read_excel("ctb_gdms140421.xls",sheet_name='Sheet 2')

print(GDMS_data_raw2.shape)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (8112, 15)

# %%
GDMS_data_raw2.head(2)
# Out:
#       CSPM_DLR_NAME EQRY_DLR_NO EQRY_ENQRY_NO  EQRY_DATE  EQRY_STAT  \
# 0  KUSALAVA HYUNDAI       S5A08    E202112248   20210316          9
# 1      BLUE HYUNDAI       S8A04    E202114416   20210329         91
#
#                      EQRY_STATUS_NM EQCR_MODEL_CODE EQCR_MODEL_NAME  \
# 0                 Enquiry Follow up              FH       New Creta
# 1  CTB-Booking Cancellation Request              SP           Venue
#
#   EQRY_NEWCAR_YN          EQRY_REF_NO CTB_BOOKING_Y  RETAIL_DATE  \
# 0              Y  ORD2021031619520788             N          NaN
# 1              Y  ORD2021032913677914             N          NaN
#
#    INVC_CNFM_YN  BKNG_NO  BKNG_DATE
# 0           NaN      NaN        NaN
# 1           NaN      NaN        NaN

# %%
#GDMS_data_raw3 = pd.read_excel("ctb_gdms040521.xls")

# %%
frames = [GDMS_data_raw1,GDMS_data_raw2]
GDMS_data_raw = pd.concat(frames)
print(GDMS_data_raw.shape)
GDMS_data_raw.columns
# Out:
# (73111, 15)
# Index(['CSPM_DLR_NAME', 'EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_DATE',
#        'EQRY_STAT', 'EQRY_STATUS_NM', 'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME',
#        'EQRY_NEWCAR_YN', 'EQRY_REF_NO', 'CTB_BOOKING_Y', 'RETAIL_DATE',
#        'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE'],
#       dtype='object')

# %%
GDMS_booking_raw = GDMS_data_raw.copy()
GDMS_booking_raw = GDMS_booking_raw[GDMS_booking_raw["BKNG_DATE"].notna()]
GDMS_booking_raw.shape
# Out:
# (5864, 15)

# %%
GDMS_booking_raw['BKNG_DATE_NEW'] = GDMS_booking_raw['BKNG_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_booking_raw['BKNG_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_booking_raw['BKNG_DATE'].map(lambda x: str(x)[6:8])
GDMS_booking_raw['BKNG_DATE_NEW'].head(2)
# Out:
# 0    2020-11-04
# 1    2020-10-28
# Name: BKNG_DATE_NEW, dtype: object

# %%
GDMS_booking_raw['BKNG_DATE_NEW']
# Out:
# 0       2020-11-04
# 1       2020-10-28
# 2       2020-05-15
# 3       2020-06-01
# 4       2020-10-06
# 5       2020-08-22
# 6       2020-11-13
# 7       2021-03-27
# 8       2020-05-07
# 9       2020-06-02
# 10      2021-03-12
# 11      2021-04-05
# 12      2021-04-05
# 13      2021-04-05
# 14      2021-04-05
# 15      2020-06-04
# 16      2020-08-13
# 17      2020-09-29
# 18      2020-11-01
# 19      2020-03-03
# 20      2020-09-13
# 21      2020-04-07
# 22      2020-03-04
# 23      2020-06-18
# 24      2020-09-21
# 25      2021-02-19
# 26      2020-04-05
# 27      2021-04-09
# 28      2020-03-11
# 29      2020-02-19
#            ...
# 5834    2021-03-20
# 5835    2021-03-23
# 5836    2021-03-30
# 5837    2021-03-31
# 5838    2021-01-04
# 5839    2021-02-15
# 5840    2021-03-27
# 5841    2021-03-05
# 5842    2021-03-08
# 5843    2021-03-20
# 5844    2021-03-24
# 5845    2021-02-16
# 5846    2021-04-12
# 5847    2021-04-03
# 5848    2021-04-05
# 5849    2021-03-26
# 5850    2021-03-10
# 5851    2021-03-10
# 5852    2021-01-26
# 5853    2021-02-27
# 5854    2021-02-27
# 5855    2021-03-03
# 5856    2021-03-17
# 5857    2021-03-20
# 5858    2021-04-07
# 5859    2021-04-08
# 5860    2021-03-09
# 5861    2020-03-15
# 5862    2020-03-11
# 5863    2020-10-13
# Name: BKNG_DATE_NEW, Length: 5864, dtype: object

# %% [markdown]
# GDMS_booking_raw = GDMS_booking_raw.loc[(GDMS_booking_raw['BKNG_DATE_NEW'] >= '2020-1-1')
#                      & (GDMS_booking_raw['BKNG_DATE_NEW'] < '2021-4-1')]

# %%
add_datepart(GDMS_booking_raw,'BKNG_DATE_NEW',False)
print(GDMS_booking_raw.columns)
GDMS_booking = select_date_range(GDMS_booking_raw,"BKNG_DATE_NEW",Startdate,Enddate)
# Out:
# Index(['CSPM_DLR_NAME', 'EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_DATE',
#        'EQRY_STAT', 'EQRY_STATUS_NM', 'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME',
#        'EQRY_NEWCAR_YN', 'EQRY_REF_NO', 'CTB_BOOKING_Y', 'RETAIL_DATE',
#        'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE', 'BKNG_DATE_NEW',
#        'BKNG_DATE_NEWYear', 'BKNG_DATE_NEWMonth', 'BKNG_DATE_NEWWeek',
#        'BKNG_DATE_NEWDay', 'BKNG_DATE_NEWhour', 'BKNG_DATE_NEWDayofweek',
#        'BKNG_DATE_NEWDayofyear', 'BKNG_DATE_NEWweekofyear',
#        'BKNG_DATE_NEWMonthName', 'BKNG_DATE_NEWMonthKey',
#        'BKNG_DATE_NEWWeekKey'],
#       dtype='object')
# old shape: (5864, 27)
# new shape: (5864, 27)

# %%
#GDMS_booking.drop(['BKNG_DATE'], axis=1, inplace=True)

# %%
#GDMS_booking.drop_duplicates(keep='first', inplace=True)

# %%
GDMS_booking.shape
# Out:
# (5864, 27)

# %%
GDMS_booking.columns
# Out:
# Index(['CSPM_DLR_NAME', 'EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_DATE',
#        'EQRY_STAT', 'EQRY_STATUS_NM', 'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME',
#        'EQRY_NEWCAR_YN', 'EQRY_REF_NO', 'CTB_BOOKING_Y', 'RETAIL_DATE',
#        'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE', 'BKNG_DATE_NEW',
#        'BKNG_DATE_NEWYear', 'BKNG_DATE_NEWMonth', 'BKNG_DATE_NEWWeek',
#        'BKNG_DATE_NEWDay', 'BKNG_DATE_NEWhour', 'BKNG_DATE_NEWDayofweek',
#        'BKNG_DATE_NEWDayofyear', 'BKNG_DATE_NEWweekofyear',
#        'BKNG_DATE_NEWMonthName', 'BKNG_DATE_NEWMonthKey',
#        'BKNG_DATE_NEWWeekKey'],
#       dtype='object')

# %%
GDMS_booking.BKNG_DATE_NEW.max()
# Out:
# Timestamp('2021-04-13 00:00:00')

# %%
GDMS_booking_march = GDMS_booking[GDMS_booking['BKNG_DATE_NEWMonthKey']!='2021_4']
GDMS_booking_march.shape
# Out:
# (5553, 27)

# %% [markdown]
# #  GDMS April

# %%
GDMS_booking_april = pd.read_excel("ctb_gdms040521.xls")
GDMS_booking_april.shape
# Out:
# WARNING *** file size (3799539) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (18028, 15)

# %%
GDMS_booking_april = GDMS_booking_april[GDMS_booking_april["BKNG_DATE"].notna()]
GDMS_booking_april.shape
# Out:
# (2044, 15)

# %%
GDMS_booking_april['BKNG_DATE_NEW'] = GDMS_booking_april['BKNG_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_booking_april['BKNG_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_booking_april['BKNG_DATE'].map(lambda x: str(x)[6:8])
GDMS_booking_april['BKNG_DATE_NEW'].head(2)
# Out:
# 4    2021-01-28
# 5    2021-02-05
# Name: BKNG_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_booking_april,'BKNG_DATE_NEW')

# %%
GDMS_booking_april = GDMS_booking_april[GDMS_booking_april['BKNG_DATE_NEWMonthKey']=='2021_4']
GDMS_booking_april.shape
# Out:
# (580, 27)

# %% [markdown]
# # GDMS MAY

# %%
GDMS_booking_may = pd.read_excel("ctb_gdms040621.xls")
GDMS_booking_may.shape
# Out:
# WARNING *** file size (4625657) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (22031, 15)

# %%
GDMS_booking_may = GDMS_booking_may[GDMS_booking_may["BKNG_DATE"].notna()]
GDMS_booking_may.shape
# Out:
# (2427, 15)

# %%
GDMS_booking_may['BKNG_DATE_NEW'] = GDMS_booking_may['BKNG_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_booking_may['BKNG_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_booking_may['BKNG_DATE'].map(lambda x: str(x)[6:8])
GDMS_booking_may['BKNG_DATE_NEW'].head(2)
# Out:
# 4    2021-01-28
# 5    2021-02-05
# Name: BKNG_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_booking_may,'BKNG_DATE_NEW')

# %%
GDMS_booking_may = GDMS_booking_may[GDMS_booking_may['BKNG_DATE_NEWMonthKey']=='2021_5']
GDMS_booking_may.shape
# Out:
# (373, 27)

# %% [markdown]
# # GDMS JUNE

# %%
GDMS_booking_june = pd.read_excel("ctb_gdms300621.xls")
GDMS_booking_june.shape
# Out:
# WARNING *** file size (6042261) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (28794, 15)

# %%
GDMS_booking_june = GDMS_booking_june[GDMS_booking_june["BKNG_DATE"].notna()]
GDMS_booking_june.shape
# Out:
# (3662, 15)

# %%
GDMS_booking_june['BKNG_DATE_NEW'] = GDMS_booking_june['BKNG_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_booking_june['BKNG_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_booking_june['BKNG_DATE'].map(lambda x: str(x)[6:8])
GDMS_booking_june['BKNG_DATE_NEW'].head(2)
# Out:
# 0    2021-03-27
# 1    2021-03-12
# Name: BKNG_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_booking_june,'BKNG_DATE_NEW')

# %%
GDMS_booking_june = GDMS_booking_june[GDMS_booking_june['BKNG_DATE_NEWMonthKey']=='2021_6']
GDMS_booking_june.shape
# Out:
# (1262, 27)

# %%
frames2 = [GDMS_booking_march,GDMS_booking_april,GDMS_booking_may,GDMS_booking_june]
GDMS_Booking_new = pd.concat(frames2)
GDMS_Booking_new.shape
# Out:
# (7768, 27)

# %%
GDMS_Booking_new1 = GDMS_Booking_new[(GDMS_Booking_new['BKNG_DATE_NEWMonthKey']>='2020_1')&(GDMS_Booking_new['BKNG_DATE_NEWMonthKey']<='2021_6')]
GDMS_Booking_new1.shape
# Out:
# (7768, 27)

# %%
GDMS_Booking_new1.BKNG_DATE_NEWMonthKey.value_counts()
# Out:
# 2021_6     1262
# 2020_10     951
# 2020_11     764
# 2021_3      605
# 2021_4      580
# 2021_2      567
# 2020_12     565
# 2021_1      517
# 2020_9      465
# 2020_8      376
# 2021_5      373
# 2020_7      317
# 2020_6      229
# 2020_5       90
# 2020_4       59
# 2020_3       39
# 2020_2        8
# 2020_1        1
# Name: BKNG_DATE_NEWMonthKey, dtype: int64

# %%
GDMS_Booking_new1.EQRY_REF_NO.count()
# Out:
# 7768

# %% [markdown]
# ## CTB AND GDMS MERGE

# %%
# outer: use union of keys from both frames, similar to a SQL full outer join; sort keys lexicographically.
CTB_GDMS = pd.merge(CTB_data, GDMS_Booking_new, left_on=['ORDER_ID'],right_on = ['EQRY_REF_NO'], how = 'outer',indicator=True)
print(CTB_GDMS.shape)
CTB_GDMS['_merge'].value_counts()
# Out:
# (81219, 73)
# left_only     73451
# both           7744
# right_only       24
# Name: _merge, dtype: int64

# %% [markdown]
# ## Retail March

# %%
frames = [GDMS_data_raw1,GDMS_data_raw2]
GDMS_retail_march = pd.concat(frames)
print(GDMS_retail_march.shape)
GDMS_retail_march.columns
# Out:
# (73111, 15)
# Index(['CSPM_DLR_NAME', 'EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_DATE',
#        'EQRY_STAT', 'EQRY_STATUS_NM', 'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME',
#        'EQRY_NEWCAR_YN', 'EQRY_REF_NO', 'CTB_BOOKING_Y', 'RETAIL_DATE',
#        'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE'],
#       dtype='object')

# %%
GDMS_retail_march = GDMS_retail_march[GDMS_retail_march["RETAIL_DATE"].notna()]
GDMS_retail_march.shape
# Out:
# (2434, 15)

# %%
GDMS_retail_march['RETAIL_DATE_NEW'] = GDMS_retail_march['RETAIL_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_retail_march['RETAIL_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_retail_march['RETAIL_DATE'].map(lambda x: str(x)[6:8])
GDMS_retail_march['RETAIL_DATE_NEW'].head(2)
# Out:
# 138    2020-01-31
# 151    2020-07-07
# Name: RETAIL_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_retail_march,"RETAIL_DATE_NEW")

# %%
GDMS_retail_march.shape
GDMS_retail_march.columns
# Out:
# Index(['CSPM_DLR_NAME', 'EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_DATE',
#        'EQRY_STAT', 'EQRY_STATUS_NM', 'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME',
#        'EQRY_NEWCAR_YN', 'EQRY_REF_NO', 'CTB_BOOKING_Y', 'RETAIL_DATE',
#        'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE', 'RETAIL_DATE_NEW',
#        'RETAIL_DATE_NEWYear', 'RETAIL_DATE_NEWMonth', 'RETAIL_DATE_NEWWeek',
#        'RETAIL_DATE_NEWDay', 'RETAIL_DATE_NEWhour', 'RETAIL_DATE_NEWDayofweek',
#        'RETAIL_DATE_NEWDayofyear', 'RETAIL_DATE_NEWweekofyear',
#        'RETAIL_DATE_NEWMonthName', 'RETAIL_DATE_NEWMonthKey',
#        'RETAIL_DATE_NEWWeekKey'],
#       dtype='object')

# %%
GDMS_retail_march.drop_duplicates(subset='EQRY_REF_NO',inplace=True)

# %%
GDMS_retail_march = GDMS_retail_march[GDMS_retail_march['RETAIL_DATE_NEWMonthKey']!='2021_4']
GDMS_retail_march.shape
# Out:
# (2352, 27)

# %%
##  retail April

# %%
GDMS_retail_april = pd.read_excel("ctb_gdms040521.xls")
GDMS_retail_april.shape
# Out:
# WARNING *** file size (3799539) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (18028, 15)

# %%
GDMS_retail_april = GDMS_retail_april[GDMS_retail_april["RETAIL_DATE"].notna()]
GDMS_retail_april.shape
# Out:
# (576, 15)

# %%
GDMS_retail_april['RETAIL_DATE_NEW'] = GDMS_retail_april['RETAIL_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_retail_april['RETAIL_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_retail_april['RETAIL_DATE'].map(lambda x: str(x)[6:8])
GDMS_retail_april['RETAIL_DATE_NEW'].head(2)
# Out:
# 4    2021-03-20
# 5    2021-03-11
# Name: RETAIL_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_retail_april,"RETAIL_DATE_NEW")

# %%
GDMS_retail_april = GDMS_retail_april[GDMS_retail_april['RETAIL_DATE_NEWMonthKey']=='2021_4']
GDMS_retail_april.shape
# Out:
# (211, 27)

# %%
GDMS_retail_april.shape
# Out:
# (211, 27)

# %%
#GDMS_retail_april.drop_duplicates(subset='EQRY_REF_NO',inplace=True)

# %%
## retail may

# %%
GDMS_retail_may = pd.read_excel("ctb_gdms040621.xls")
GDMS_retail_may.shape
# Out:
# WARNING *** file size (4625657) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (22031, 15)

# %%
GDMS_retail_may = GDMS_retail_may[GDMS_retail_may["RETAIL_DATE"].notna()]
GDMS_retail_may.shape
# Out:
# (693, 15)

# %%
GDMS_retail_may['RETAIL_DATE_NEW'] = GDMS_retail_may['RETAIL_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_retail_may['RETAIL_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_retail_may['RETAIL_DATE'].map(lambda x: str(x)[6:8])
GDMS_retail_may['RETAIL_DATE_NEW'].head(2)
# Out:
# 4    2021-03-20
# 5    2021-03-11
# Name: RETAIL_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_retail_may,"RETAIL_DATE_NEW")

# %%
GDMS_retail_may = GDMS_retail_may[GDMS_retail_may['RETAIL_DATE_NEWMonthKey']=='2021_5']
GDMS_retail_may.shape
# Out:
# (112, 27)

# %%
GDMS_retail_may.drop_duplicates(subset='EQRY_REF_NO',inplace=True)

# %% [markdown]
# ## GDMS JUNE

# %%
GDMS_retail_june = pd.read_excel("ctb_gdms300621.xls")
GDMS_retail_june.shape
# Out:
# WARNING *** file size (6042261) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (28794, 15)

# %%
GDMS_retail_june = GDMS_retail_june[GDMS_retail_june["RETAIL_DATE"].notna()]
GDMS_retail_june.shape
# Out:
# (1039, 15)

# %%
GDMS_retail_june['RETAIL_DATE_NEW'] = GDMS_retail_june['RETAIL_DATE'].map(lambda x: str(x)[0:4]) + "-" +GDMS_retail_june['RETAIL_DATE'].map(lambda x: str(x)[4:6])+ "-" +GDMS_retail_june['RETAIL_DATE'].map(lambda x: str(x)[6:8])
GDMS_retail_june['RETAIL_DATE_NEW'].head(2)
# Out:
# 212    2021-02-13
# 223    2021-01-25
# Name: RETAIL_DATE_NEW, dtype: object

# %%
add_datepart(GDMS_retail_june,"RETAIL_DATE_NEW")

# %%
GDMS_retail_june = GDMS_retail_june[GDMS_retail_june['RETAIL_DATE_NEWMonthKey']=='2021_6']
GDMS_retail_june.shape
# Out:
# (352, 27)

# %%
GDMS_retail_june.drop_duplicates(subset='EQRY_REF_NO',inplace=True)

# %%
frames4 = [GDMS_retail_march,GDMS_retail_april,GDMS_retail_may,GDMS_retail_june]

# %%
GDMS_RETAIL = pd.concat(frames4)
GDMS_RETAIL.shape
# Out:
# (3027, 27)

# %%
CTB_GDMS_RETAIL = pd.merge(CTB_data, GDMS_RETAIL, left_on=['ORDER_ID'],right_on = ['EQRY_REF_NO'], how = 'outer',indicator=True)
print(CTB_GDMS_RETAIL.shape)
CTB_GDMS_RETAIL['_merge'].value_counts()
# Out:
# (81206, 73)
# left_only     78179
# both           3016
# right_only       11
# Name: _merge, dtype: int64

# %%
CTB_GDMS_RETAIL = CTB_GDMS_RETAIL[CTB_GDMS_RETAIL["_merge"]!="left_only"]

# %%
CTB_GDMS_RETAIL.shape
# Out:
# (3027, 73)

# %%
GDMS_retail_raw = CTB_GDMS_RETAIL[(CTB_GDMS_RETAIL["RETAIL_DATE"].notna()) & (CTB_GDMS_RETAIL['EQRY_STAT']==45)]
print(GDMS_retail_raw.shape)
GDMS_retail_raw.head(2)
# Out:
# (2972, 73)
#    ASSIGNED_SALES_CONSULTANT  BALANCE_AMOUNT BOOKING  BOOKING_AMOUNT  \
# 31            Manish Kr. Ray       1096943.0       N             0.0
# 44              Ajit Sharma         960127.0       N             0.0
#
#    BOOKING_DATE       CITY CONSULTANT_ASSISGN_Y_N  \
# 31          NaT    Kolkata                      Y
# 44          NaT  Singrauli                      Y
#
#                      CUSTOMER_EMAIL  CUSTOMER_MOBILE  \
# 31    manoranjanprasad190@gmail.com     7.980744e+09
# 44  ramgyanivishwakarmaom@gmail.com     9.039185e+09
#
#                      CUSTOMER_NAME  ... RETAIL_DATE_NEWWeek  \
# 31          Manoranjan Prasad Sing  ...                 9.0
# 44  Ramgyani vishwakarma undefined  ...                 7.0
#
#    RETAIL_DATE_NEWDay RETAIL_DATE_NEWhour  RETAIL_DATE_NEWDayofweek  \
# 31                5.0                 0.0                       4.0
# 44               18.0                 0.0                       3.0
#
#    RETAIL_DATE_NEWDayofyear RETAIL_DATE_NEWweekofyear  \
# 31                     64.0                       9.0
# 44                     49.0                       7.0
#
#    RETAIL_DATE_NEWMonthName  RETAIL_DATE_NEWMonthKey RETAIL_DATE_NEWWeekKey  \
# 31                      Mar                   2021_3                 2021_9
# 44                      Feb                   2021_2                 2021_7
#
#    _merge
# 31   both
# 44   both
#
# [2 rows x 73 columns]

# %%
GDMS_Booking = GDMS_Booking_new.copy()
GDMS_retail = GDMS_retail_raw.copy()

# %%
GDMS_retail.columns
# Out:
# Index(['ASSIGNED_SALES_CONSULTANT', 'BALANCE_AMOUNT', 'BOOKING',
#        'BOOKING_AMOUNT', 'BOOKING_DATE', 'CITY', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_EMAIL', 'CUSTOMER_MOBILE', 'CUSTOMER_NAME', 'DEALER_CODE',
#        'DEALER_ID', 'DEALER_NAME', 'DEAL_CODE_VALUE', 'DELR_RGON_NAME',
#        'ENGINE', 'EXTERIOR_COLOR', 'FINAL_PURCHASE_AMOUNT', 'FINANCE',
#        'FINANCE_STATUS', 'INTERIOR_COLOR', 'INVC_CNFR_YN', 'LOAN_TYPE',
#        'MODEL', 'ORDER_DATE', 'ORDER_DATEDay', 'ORDER_DATEDayofweek',
#        'ORDER_DATEDayofyear', 'ORDER_DATEMonth', 'ORDER_DATEMonthKey',
#        'ORDER_DATEMonthName', 'ORDER_DATEWeek', 'ORDER_DATEWeekKey',
#        'ORDER_DATEYear', 'ORDER_DATEhour', 'ORDER_DATEweekofyear', 'ORDER_ID',
#        'ORDER_STAGE', 'ORDER_STATUS', 'PAY_AT_DELR_YN', 'REGION_CODE', 'STATE',
#        'TRADE', 'VARIANT', '_ORDER _ID', 'CSPM_DLR_NAME', 'EQRY_DLR_NO',
#        'EQRY_ENQRY_NO', 'EQRY_DATE', 'EQRY_STAT', 'EQRY_STATUS_NM',
#        'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME', 'EQRY_NEWCAR_YN', 'EQRY_REF_NO',
#        'CTB_BOOKING_Y', 'RETAIL_DATE', 'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE',
#        'RETAIL_DATE_NEW', 'RETAIL_DATE_NEWYear', 'RETAIL_DATE_NEWMonth',
#        'RETAIL_DATE_NEWWeek', 'RETAIL_DATE_NEWDay', 'RETAIL_DATE_NEWhour',
#        'RETAIL_DATE_NEWDayofweek', 'RETAIL_DATE_NEWDayofyear',
#        'RETAIL_DATE_NEWweekofyear', 'RETAIL_DATE_NEWMonthName',
#        'RETAIL_DATE_NEWMonthKey', 'RETAIL_DATE_NEWWeekKey', '_merge'],
#       dtype='object')

# %%
GDMS_retail.drop_duplicates(subset='EQRY_REF_NO', inplace=True)

# %%
GDMS_retail.RETAIL_DATE_NEWMonthKey.count()
# Out:
# 2972

# %%
GDMS_retail.to_excel("CTB_Retail_june_31.xlsx")

# %%
GDMS_Booking.to_excel("CTB_Booking_June.xlsx")

# %% [markdown]
# ### Monthly/Weekly/Hourly Analysis

# %%
#Monthly Enquiry trend
Monthly_trend_Enq = Trend_Analysis_gb(ctb_data_raw,['ORDER_ID','ORDER_DATEMonthKey'],'ORDER_DATEMonthKey','ORDER_DATEMonthKey','Monthly')
Monthly_trend_Enq.columns = ["ORDER_DATEMonthKey","Enquiry Count"]

# %%
#Monthly Booking trend
Monthly_trend_Booking = Trend_Analysis_pi(GDMS_Booking,['CTB_BOOKING_Y','BKNG_DATE_NEWMonthKey'],'CTB_BOOKING_Y','BKNG_DATE_NEWMonthKey','BKNG_DATE_NEWMonthKey','Monthly')
Monthly_trend_Booking.columns = ['BKNG_DATE_NEWMonthKey', 'CTB_BOOKING_N', 'CTB_BOOKING_Y']

#Monthly Retail trend
Monthly_trend_Retail = Trend_Analysis_gb(GDMS_retail,['EQRY_REF_NO','RETAIL_DATE_NEWMonthKey'],'RETAIL_DATE_NEWMonthKey','RETAIL_DATE_NEWMonthKey','Monthly')
Monthly_trend_Retail.columns = ["RETAIL_DATE_NEWMonthKey","Retail Count"]

# %%
Monthly_trend_Booking
# Out:
#    BKNG_DATE_NEWMonthKey  CTB_BOOKING_N  CTB_BOOKING_Y
# 0                 2020_1              1              0
# 1                2020_10            416            535
# 2                2020_11            403            361
# 3                2020_12            383            182
# 4                 2020_2              8              0
# 5                 2020_3             31              8
# 6                 2020_4              9             50
# 7                 2020_5             50             40
# 8                 2020_6            162             67
# 9                 2020_7            244             73
# 10                2020_8            275            101
# 11                2020_9            357            108
# 12                2021_1            326            191
# 13                2021_2            328            239
# 14                2021_3            352            253
# 15                2021_4            280            300
# 16                2021_5            181            192
# 17                2021_6            498            764

# %%
181 +192
# Out:
# 373

# %%
Monthly_trend_Retail
# Out:
#    RETAIL_DATE_NEWMonthKey  Retail Count
# 0                   2020_1             1
# 1                  2020_10           273
# 2                  2020_11           295
# 3                  2020_12           297
# 4                   2020_2             3
# 5                   2020_3             2
# 6                   2020_5            30
# 7                   2020_6           106
# 8                   2020_7           159
# 9                   2020_8           219
# 10                  2020_9           212
# 11                  2021_1           244
# 12                  2021_2           229
# 13                  2021_3           242
# 14                  2021_4           209
# 15                  2021_5           110
# 16                  2021_6           341

# %%
Monthly_trend_Enq
# Out:
#    ORDER_DATEMonthKey  Enquiry Count
# 0              2020_1            191
# 1             2020_10           8590
# 2             2020_11           6887
# 3             2020_12           6603
# 4              2020_2            350
# 5              2020_3            688
# 6              2020_4           4051
# 7              2020_5           2224
# 8              2020_6           5888
# 9              2020_7           4902
# 10             2020_8           4859
# 11             2020_9           6012
# 12             2021_1           5279
# 13             2021_2           4662
# 14             2021_3           4606
# 15             2021_4           3955
# 16             2021_5           4192
# 17             2021_6           7368

# %%
#Weekly Enquiry trend
Weekly_trend_Enq = Trend_Analysis_gb(CTB_data,['ORDER_ID','ORDER_DATEWeekKey'],'ORDER_DATEWeekKey','ORDER_DATEWeekKey','Weekly')
Weekly_trend_Enq.columns = ['ORDER_DATEWeekKey','Enquiry Count']

#Weekly Booking trend
Weekly_trend_Booking = Trend_Analysis_pi(GDMS_booking,['CTB_BOOKING_Y','BKNG_DATE_NEWWeekKey'],'CTB_BOOKING_Y','BKNG_DATE_NEWWeekKey','BKNG_DATE_NEWWeekKey','Weekly')
Weekly_trend_Booking.columns = ['BKNG_DATE_NEWWeekKey', 'CTB_BOOKING_N', 'CTB_BOOKING_Y']

#Weekly Retail trend
Weekly_trend_Retail = Trend_Analysis_gb(GDMS_retail,['EQRY_REF_NO','RETAIL_DATE_NEWWeekKey'],'RETAIL_DATE_NEWWeekKey','RETAIL_DATE_NEWWeekKey','Weekly')
Weekly_trend_Retail.columns = ["RETAIL_DATE_NEWWeekKey","Retail Count"]

# %%
#Hourly_trend_booking
Hourly_trend_Enq = Trend_Analysis_gb(CTB_data,['ORDER_ID','ORDER_DATEhour'],'ORDER_DATEhour','ORDER_DATEhour','Hourly')
Hourly_trend_Enq.columns = ['Range_name','Enquiry Count']

Hourly_trend_booking = Trend_Analysis_gb(CTB_booking_na,['ORDER_ID','BOOKING_DATEhour'],'BOOKING_DATEhour','BOOKING_DATEhour','Hourly')
Hourly_trend_booking.columns = ["Range_name","Booking Count"]

# %%
Weekly_trend_Enq
# Out:
#    ORDER_DATEWeekKey  Enquiry Count
# 0            2020_10            105
# 1            2020_11            101
# 2            2020_12            160
# 3            2020_13            255
# 4            2020_14            287
# 5            2020_15           1175
# 6            2020_16            697
# 7            2020_17           1534
# 8            2020_18            634
# 9            2020_19            452
# 10           2020_20            234
# 11           2020_21            460
# 12           2020_22            854
# 13           2020_23           1329
# 14           2020_24           1369
# 15           2020_25           1306
# 16           2020_26           1532
# 17           2020_27           1278
# 18           2020_28           1171
# 19           2020_29           1153
# 20            2020_3             61
# 21           2020_30           1029
# 22           2020_31            904
# 23           2020_32           1060
# 24           2020_33           1092
# 25           2020_34           1224
# 26           2020_35           1048
# 27           2020_36           1001
# 28           2020_37           1707
# 29           2020_38           1362
# ..               ...            ...
# 48            2020_7            118
# 49            2020_8             87
# 50            2020_9             89
# 51            2021_1           1309
# 52           2021_10           1143
# 53           2021_11           1011
# 54           2021_12            989
# 55           2021_13           1042
# 56           2021_14           1135
# 57           2021_15           1018
# 58           2021_16            759
# 59           2021_17            700
# 60           2021_18            831
# 61           2021_19            819
# 62            2021_2           1191
# 63           2021_20           1059
# 64           2021_21           1110
# 65           2021_22           1079
# 66           2021_23           2268
# 67           2021_24           2174
# 68           2021_25           1418
# 69           2021_26            608
# 70            2021_3           1154
# 71            2021_4           1077
# 72            2021_5           1070
# 73           2021_53            522
# 74            2021_6           1399
# 75            2021_7           1167
# 76            2021_8           1001
# 77            2021_9            914
#
# [78 rows x 2 columns]

# %%
Weekly_trend_Booking
# Out:
#    BKNG_DATE_NEWWeekKey  CTB_BOOKING_N  CTB_BOOKING_Y
# 0               2020_10              9              0
# 1               2020_11             10              2
# 2               2020_12              7              3
# 3               2020_13              5              3
# 4               2020_14              0              6
# 5               2020_15              2             11
# 6               2020_16              3              7
# 7               2020_17              1             16
# 8               2020_18              3             12
# 9               2020_19              9             17
# 10              2020_20              8              8
# 11              2020_21             20              4
# 12              2020_22             13              9
# 13              2020_23             28             20
# 14              2020_24             43             14
# 15              2020_25             37             10
# 16              2020_26             42             15
# 17              2020_27             35             16
# 18              2020_28             48             17
# 19              2020_29             57             21
# 20              2020_30             69             21
# 21              2020_31             61             11
# 22              2020_32             63             24
# 23              2020_33             50             23
# 24              2020_34             66             18
# 25              2020_35             70             25
# 26              2020_36             49             29
# 27              2020_37             76             23
# 28              2020_38             85             32
# 29              2020_39            103             26
# ..                  ...            ...            ...
# 35              2020_45             89            149
# 36              2020_46             91             60
# 37              2020_47             97             54
# 38              2020_48            110             35
# 39              2020_49             67             52
# 40               2020_5              1              0
# 41              2020_50             96             34
# 42              2020_51             96             33
# 43              2020_52             89             46
# 44              2020_53             48             32
# 45               2020_6              1              0
# 46               2020_7              2              0
# 47               2020_8              2              0
# 48               2020_9              3              0
# 49               2021_1             80             44
# 50              2021_10             86             44
# 51              2021_11             69             54
# 52              2021_12             99             85
# 53              2021_13             64             78
# 54              2021_14             89            100
# 55              2021_15             31             26
# 56               2021_2             65             51
# 57               2021_3             86             41
# 58               2021_4             88             34
# 59               2021_5             68             41
# 60              2021_53              7             21
# 61               2021_6             76             80
# 62               2021_7             68             62
# 63               2021_8            116             56
# 64               2021_9             63             28
#
# [65 rows x 3 columns]

# %%
Weekly_trend_Retail
# Out:
#    RETAIL_DATE_NEWWeekKey  Retail Count
# 0                 2020_12             2
# 1                 2020_19             2
# 2                 2020_20             5
# 3                 2020_21             9
# 4                 2020_22            14
# 5                 2020_23            16
# 6                 2020_24            21
# 7                 2020_25            34
# 8                 2020_26            24
# 9                 2020_27            24
# 10                2020_28            29
# 11                2020_29            25
# 12                2020_30            34
# 13                2020_31            61
# 14                2020_32            34
# 15                2020_33            48
# 16                2020_34            58
# 17                2020_35            63
# 18                2020_36            41
# 19                2020_37            22
# 20                2020_38            53
# 21                2020_39            63
# 22                2020_40            51
# 23                2020_41            38
# 24                2020_42            53
# 25                2020_43           111
# 26                2020_44            66
# 27                2020_45            24
# 28                2020_46            92
# 29                2020_47            70
# ..                    ...           ...
# 37                 2020_6             1
# 38                 2020_8             1
# 39                 2020_9             1
# 40                 2021_1            54
# 41                2021_10            49
# 42                2021_11            60
# 43                2021_12            72
# 44                2021_13            34
# 45                2021_14            35
# 46                2021_15            61
# 47                2021_16            51
# 48                2021_17            53
# 49                2021_18            17
# 50                2021_19            18
# 51                 2021_2            55
# 52                2021_20            25
# 53                2021_21            36
# 54                2021_22            37
# 55                2021_23            61
# 56                2021_24            87
# 57                2021_25            89
# 58                2021_26            81
# 59                 2021_3            70
# 60                 2021_4            60
# 61                 2021_5            49
# 62                2021_53             5
# 63                 2021_6            53
# 64                 2021_7            55
# 65                 2021_8            72
# 66                 2021_9            36
#
# [67 rows x 2 columns]

# %%
Hourly_trend_Enq
# Out:
#    Range_name  Enquiry Count
# 0         0-2           3070
# 1       10-12           9905
# 2       12-14          10124
# 3       14-16          10283
# 4       16-18           9198
# 5       18-20           9527
# 6         2-4           1170
# 7       20-22           9522
# 8       22-24           7520
# 9         4-6           1254
# 10        6-8           3402
# 11       8-10           6220

# %%
Hourly_trend_Enq['Enquiry Count'].sum()
# Out:
# 81195

# %%
Hourly_trend_booking['Booking Count'].sum()
# Out:
# 3469

# %%
Monthly_Trend_merg = Merge(Monthly_trend_Enq,'ORDER_DATEMonthKey',Monthly_trend_Booking,'BKNG_DATE_NEWMonthKey',Monthly_trend_Retail,'RETAIL_DATE_NEWMonthKey','outer',True,'double')
Monthly_Trend_merg[['Year','Month']] = Monthly_Trend_merg.ORDER_DATEMonthKey.str.split("_",expand=True)

Monthly_Trend_merg
# Out:
#    ORDER_DATEMonthKey  Enquiry Count BKNG_DATE_NEWMonthKey  CTB_BOOKING_N  \
# 0              2020_1            191                2020_1              1
# 1             2020_10           8590               2020_10            416
# 2             2020_11           6887               2020_11            403
# 3             2020_12           6603               2020_12            383
# 4              2020_2            350                2020_2              8
# 5              2020_3            688                2020_3             31
# 6              2020_4           4051                2020_4              9
# 7              2020_5           2224                2020_5             50
# 8              2020_6           5888                2020_6            162
# 9              2020_7           4902                2020_7            244
# 10             2020_8           4859                2020_8            275
# 11             2020_9           6012                2020_9            357
# 12             2021_1           5279                2021_1            326
# 13             2021_2           4662                2021_2            328
# 14             2021_3           4606                2021_3            352
# 15             2021_4           3955                2021_4            280
# 16             2021_5           4192                2021_5            181
# 17             2021_6           7368                2021_6            498
#
#     CTB_BOOKING_Y RETAIL_DATE_NEWMonthKey  Retail Count     _merge  Year Month
# 0               0                  2020_1           1.0       both  2020     1
# 1             535                 2020_10         273.0       both  2020    10
# 2             361                 2020_11         295.0       both  2020    11
# 3             182                 2020_12         297.0       both  2020    12
# 4               0                  2020_2           3.0       both  2020     2
# 5               8                  2020_3           2.0       both  2020     3
# 6              50                     NaN           NaN  left_only  2020     4
# 7              40                  2020_5          30.0       both  2020     5
# 8              67                  2020_6         106.0       both  2020     6
# 9              73                  2020_7         159.0       both  2020     7
# 10            101                  2020_8         219.0       both  2020     8
# 11            108                  2020_9         212.0       both  2020     9
# 12            191                  2021_1         244.0       both  2021     1
# 13            239                  2021_2         229.0       both  2021     2
# 14            253                  2021_3         242.0       both  2021     3
# 15            300                  2021_4         209.0       both  2021     4
# 16            192                  2021_5         110.0       both  2021     5
# 17            764                  2021_6         341.0       both  2021     6

# %%
Monthly_Trend = Monthly_Trend_merg[["ORDER_DATEMonthKey","Year","Month","Enquiry Count","CTB_BOOKING_Y","CTB_BOOKING_N","Retail Count"]]
Monthly_Trend
# Out:
#    ORDER_DATEMonthKey  Year Month  Enquiry Count  CTB_BOOKING_Y  \
# 0              2020_1  2020     1            191              0
# 1             2020_10  2020    10           8590            535
# 2             2020_11  2020    11           6887            361
# 3             2020_12  2020    12           6603            182
# 4              2020_2  2020     2            350              0
# 5              2020_3  2020     3            688              8
# 6              2020_4  2020     4           4051             50
# 7              2020_5  2020     5           2224             40
# 8              2020_6  2020     6           5888             67
# 9              2020_7  2020     7           4902             73
# 10             2020_8  2020     8           4859            101
# 11             2020_9  2020     9           6012            108
# 12             2021_1  2021     1           5279            191
# 13             2021_2  2021     2           4662            239
# 14             2021_3  2021     3           4606            253
# 15             2021_4  2021     4           3955            300
# 16             2021_5  2021     5           4192            192
# 17             2021_6  2021     6           7368            764
#
#     CTB_BOOKING_N  Retail Count
# 0               1           1.0
# 1             416         273.0
# 2             403         295.0
# 3             383         297.0
# 4               8           3.0
# 5              31           2.0
# 6               9           NaN
# 7              50          30.0
# 8             162         106.0
# 9             244         159.0
# 10            275         219.0
# 11            357         212.0
# 12            326         244.0
# 13            328         229.0
# 14            352         242.0
# 15            280         209.0
# 16            181         110.0
# 17            498         341.0

# %%
Monthly_Trend_final_added = Monthly_Trend.copy()
Monthly_Trend_final_added["CRM Booking"] = 0
Monthly_Trend_final_added["CRM Booking"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_4"), 114,Monthly_Trend_final_added["CRM Booking"])
Monthly_Trend_final_added["CRM Booking"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_5"), 156,Monthly_Trend_final_added["CRM Booking"])
Monthly_Trend_final_added["CRM Booking"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_6"), 122,Monthly_Trend_final_added["CRM Booking"])

Monthly_Trend_final_added["CRM Retail"] = 0
Monthly_Trend_final_added["CRM Retail"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_4"), 1,Monthly_Trend_final_added["CRM Retail"])
Monthly_Trend_final_added["CRM Retail"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_5"), 66,Monthly_Trend_final_added["CRM Retail"])
Monthly_Trend_final_added["CRM Retail"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_6"), 112,Monthly_Trend_final_added["CRM Retail"])


Monthly_Trend_final_added["Financial_enquiry"] = 0
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_12"),2712,Monthly_Trend_final_added["Financial_enquiry"])
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_1"), 727,Monthly_Trend_final_added["Financial_enquiry"])
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_2"), 1346,Monthly_Trend_final_added["Financial_enquiry"])
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_3"), 1441,Monthly_Trend_final_added["Financial_enquiry"])
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_4"), 1966,Monthly_Trend_final_added["Financial_enquiry"])
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_5"), 610,Monthly_Trend_final_added["Financial_enquiry"])
Monthly_Trend_final_added["Financial_enquiry"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_6"), 1077,Monthly_Trend_final_added["Financial_enquiry"])


Monthly_Trend_final_added["Visitors"] = 0
Monthly_Trend_final_added["Visitors"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_4"),634892,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_5"),43962 ,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_6"), 739592,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_7"), 1743236,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_8"), 281136,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_9"), 525295,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_10"), 966755,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_11"), 953487,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2020_12"), 1152471,Monthly_Trend_final_added["Visitors"])

Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_1"), 794194,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_2"), 704709,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_3"), 1101148,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_4"), 894081,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_5"), 1730711,Monthly_Trend_final_added["Visitors"])
Monthly_Trend_final_added["Visitors"] = np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"] =="2021_6"), 2630538,Monthly_Trend_final_added["Visitors"])


Monthly_Trend_final_added["CTB Registration"] = 0
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_1"),120,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_2"),276,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_3"),664,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_4"),4487,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_5"),1657,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_6"),5127,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_7"),5004,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_8"),4012,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_9"),5694,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_10"),8000,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_11"),5874,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2020_12"),6236,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2021_1"),4057,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2021_2"),3835,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2021_3"),4403,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2021_4"),3768,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2021_5"),3074,Monthly_Trend_final_added["CTB Registration"])
Monthly_Trend_final_added["CTB Registration"]=np.where((Monthly_Trend_final_added["ORDER_DATEMonthKey"]=="2021_6"),5292,Monthly_Trend_final_added["CTB Registration"])





Monthly_Trend_final_added["Online Booking"] = Monthly_Trend_final_added["CTB_BOOKING_Y"]+Monthly_Trend_final_added["CRM Booking"]
Monthly_Trend_final_added["Total CTB Booking"] = Monthly_Trend_final_added["CTB_BOOKING_Y"]+Monthly_Trend_final_added["CTB_BOOKING_N"]
#Monthly_Trend_final_added["Offline Booking"] =Monthly_Trend_final_added["Total CTB Booking"] - Monthly_Trend_final_added["CTB_BOOKING_Y"]
Monthly_Trend_final_added["Total Booking"] = Monthly_Trend_final_added["CTB_BOOKING_N"]+ Monthly_Trend_final_added["CTB_BOOKING_Y"]+Monthly_Trend_final_added["CRM Booking"]
Monthly_Trend_final_added["Total Retail"] = Monthly_Trend_final_added["Retail Count"]+ Monthly_Trend_final_added["CRM Retail"]
Monthly_Trend_final_added["Total Enquiry"] = Monthly_Trend_final_added["Enquiry Count"]+Monthly_Trend_final_added["Financial_enquiry"]
Monthly_Trend_final_added.fillna(0,inplace=True)
Monthly_Trend_final_added["Retail Conversion Ratio"] = (Monthly_Trend_final_added["Total Retail"]/Monthly_Trend_final_added["Enquiry Count"])


Monthly_Trend_final_added
#np.where((CTB_Registrations['Month_Name'] == 'Apr') & (CTB_Registrations['year'] == 2020 ) , 4487,CTB_Registrations['Registration_Count'] )
# Out:
#    ORDER_DATEMonthKey  Year Month  Enquiry Count  CTB_BOOKING_Y  \
# 0              2020_1  2020     1            191              0
# 1             2020_10  2020    10           8590            535
# 2             2020_11  2020    11           6887            361
# 3             2020_12  2020    12           6603            182
# 4              2020_2  2020     2            350              0
# 5              2020_3  2020     3            688              8
# 6              2020_4  2020     4           4051             50
# 7              2020_5  2020     5           2224             40
# 8              2020_6  2020     6           5888             67
# 9              2020_7  2020     7           4902             73
# 10             2020_8  2020     8           4859            101
# 11             2020_9  2020     9           6012            108
# 12             2021_1  2021     1           5279            191
# 13             2021_2  2021     2           4662            239
# 14             2021_3  2021     3           4606            253
# 15             2021_4  2021     4           3955            300
# 16             2021_5  2021     5           4192            192
# 17             2021_6  2021     6           7368            764
#
#     CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 0               1           1.0            0           0                  0
# 1             416         273.0            0           0                  0
# 2             403         295.0            0           0                  0
# 3             383         297.0            0           0               2712
# 4               8           3.0            0           0                  0
# 5              31           2.0            0           0                  0
# 6               9           0.0          114           1                  0
# 7              50          30.0          156          66                  0
# 8             162         106.0          122         112                  0
# 9             244         159.0            0           0                  0
# 10            275         219.0            0           0                  0
# 11            357         212.0            0           0                  0
# 12            326         244.0            0           0                727
# 13            328         229.0            0           0               1346
# 14            352         242.0            0           0               1441
# 15            280         209.0            0           0               1966
# 16            181         110.0            0           0                610
# 17            498         341.0            0           0               1077
#
#     Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 0          0               120               0                  1
# 1     966755              8000             535                951
# 2     953487              5874             361                764
# 3    1152471              6236             182                565
# 4          0               276               0                  8
# 5          0               664               8                 39
# 6     634892              4487             164                 59
# 7      43962              1657             196                 90
# 8     739592              5127             189                229
# 9    1743236              5004              73                317
# 10    281136              4012             101                376
# 11    525295              5694             108                465
# 12    794194              4057             191                517
# 13    704709              3835             239                567
# 14   1101148              4403             253                605
# 15    894081              3768             300                580
# 16   1730711              3074             192                373
# 17   2630538              5292             764               1262
#
#     Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 0               1           1.0            191                 0.005236
# 1             951         273.0           8590                 0.031781
# 2             764         295.0           6887                 0.042834
# 3             565         297.0           9315                 0.044980
# 4               8           3.0            350                 0.008571
# 5              39           2.0            688                 0.002907
# 6             173           0.0           4051                 0.000000
# 7             246          96.0           2224                 0.043165
# 8             351         218.0           5888                 0.037024
# 9             317         159.0           4902                 0.032436
# 10            376         219.0           4859                 0.045071
# 11            465         212.0           6012                 0.035263
# 12            517         244.0           6006                 0.046221
# 13            567         229.0           6008                 0.049121
# 14            605         242.0           6047                 0.052540
# 15            580         209.0           5921                 0.052845
# 16            373         110.0           4802                 0.026240
# 17           1262         341.0           8445                 0.046281

# %%
from natsort import natsorted
from natsort import natsorted, index_natsorted, order_by_index

#df2=natsorted(df2,df2['ORDER_DATEWeekKey'],)
Monthly_Trend_final_added = Monthly_Trend_final_added.reindex(index=order_by_index(Monthly_Trend_final_added.index, index_natsorted(Monthly_Trend_final_added.ORDER_DATEMonthKey)))

# %%
Monthly_Trend_final_added
# Out:
#    ORDER_DATEMonthKey  Year Month  Enquiry Count  CTB_BOOKING_Y  \
# 0              2020_1  2020     1            191              0
# 4              2020_2  2020     2            350              0
# 5              2020_3  2020     3            688              8
# 6              2020_4  2020     4           4051             50
# 7              2020_5  2020     5           2224             40
# 8              2020_6  2020     6           5888             67
# 9              2020_7  2020     7           4902             73
# 10             2020_8  2020     8           4859            101
# 11             2020_9  2020     9           6012            108
# 1             2020_10  2020    10           8590            535
# 2             2020_11  2020    11           6887            361
# 3             2020_12  2020    12           6603            182
# 12             2021_1  2021     1           5279            191
# 13             2021_2  2021     2           4662            239
# 14             2021_3  2021     3           4606            253
# 15             2021_4  2021     4           3955            300
# 16             2021_5  2021     5           4192            192
# 17             2021_6  2021     6           7368            764
#
#     CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 0               1           1.0            0           0                  0
# 4               8           3.0            0           0                  0
# 5              31           2.0            0           0                  0
# 6               9           0.0          114           1                  0
# 7              50          30.0          156          66                  0
# 8             162         106.0          122         112                  0
# 9             244         159.0            0           0                  0
# 10            275         219.0            0           0                  0
# 11            357         212.0            0           0                  0
# 1             416         273.0            0           0                  0
# 2             403         295.0            0           0                  0
# 3             383         297.0            0           0               2712
# 12            326         244.0            0           0                727
# 13            328         229.0            0           0               1346
# 14            352         242.0            0           0               1441
# 15            280         209.0            0           0               1966
# 16            181         110.0            0           0                610
# 17            498         341.0            0           0               1077
#
#     Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 0          0               120               0                  1
# 4          0               276               0                  8
# 5          0               664               8                 39
# 6     634892              4487             164                 59
# 7      43962              1657             196                 90
# 8     739592              5127             189                229
# 9    1743236              5004              73                317
# 10    281136              4012             101                376
# 11    525295              5694             108                465
# 1     966755              8000             535                951
# 2     953487              5874             361                764
# 3    1152471              6236             182                565
# 12    794194              4057             191                517
# 13    704709              3835             239                567
# 14   1101148              4403             253                605
# 15    894081              3768             300                580
# 16   1730711              3074             192                373
# 17   2630538              5292             764               1262
#
#     Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 0               1           1.0            191                 0.005236
# 4               8           3.0            350                 0.008571
# 5              39           2.0            688                 0.002907
# 6             173           0.0           4051                 0.000000
# 7             246          96.0           2224                 0.043165
# 8             351         218.0           5888                 0.037024
# 9             317         159.0           4902                 0.032436
# 10            376         219.0           4859                 0.045071
# 11            465         212.0           6012                 0.035263
# 1             951         273.0           8590                 0.031781
# 2             764         295.0           6887                 0.042834
# 3             565         297.0           9315                 0.044980
# 12            517         244.0           6006                 0.046221
# 13            567         229.0           6008                 0.049121
# 14            605         242.0           6047                 0.052540
# 15            580         209.0           5921                 0.052845
# 16            373         110.0           4802                 0.026240
# 17           1262         341.0           8445                 0.046281

# %%
Monthly_Trend_final_added.to_excel("CTB_monthly_stats_June21.xlsx")

# %%
monthlist = ["ORDER_DATEMonthKey","Year","Month","Enquiry Count","CTB_BOOKING_Y","CTB_BOOKING_N","Total CTB Booking","CRM Booking","Online Booking","Financial_enquiry","Total Booking","CRM Retail","Total Retail","Total Enquiry","Retail Conversion Ratio"]
Monthly_Trend_final = Monthly_Trend_final_added[monthlist]
Monthly_Trend_final
# Out:
#    ORDER_DATEMonthKey  Year Month  Enquiry Count  CTB_BOOKING_Y  \
# 0              2020_1  2020     1            191              0
# 4              2020_2  2020     2            350              0
# 5              2020_3  2020     3            688              8
# 6              2020_4  2020     4           4051             50
# 7              2020_5  2020     5           2224             40
# 8              2020_6  2020     6           5888             67
# 9              2020_7  2020     7           4902             73
# 10             2020_8  2020     8           4859            101
# 11             2020_9  2020     9           6012            108
# 1             2020_10  2020    10           8590            535
# 2             2020_11  2020    11           6887            361
# 3             2020_12  2020    12           6603            182
# 12             2021_1  2021     1           5279            191
# 13             2021_2  2021     2           4662            239
# 14             2021_3  2021     3           4606            253
# 15             2021_4  2021     4           3955            300
# 16             2021_5  2021     5           4192            192
# 17             2021_6  2021     6           7368            764
#
#     CTB_BOOKING_N  Total CTB Booking  CRM Booking  Online Booking  \
# 0               1                  1            0               0
# 4               8                  8            0               0
# 5              31                 39            0               8
# 6               9                 59          114             164
# 7              50                 90          156             196
# 8             162                229          122             189
# 9             244                317            0              73
# 10            275                376            0             101
# 11            357                465            0             108
# 1             416                951            0             535
# 2             403                764            0             361
# 3             383                565            0             182
# 12            326                517            0             191
# 13            328                567            0             239
# 14            352                605            0             253
# 15            280                580            0             300
# 16            181                373            0             192
# 17            498               1262            0             764
#
#     Financial_enquiry  Total Booking  CRM Retail  Total Retail  Total Enquiry  \
# 0                   0              1           0           1.0            191
# 4                   0              8           0           3.0            350
# 5                   0             39           0           2.0            688
# 6                   0            173           1           0.0           4051
# 7                   0            246          66          96.0           2224
# 8                   0            351         112         218.0           5888
# 9                   0            317           0         159.0           4902
# 10                  0            376           0         219.0           4859
# 11                  0            465           0         212.0           6012
# 1                   0            951           0         273.0           8590
# 2                   0            764           0         295.0           6887
# 3                2712            565           0         297.0           9315
# 12                727            517           0         244.0           6006
# 13               1346            567           0         229.0           6008
# 14               1441            605           0         242.0           6047
# 15               1966            580           0         209.0           5921
# 16                610            373           0         110.0           4802
# 17               1077           1262           0         341.0           8445
#
#     Retail Conversion Ratio
# 0                  0.005236
# 4                  0.008571
# 5                  0.002907
# 6                  0.000000
# 7                  0.043165
# 8                  0.037024
# 9                  0.032436
# 10                 0.045071
# 11                 0.035263
# 1                  0.031781
# 2                  0.042834
# 3                  0.044980
# 12                 0.046221
# 13                 0.049121
# 14                 0.052540
# 15                 0.052845
# 16                 0.026240
# 17                 0.046281

# %%
Monthly_Trend_final['Total Retail'].sum()
# Out:
# 3150.0

# %%
Weekly_Trend_final = Merge(Weekly_trend_Enq,'ORDER_DATEWeekKey',Weekly_trend_Booking,'BKNG_DATE_NEWWeekKey',Weekly_trend_Retail,'RETAIL_DATE_NEWWeekKey','outer',True,'double')
Weekly_Trend_final
# Out:
#    ORDER_DATEWeekKey  Enquiry Count BKNG_DATE_NEWWeekKey  CTB_BOOKING_N  \
# 0            2020_10            105              2020_10            9.0
# 1            2020_11            101              2020_11           10.0
# 2            2020_12            160              2020_12            7.0
# 3            2020_13            255              2020_13            5.0
# 4            2020_14            287              2020_14            0.0
# 5            2020_15           1175              2020_15            2.0
# 6            2020_16            697              2020_16            3.0
# 7            2020_17           1534              2020_17            1.0
# 8            2020_18            634              2020_18            3.0
# 9            2020_19            452              2020_19            9.0
# 10           2020_20            234              2020_20            8.0
# 11           2020_21            460              2020_21           20.0
# 12           2020_22            854              2020_22           13.0
# 13           2020_23           1329              2020_23           28.0
# 14           2020_24           1369              2020_24           43.0
# 15           2020_25           1306              2020_25           37.0
# 16           2020_26           1532              2020_26           42.0
# 17           2020_27           1278              2020_27           35.0
# 18           2020_28           1171              2020_28           48.0
# 19           2020_29           1153              2020_29           57.0
# 20            2020_3             61                  NaN            NaN
# 21           2020_30           1029              2020_30           69.0
# 22           2020_31            904              2020_31           61.0
# 23           2020_32           1060              2020_32           63.0
# 24           2020_33           1092              2020_33           50.0
# 25           2020_34           1224              2020_34           66.0
# 26           2020_35           1048              2020_35           70.0
# 27           2020_36           1001              2020_36           49.0
# 28           2020_37           1707              2020_37           76.0
# 29           2020_38           1362              2020_38           85.0
# ..               ...            ...                  ...            ...
# 48            2020_7            118               2020_7            2.0
# 49            2020_8             87               2020_8            2.0
# 50            2020_9             89               2020_9            3.0
# 51            2021_1           1309               2021_1           80.0
# 52           2021_10           1143              2021_10           86.0
# 53           2021_11           1011              2021_11           69.0
# 54           2021_12            989              2021_12           99.0
# 55           2021_13           1042              2021_13           64.0
# 56           2021_14           1135              2021_14           89.0
# 57           2021_15           1018              2021_15           31.0
# 58           2021_16            759                  NaN            NaN
# 59           2021_17            700                  NaN            NaN
# 60           2021_18            831                  NaN            NaN
# 61           2021_19            819                  NaN            NaN
# 62            2021_2           1191               2021_2           65.0
# 63           2021_20           1059                  NaN            NaN
# 64           2021_21           1110                  NaN            NaN
# 65           2021_22           1079                  NaN            NaN
# 66           2021_23           2268                  NaN            NaN
# 67           2021_24           2174                  NaN            NaN
# 68           2021_25           1418                  NaN            NaN
# 69           2021_26            608                  NaN            NaN
# 70            2021_3           1154               2021_3           86.0
# 71            2021_4           1077               2021_4           88.0
# 72            2021_5           1070               2021_5           68.0
# 73           2021_53            522              2021_53            7.0
# 74            2021_6           1399               2021_6           76.0
# 75            2021_7           1167               2021_7           68.0
# 76            2021_8           1001               2021_8          116.0
# 77            2021_9            914               2021_9           63.0
#
#     CTB_BOOKING_Y RETAIL_DATE_NEWWeekKey  Retail Count     _merge
# 0             0.0                    NaN           NaN  left_only
# 1             2.0                    NaN           NaN  left_only
# 2             3.0                2020_12           2.0       both
# 3             3.0                    NaN           NaN  left_only
# 4             6.0                    NaN           NaN  left_only
# 5            11.0                    NaN           NaN  left_only
# 6             7.0                    NaN           NaN  left_only
# 7            16.0                    NaN           NaN  left_only
# 8            12.0                    NaN           NaN  left_only
# 9            17.0                2020_19           2.0       both
# 10            8.0                2020_20           5.0       both
# 11            4.0                2020_21           9.0       both
# 12            9.0                2020_22          14.0       both
# 13           20.0                2020_23          16.0       both
# 14           14.0                2020_24          21.0       both
# 15           10.0                2020_25          34.0       both
# 16           15.0                2020_26          24.0       both
# 17           16.0                2020_27          24.0       both
# 18           17.0                2020_28          29.0       both
# 19           21.0                2020_29          25.0       both
# 20            NaN                    NaN           NaN  left_only
# 21           21.0                2020_30          34.0       both
# 22           11.0                2020_31          61.0       both
# 23           24.0                2020_32          34.0       both
# 24           23.0                2020_33          48.0       both
# 25           18.0                2020_34          58.0       both
# 26           25.0                2020_35          63.0       both
# 27           29.0                2020_36          41.0       both
# 28           23.0                2020_37          22.0       both
# 29           32.0                2020_38          53.0       both
# ..            ...                    ...           ...        ...
# 48            0.0                    NaN           NaN  left_only
# 49            0.0                 2020_8           1.0       both
# 50            0.0                 2020_9           1.0       both
# 51           44.0                 2021_1          54.0       both
# 52           44.0                2021_10          49.0       both
# 53           54.0                2021_11          60.0       both
# 54           85.0                2021_12          72.0       both
# 55           78.0                2021_13          34.0       both
# 56          100.0                2021_14          35.0       both
# 57           26.0                2021_15          61.0       both
# 58            NaN                2021_16          51.0       both
# 59            NaN                2021_17          53.0       both
# 60            NaN                2021_18          17.0       both
# 61            NaN                2021_19          18.0       both
# 62           51.0                 2021_2          55.0       both
# 63            NaN                2021_20          25.0       both
# 64            NaN                2021_21          36.0       both
# 65            NaN                2021_22          37.0       both
# 66            NaN                2021_23          61.0       both
# 67            NaN                2021_24          87.0       both
# 68            NaN                2021_25          89.0       both
# 69            NaN                2021_26          81.0       both
# 70           41.0                 2021_3          70.0       both
# 71           34.0                 2021_4          60.0       both
# 72           41.0                 2021_5          49.0       both
# 73           21.0                2021_53           5.0       both
# 74           80.0                 2021_6          53.0       both
# 75           62.0                 2021_7          55.0       both
# 76           56.0                 2021_8          72.0       both
# 77           28.0                 2021_9          36.0       both
#
# [78 rows x 8 columns]

# %%
Weekly_Trend_final = Weekly_Trend_final[["ORDER_DATEWeekKey","Enquiry Count","CTB_BOOKING_Y","CTB_BOOKING_N","Retail Count"]]
Weekly_Trend_final
# Out:
#    ORDER_DATEWeekKey  Enquiry Count  CTB_BOOKING_Y  CTB_BOOKING_N  \
# 0            2020_10            105            0.0            9.0
# 1            2020_11            101            2.0           10.0
# 2            2020_12            160            3.0            7.0
# 3            2020_13            255            3.0            5.0
# 4            2020_14            287            6.0            0.0
# 5            2020_15           1175           11.0            2.0
# 6            2020_16            697            7.0            3.0
# 7            2020_17           1534           16.0            1.0
# 8            2020_18            634           12.0            3.0
# 9            2020_19            452           17.0            9.0
# 10           2020_20            234            8.0            8.0
# 11           2020_21            460            4.0           20.0
# 12           2020_22            854            9.0           13.0
# 13           2020_23           1329           20.0           28.0
# 14           2020_24           1369           14.0           43.0
# 15           2020_25           1306           10.0           37.0
# 16           2020_26           1532           15.0           42.0
# 17           2020_27           1278           16.0           35.0
# 18           2020_28           1171           17.0           48.0
# 19           2020_29           1153           21.0           57.0
# 20            2020_3             61            NaN            NaN
# 21           2020_30           1029           21.0           69.0
# 22           2020_31            904           11.0           61.0
# 23           2020_32           1060           24.0           63.0
# 24           2020_33           1092           23.0           50.0
# 25           2020_34           1224           18.0           66.0
# 26           2020_35           1048           25.0           70.0
# 27           2020_36           1001           29.0           49.0
# 28           2020_37           1707           23.0           76.0
# 29           2020_38           1362           32.0           85.0
# ..               ...            ...            ...            ...
# 48            2020_7            118            0.0            2.0
# 49            2020_8             87            0.0            2.0
# 50            2020_9             89            0.0            3.0
# 51            2021_1           1309           44.0           80.0
# 52           2021_10           1143           44.0           86.0
# 53           2021_11           1011           54.0           69.0
# 54           2021_12            989           85.0           99.0
# 55           2021_13           1042           78.0           64.0
# 56           2021_14           1135          100.0           89.0
# 57           2021_15           1018           26.0           31.0
# 58           2021_16            759            NaN            NaN
# 59           2021_17            700            NaN            NaN
# 60           2021_18            831            NaN            NaN
# 61           2021_19            819            NaN            NaN
# 62            2021_2           1191           51.0           65.0
# 63           2021_20           1059            NaN            NaN
# 64           2021_21           1110            NaN            NaN
# 65           2021_22           1079            NaN            NaN
# 66           2021_23           2268            NaN            NaN
# 67           2021_24           2174            NaN            NaN
# 68           2021_25           1418            NaN            NaN
# 69           2021_26            608            NaN            NaN
# 70            2021_3           1154           41.0           86.0
# 71            2021_4           1077           34.0           88.0
# 72            2021_5           1070           41.0           68.0
# 73           2021_53            522           21.0            7.0
# 74            2021_6           1399           80.0           76.0
# 75            2021_7           1167           62.0           68.0
# 76            2021_8           1001           56.0          116.0
# 77            2021_9            914           28.0           63.0
#
#     Retail Count
# 0            NaN
# 1            NaN
# 2            2.0
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            2.0
# 10           5.0
# 11           9.0
# 12          14.0
# 13          16.0
# 14          21.0
# 15          34.0
# 16          24.0
# 17          24.0
# 18          29.0
# 19          25.0
# 20           NaN
# 21          34.0
# 22          61.0
# 23          34.0
# 24          48.0
# 25          58.0
# 26          63.0
# 27          41.0
# 28          22.0
# 29          53.0
# ..           ...
# 48           NaN
# 49           1.0
# 50           1.0
# 51          54.0
# 52          49.0
# 53          60.0
# 54          72.0
# 55          34.0
# 56          35.0
# 57          61.0
# 58          51.0
# 59          53.0
# 60          17.0
# 61          18.0
# 62          55.0
# 63          25.0
# 64          36.0
# 65          37.0
# 66          61.0
# 67          87.0
# 68          89.0
# 69          81.0
# 70          70.0
# 71          60.0
# 72          49.0
# 73           5.0
# 74          53.0
# 75          55.0
# 76          72.0
# 77          36.0
#
# [78 rows x 5 columns]

# %%
Weekly_Trend_final1 = Weekly_Trend_final.copy()
Weekly_Trend_final1["CRM Booking"] = 0
Weekly_Trend_final1["CRM Retail"] = 0
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_14"), 22,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_15"), 23,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_16"), 23,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_17"), 23,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_18"), 23,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_19"), 39,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_20"), 39,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_21"), 39,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_22"), 39,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_23"), 30,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_24"), 30,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_25"), 30,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_26"), 30,Weekly_Trend_final1["CRM Booking"])
Weekly_Trend_final1["CRM Booking"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_27"), 2,Weekly_Trend_final1["CRM Booking"])

Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_16"), 1,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_19"), 16,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_20"), 17,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_21"), 17,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_22"), 16,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_23"), 26,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_24"), 26,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_25"), 26,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_26"), 26,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1["CRM Retail"] = np.where((Weekly_Trend_final1["ORDER_DATEWeekKey"] =="2020_27"), 8,Weekly_Trend_final1["CRM Retail"])
Weekly_Trend_final1.fillna(0, inplace = True)
Weekly_Trend_final1["Total Booking"] = Weekly_Trend_final1["CTB_BOOKING_N"]+ Weekly_Trend_final1["CTB_BOOKING_Y"]+Weekly_Trend_final1["CRM Booking"]
Weekly_Trend_final1["Total Retail"] = Weekly_Trend_final1["Retail Count"]+ Weekly_Trend_final1["CRM Retail"]
Weekly_Trend_final1["Retail Conversion Ratio"] = (Weekly_Trend_final1["Total Retail"]/Weekly_Trend_final1["Enquiry Count"])

Weekly_Trend_final1
# Out:
#    ORDER_DATEWeekKey  Enquiry Count  CTB_BOOKING_Y  CTB_BOOKING_N  \
# 0            2020_10            105            0.0            9.0
# 1            2020_11            101            2.0           10.0
# 2            2020_12            160            3.0            7.0
# 3            2020_13            255            3.0            5.0
# 4            2020_14            287            6.0            0.0
# 5            2020_15           1175           11.0            2.0
# 6            2020_16            697            7.0            3.0
# 7            2020_17           1534           16.0            1.0
# 8            2020_18            634           12.0            3.0
# 9            2020_19            452           17.0            9.0
# 10           2020_20            234            8.0            8.0
# 11           2020_21            460            4.0           20.0
# 12           2020_22            854            9.0           13.0
# 13           2020_23           1329           20.0           28.0
# 14           2020_24           1369           14.0           43.0
# 15           2020_25           1306           10.0           37.0
# 16           2020_26           1532           15.0           42.0
# 17           2020_27           1278           16.0           35.0
# 18           2020_28           1171           17.0           48.0
# 19           2020_29           1153           21.0           57.0
# 20            2020_3             61            0.0            0.0
# 21           2020_30           1029           21.0           69.0
# 22           2020_31            904           11.0           61.0
# 23           2020_32           1060           24.0           63.0
# 24           2020_33           1092           23.0           50.0
# 25           2020_34           1224           18.0           66.0
# 26           2020_35           1048           25.0           70.0
# 27           2020_36           1001           29.0           49.0
# 28           2020_37           1707           23.0           76.0
# 29           2020_38           1362           32.0           85.0
# ..               ...            ...            ...            ...
# 48            2020_7            118            0.0            2.0
# 49            2020_8             87            0.0            2.0
# 50            2020_9             89            0.0            3.0
# 51            2021_1           1309           44.0           80.0
# 52           2021_10           1143           44.0           86.0
# 53           2021_11           1011           54.0           69.0
# 54           2021_12            989           85.0           99.0
# 55           2021_13           1042           78.0           64.0
# 56           2021_14           1135          100.0           89.0
# 57           2021_15           1018           26.0           31.0
# 58           2021_16            759            0.0            0.0
# 59           2021_17            700            0.0            0.0
# 60           2021_18            831            0.0            0.0
# 61           2021_19            819            0.0            0.0
# 62            2021_2           1191           51.0           65.0
# 63           2021_20           1059            0.0            0.0
# 64           2021_21           1110            0.0            0.0
# 65           2021_22           1079            0.0            0.0
# 66           2021_23           2268            0.0            0.0
# 67           2021_24           2174            0.0            0.0
# 68           2021_25           1418            0.0            0.0
# 69           2021_26            608            0.0            0.0
# 70            2021_3           1154           41.0           86.0
# 71            2021_4           1077           34.0           88.0
# 72            2021_5           1070           41.0           68.0
# 73           2021_53            522           21.0            7.0
# 74            2021_6           1399           80.0           76.0
# 75            2021_7           1167           62.0           68.0
# 76            2021_8           1001           56.0          116.0
# 77            2021_9            914           28.0           63.0
#
#     Retail Count  CRM Booking  CRM Retail  Total Booking  Total Retail  \
# 0            0.0            0           0            9.0           0.0
# 1            0.0            0           0           12.0           0.0
# 2            2.0            0           0           10.0           2.0
# 3            0.0            0           0            8.0           0.0
# 4            0.0           22           0           28.0           0.0
# 5            0.0           23           0           36.0           0.0
# 6            0.0           23           1           33.0           1.0
# 7            0.0           23           0           40.0           0.0
# 8            0.0           23           0           38.0           0.0
# 9            2.0           39          16           65.0          18.0
# 10           5.0           39          17           55.0          22.0
# 11           9.0           39          17           63.0          26.0
# 12          14.0           39          16           61.0          30.0
# 13          16.0           30          26           78.0          42.0
# 14          21.0           30          26           87.0          47.0
# 15          34.0           30          26           77.0          60.0
# 16          24.0           30          26           87.0          50.0
# 17          24.0            2           8           53.0          32.0
# 18          29.0            0           0           65.0          29.0
# 19          25.0            0           0           78.0          25.0
# 20           0.0            0           0            0.0           0.0
# 21          34.0            0           0           90.0          34.0
# 22          61.0            0           0           72.0          61.0
# 23          34.0            0           0           87.0          34.0
# 24          48.0            0           0           73.0          48.0
# 25          58.0            0           0           84.0          58.0
# 26          63.0            0           0           95.0          63.0
# 27          41.0            0           0           78.0          41.0
# 28          22.0            0           0           99.0          22.0
# 29          53.0            0           0          117.0          53.0
# ..           ...          ...         ...            ...           ...
# 48           0.0            0           0            2.0           0.0
# 49           1.0            0           0            2.0           1.0
# 50           1.0            0           0            3.0           1.0
# 51          54.0            0           0          124.0          54.0
# 52          49.0            0           0          130.0          49.0
# 53          60.0            0           0          123.0          60.0
# 54          72.0            0           0          184.0          72.0
# 55          34.0            0           0          142.0          34.0
# 56          35.0            0           0          189.0          35.0
# 57          61.0            0           0           57.0          61.0
# 58          51.0            0           0            0.0          51.0
# 59          53.0            0           0            0.0          53.0
# 60          17.0            0           0            0.0          17.0
# 61          18.0            0           0            0.0          18.0
# 62          55.0            0           0          116.0          55.0
# 63          25.0            0           0            0.0          25.0
# 64          36.0            0           0            0.0          36.0
# 65          37.0            0           0            0.0          37.0
# 66          61.0            0           0            0.0          61.0
# 67          87.0            0           0            0.0          87.0
# 68          89.0            0           0            0.0          89.0
# 69          81.0            0           0            0.0          81.0
# 70          70.0            0           0          127.0          70.0
# 71          60.0            0           0          122.0          60.0
# 72          49.0            0           0          109.0          49.0
# 73           5.0            0           0           28.0           5.0
# 74          53.0            0           0          156.0          53.0
# 75          55.0            0           0          130.0          55.0
# 76          72.0            0           0          172.0          72.0
# 77          36.0            0           0           91.0          36.0
#
#     Retail Conversion Ratio
# 0                  0.000000
# 1                  0.000000
# 2                  0.012500
# 3                  0.000000
# 4                  0.000000
# 5                  0.000000
# 6                  0.001435
# 7                  0.000000
# 8                  0.000000
# 9                  0.039823
# 10                 0.094017
# 11                 0.056522
# 12                 0.035129
# 13                 0.031603
# 14                 0.034332
# 15                 0.045942
# 16                 0.032637
# 17                 0.025039
# 18                 0.024765
# 19                 0.021683
# 20                 0.000000
# 21                 0.033042
# 22                 0.067478
# 23                 0.032075
# 24                 0.043956
# 25                 0.047386
# 26                 0.060115
# 27                 0.040959
# 28                 0.012888
# 29                 0.038913
# ..                      ...
# 48                 0.000000
# 49                 0.011494
# 50                 0.011236
# 51                 0.041253
# 52                 0.042870
# 53                 0.059347
# 54                 0.072801
# 55                 0.032630
# 56                 0.030837
# 57                 0.059921
# 58                 0.067194
# 59                 0.075714
# 60                 0.020457
# 61                 0.021978
# 62                 0.046180
# 63                 0.023607
# 64                 0.032432
# 65                 0.034291
# 66                 0.026896
# 67                 0.040018
# 68                 0.062764
# 69                 0.133224
# 70                 0.060659
# 71                 0.055710
# 72                 0.045794
# 73                 0.009579
# 74                 0.037884
# 75                 0.047129
# 76                 0.071928
# 77                 0.039387
#
# [78 rows x 10 columns]

# %%
Hourly_Trend_final = Merge(Hourly_trend_Enq,'Range_name',Hourly_trend_booking,'Range_name','','','outer',True,'single')
Hourly_Trend_final = Hourly_Trend_final[["Range_name","Enquiry Count","Booking Count"]]
Hourly_Trend_final
# Out:
#    Range_name  Enquiry Count  Booking Count
# 0         0-2           3070             48
# 1       10-12           9905            503
# 2       12-14          10124            556
# 3       14-16          10283            559
# 4       16-18           9198            506
# 5       18-20           9527            405
# 6         2-4           1170             18
# 7       20-22           9522            344
# 8       22-24           7520            179
# 9         4-6           1254             17
# 10        6-8           3402            102
# 11       8-10           6220            232

# %%
Hourly_Trend_final1 = Hourly_Trend_final.copy()
total_enquiry =Hourly_Trend_final1["Enquiry Count"].sum()
total_Booking =Hourly_Trend_final1["Booking Count"].sum()
print(total_enquiry)
print(total_Booking)
Hourly_Trend_final1["Enquiry Ratio"] = (Hourly_Trend_final1["Enquiry Count"]/total_enquiry)
Hourly_Trend_final1["Booking Ratio"] = (Hourly_Trend_final1["Booking Count"]/total_Booking)


Hourly_Trend_final1 = Hourly_Trend_final1.reindex(index=order_by_index(Hourly_Trend_final1.index, index_natsorted(Hourly_Trend_final1.Range_name)))
Hourly_Trend_final1
# Out:
# 81195
# 3469
#    Range_name  Enquiry Count  Booking Count  Enquiry Ratio  Booking Ratio
# 0         0-2           3070             48       0.037810       0.013837
# 6         2-4           1170             18       0.014410       0.005189
# 9         4-6           1254             17       0.015444       0.004901
# 10        6-8           3402            102       0.041899       0.029403
# 11       8-10           6220            232       0.076606       0.066878
# 1       10-12           9905            503       0.121990       0.144999
# 2       12-14          10124            556       0.124687       0.160277
# 3       14-16          10283            559       0.126646       0.161142
# 4       16-18           9198            506       0.113283       0.145863
# 5       18-20           9527            405       0.117335       0.116748
# 7       20-22           9522            344       0.117273       0.099164
# 8       22-24           7520            179       0.092617       0.051600

# %%
Hourly_Trend_final1.to_excel("CTB_hourly_trend_June.xlsx")

# %%
## Region wise

# %%
Region_enq = Trend_Analysis_gb(CTB_data,['ORDER_ID','DELR_RGON_NAME'],'','DELR_RGON_NAME','Weekly')
print("total enquiry : ",Region_enq.ORDER_ID.sum())
Region_enq
# Out:
# total enquiry :  81195
#    DELR_RGON_NAME  ORDER_ID
# 0     Central RO1      6273
# 1     Central RO2      7349
# 2     Central RO3      5710
# 3        East RO1      3717
# 4        East RO2      1375
# 5        East RO3      3043
# 6       North RO1      3468
# 7       North RO2      3364
# 8       North RO3      3932
# 9       South RO1      4406
# 10      South RO2      9116
# 11      South RO3      2561
# 12      South RO4      6518
# 13       West RO1      6502
# 14       West RO2      4256
# 15       West RO3      5815
# 16       West RO4      3790

# %%
Region_list = CTB_data[["DELR_RGON_NAME","DEALER_ID"]]
Region_list_uniq = Region_list.drop_duplicates(subset=['DELR_RGON_NAME', 'DEALER_ID'], keep='last')
Region_list_uniq.head(2)
# Out:
#       DELR_RGON_NAME DEALER_ID
# 63126       West RO2     W3720
# 45811      South RO4     S8823

# %%
GDMS_Booking.shape
# Out:
# (7768, 27)

# %%
GDMS_booking_add_region = pd.merge(GDMS_Booking, Region_list_uniq, left_on=['EQRY_DLR_NO'],right_on = ['DEALER_ID'], how = 'outer',indicator=True)
print("GDMS_add_region" , GDMS_booking_add_region.shape)
GDMS_booking_add_region['_merge'].value_counts()
# Out:
# GDMS_add_region (8025, 30)
# both          7768
# right_only     257
# left_only        0
# Name: _merge, dtype: int64

# %%
GDMS_booking_add_region.loc[GDMS_booking_add_region['_merge'] == "left_only", ['DELR_RGON_NAME']] = 'North RO3'
GDMS_booking_add_region[GDMS_booking_add_region["_merge"]=="left_only"]
# Out:
# Empty DataFrame
# Columns: [CSPM_DLR_NAME, EQRY_DLR_NO, EQRY_ENQRY_NO, EQRY_DATE, EQRY_STAT, EQRY_STATUS_NM, EQCR_MODEL_CODE, EQCR_MODEL_NAME, EQRY_NEWCAR_YN, EQRY_REF_NO, CTB_BOOKING_Y, RETAIL_DATE, INVC_CNFM_YN, BKNG_NO, BKNG_DATE, BKNG_DATE_NEW, BKNG_DATE_NEWYear, BKNG_DATE_NEWMonth, BKNG_DATE_NEWWeek, BKNG_DATE_NEWDay, BKNG_DATE_NEWhour, BKNG_DATE_NEWDayofweek, BKNG_DATE_NEWDayofyear, BKNG_DATE_NEWweekofyear, BKNG_DATE_NEWMonthName, BKNG_DATE_NEWMonthKey, BKNG_DATE_NEWWeekKey, DELR_RGON_NAME, DEALER_ID, _merge]
# Index: []
#
# [0 rows x 30 columns]

# %%
GDMS_booking_add_region_bl = GDMS_booking_add_region[GDMS_booking_add_region["_merge"]!="right_only"]
GDMS_booking_add_region_bl.shape
# Out:
# (7768, 30)

# %%
Region_Booking = Trend_Analysis_gb(GDMS_booking_add_region_bl,['EQRY_REF_NO','DELR_RGON_NAME'],'','DELR_RGON_NAME','Monthly')
Region_Booking
# Out:
#    DELR_RGON_NAME  EQRY_REF_NO
# 0     Central RO1          665
# 1     Central RO2          620
# 2     Central RO3          577
# 3        East RO1          417
# 4        East RO2          102
# 5        East RO3          305
# 6       North RO1          382
# 7       North RO2          270
# 8       North RO3          495
# 9       South RO1          422
# 10      South RO2          731
# 11      South RO3          210
# 12      South RO4          624
# 13       West RO1          666
# 14       West RO2          525
# 15       West RO3          453
# 16       West RO4          304

# %%
Region_final_merg = Merge(Region_enq,'DELR_RGON_NAME',Region_Booking,'DELR_RGON_NAME','','','outer',True,'single')
#Region_final = Hourly_Trend_final[["Range_name","Enquiry Count","Booking Count"]]
Region_final_merg
# Out:
#    DELR_RGON_NAME  ORDER_ID  EQRY_REF_NO _merge
# 0     Central RO1      6273          665   both
# 1     Central RO2      7349          620   both
# 2     Central RO3      5710          577   both
# 3        East RO1      3717          417   both
# 4        East RO2      1375          102   both
# 5        East RO3      3043          305   both
# 6       North RO1      3468          382   both
# 7       North RO2      3364          270   both
# 8       North RO3      3932          495   both
# 9       South RO1      4406          422   both
# 10      South RO2      9116          731   both
# 11      South RO3      2561          210   both
# 12      South RO4      6518          624   both
# 13       West RO1      6502          666   both
# 14       West RO2      4256          525   both
# 15       West RO3      5815          453   both
# 16       West RO4      3790          304   both

# %%
Region_final = Region_final_merg[["DELR_RGON_NAME","ORDER_ID","EQRY_REF_NO"]]
Region_final.columns = ['Dealer Region Name','Enquiry Count','Booking Count']
Region_enq = Region_final["Enquiry Count"].sum()
Region_book = Region_final["Booking Count"].sum()
Region_final["Enquiry Ratio"] = (Region_final["Enquiry Count"]/Region_enq)
Region_final["Booking Ratio"] = (Region_final["Booking Count"]/Region_book)
Region_final["Enq to Booking Ratio"] = (Region_final["Booking Count"]/Region_final["Enquiry Count"])
Region_final["Avg_Enquiry"]=Region_enq/Region_final["Dealer Region Name"].count()
Region_final["Avg_booking"]=Region_book/Region_final["Dealer Region Name"].count()
Region_final
# Out:
#    Dealer Region Name  Enquiry Count  Booking Count  Enquiry Ratio  \
# 0         Central RO1           6273            665       0.077258
# 1         Central RO2           7349            620       0.090510
# 2         Central RO3           5710            577       0.070325
# 3            East RO1           3717            417       0.045779
# 4            East RO2           1375            102       0.016935
# 5            East RO3           3043            305       0.037478
# 6           North RO1           3468            382       0.042712
# 7           North RO2           3364            270       0.041431
# 8           North RO3           3932            495       0.048427
# 9           South RO1           4406            422       0.054264
# 10          South RO2           9116            731       0.112273
# 11          South RO3           2561            210       0.031541
# 12          South RO4           6518            624       0.080276
# 13           West RO1           6502            666       0.080079
# 14           West RO2           4256            525       0.052417
# 15           West RO3           5815            453       0.071618
# 16           West RO4           3790            304       0.046678
#
#     Booking Ratio  Enq to Booking Ratio  Avg_Enquiry  Avg_booking
# 0        0.085608              0.106010  4776.176471   456.941176
# 1        0.079815              0.084365  4776.176471   456.941176
# 2        0.074279              0.101051  4776.176471   456.941176
# 3        0.053682              0.112187  4776.176471   456.941176
# 4        0.013131              0.074182  4776.176471   456.941176
# 5        0.039264              0.100230  4776.176471   456.941176
# 6        0.049176              0.110150  4776.176471   456.941176
# 7        0.034758              0.080262  4776.176471   456.941176
# 8        0.063723              0.125890  4776.176471   456.941176
# 9        0.054325              0.095778  4776.176471   456.941176
# 10       0.094104              0.080189  4776.176471   456.941176
# 11       0.027034              0.081999  4776.176471   456.941176
# 12       0.080330              0.095735  4776.176471   456.941176
# 13       0.085736              0.102430  4776.176471   456.941176
# 14       0.067585              0.123355  4776.176471   456.941176
# 15       0.058316              0.077902  4776.176471   456.941176
# 16       0.039135              0.080211  4776.176471   456.941176

# %%
Region_final['Booking Count'].sum()
# Out:
# 7768

# %% [markdown]
# # zone wise

# %%
GDMS_booking_region = GDMS_booking_add_region_bl.copy()
GDMS_booking_region[["Region Name","RO"]] = GDMS_booking_region.DELR_RGON_NAME.str.split(" ",expand=True)
GDMS_booking_region["Region Name"].count()
# Out:
# 7768

# %%
def Zone(dataset,element):
    var = dataset[dataset["Region Name"] == element]
    #print(var.shape)
    var = Trend_Analysis_pi(var,['CTB_BOOKING_Y','BKNG_DATE_NEWMonthKey'],'CTB_BOOKING_Y','BKNG_DATE_NEWMonthKey','BKNG_DATE_NEWMonthKey','Monthly')
    var.columns = ['BKNG_DATE_NEWMonthKey', 'Offline Booking', 'Online Booking']
    var["Total Booking"] = var["Offline Booking"]+var["Online Booking"]
    var_off_book = var["Offline Booking"].sum()
    var_on_book = var["Online Booking"].sum()
    var_tot_book = var_off_book+var_on_book
    var_off_book_per = var_off_book/var_tot_book
    var_on_book_per = var_on_book/var_tot_book
    print(element,":- ",var_off_book,var_on_book,var_tot_book,var_off_book_per,var_on_book_per)

    var = var[['BKNG_DATE_NEWMonthKey','Offline Booking', 'Online Booking',"Total Booking"]]
    
    return var

# %%
GDMS_booking_north = Zone(GDMS_booking_region,"North")
GDMS_booking_east = Zone(GDMS_booking_region,"East")
GDMS_booking_west = Zone(GDMS_booking_region,"West")
GDMS_booking_south = Zone(GDMS_booking_region,"South")
GDMS_booking_central = Zone(GDMS_booking_region,"Central")
# Out:
# North :-  677 470 1147 0.5902353966870096 0.4097646033129904
# East :-  511 313 824 0.6201456310679612 0.37985436893203883
# West :-  1218 730 1948 0.6252566735112937 0.37474332648870634
# South :-  977 1010 1987 0.49169602415702063 0.5083039758429794
# Central :-  921 941 1862 0.49462943071965626 0.5053705692803437

# %% [markdown]
# ### Model, Variant, Body and Fuel

# %%
def Trend_Analysis1(dataset,Variables, GroupbyVariable):
    #Var_name = TrendType+"_"+dataset
    #count_col_name = EBR_Type+"_"+"Count"
    #print(count_col_name)
    Trend = dataset[Variables].groupby(GroupbyVariable,as_index=False).sum()
    return Trend

# %%
def Trend_Analysis2(dataset,Variables, GroupbyVariable):
    #Var_name = TrendType+"_"+dataset
    #count_col_name = EBR_Type+"_"+"Count"
    #print(count_col_name)
    Trend = dataset[Variables].groupby(GroupbyVariable,as_index=False).count()
    return Trend

# %%
car_dict = {
    "SUV" : ["New Creta", "Creta", "Venue","Tucson","Alcazar"],
    "HatchBack" : ["Grand i10 NIOS","ELITE i20","All New i20","New i20","Grand i10","Santro","i20 Active"],
    "Sedan" : ["AURA","Elantra","Kona EV","New Verna","Xcent","Next Gen Verna"]
}

body_dict = {}
for k, v in car_dict.items():
    for i in v:
        body_dict[i] = k
body_dict
# Out:
# {'New Creta': 'SUV',
#  'Creta': 'SUV',
#  'Venue': 'SUV',
#  'Tucson': 'SUV',
#  'Alcazar': 'SUV',
#  'Grand i10 NIOS': 'HatchBack',
#  'ELITE i20': 'HatchBack',
#  'All New i20': 'HatchBack',
#  'New i20': 'HatchBack',
#  'Grand i10': 'HatchBack',
#  'Santro': 'HatchBack',
#  'i20 Active': 'HatchBack',
#  'AURA': 'Sedan',
#  'Elantra': 'Sedan',
#  'Kona EV': 'Sedan',
#  'New Verna': 'Sedan',
#  'Xcent': 'Sedan',
#  'Next Gen Verna': 'Sedan'}

# %%
low = ['AURA_AURA1.2MTCNGS', 'AURA_AURA1.2MTCRDiS', 'AURA_AURA1.2MTKappaE', 'AURA_AURA1.2MTKappaS', 'Creta_CRETA1.4CRDiE+', 'Creta_CRETA1.4CRDiS', 'NewCreta_Creta1.5CRDiMTE', 'NewCreta_Creta1.5CRDiMTS', 'NewCreta_Creta1.5MPiMTE', 'NewCreta_Creta1.5MPiMTS', 'Elantra_ElantraVTVTS', 'Grandi10_Grandi10Magna1.2', 'Grandi10_Grandi10Magna1.2CNG', 'Grandi10NIOS_Grandi10NIOS1.2AMTKappaMagna', 'Grandi10NIOS_Grandi10NIOS1.2MTCNGMagna', 'Grandi10NIOS_Grandi10NIOS1.2MTCorporate', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiMagna', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaEra', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaMagna', 'i20Active_i20ActiveVTVTS', 'ELITEi20_i20EraCRDi', 'ELITEi20_i20EraVTVT', 'ELITEi20_i20Magna+CRDi', 'ELITEi20_i20Magna+VTVT', 'AllNewi20_MagnaMT', 'Santro_Santro1.1AMTMagna', 'Santro_Santro1.1MTCNGMagna', 'Santro_Santro1.1MTEraExecutive', 'Santro_Santro1.1MTMagna', 'Tucson_TUCSONCRDiAUTOGL(O)', 'Tucson_TUCSONCRDiL', 'Tucson_TUCSONVTVTAUTOGL(O)', 'Tucson_TUCSONVTVTAUTOGL(O)', 'Tucson_TUCSONVTVTL', 'Venue_VENUE1.0TurboGDIDCTS', 'Venue_VENUE1.0TurboGDIMTS', 'Venue_VENUE1.2KappaMTE', 'Venue_VENUE1.2KappaMTS', 'Venue_VENUE1.4CRDiMTE', 'Venue_VENUE1.4CRDiMTS', 'Venue_VENUE1.5CRDiMTE', 'Venue_VENUE1.5CRDiMTS', 'NewVerna_VERNA1.5CRDiMTS+', 'NewVerna_VERNA1.5MPIMTS', 'Xcent_XcentAUTOS','Alcazar_ALCAZAR1.5ATPrestige(O)7Seater', 'Alcazar_ALCAZAR1.5MTPrestige6Seater', 'Alcazar_ALCAZAR1.5MTPrestige7Seater','Alcazar_ALCAZAR2.0ATPrestige(O)6Seater','Alcazar_ALCAZAR 2.0 MT Prestige 6 Seater','Alcazar_ALCAZAR2.0MTPrestige7Seater','AllNewi20_i20Era1.2KappaMT','AllNewi20_i20Magna1.2KappaMT','AllNewi20_MagnaMT']

mid = ['AllNewi20_Asta Turbo iMT', 'AllNewi20_Asta Turbo iMT (Dual Tone)', 'AllNewi20_i20 Asta 1.0 Turbo GDI DCT', 'AllNewi20_i20 Asta 1.0 Turbo GDI iMT', 'AllNewi20_i20 Asta 1.2 Kappa IVT', 'AllNewi20_i20 Asta 1.2 Kappa MT','AllNewi20_i20 Sportz 1.0 Turbo GDI iMT','AllNewi20_i20 Sportz 1.2 Kappa IVT','AllNewi20_i20 Sportz 1.2 Kappa MT','AllNewi20_i20 Sportz 1.5 CRDi MT','AllNewi20_Sportz IVT','AllNewi20_Sportz IVT (Dual Tone)','AllNewi20_Sportz MT','AllNewi20_Sportz MT  (Dual Tone)','AllNewi20_Sportz MT (Dual Tone)','AURA_AURA1.2AMTCRDiS', 'AURA_AURA1.2AMTKappaS', 'AURA_AURA1.2MTCRDiSX(O)', 'AURA_AURA1.2MTKappaSX', 'AURA_AURA1.2MTkappaSX(O)', 'Creta_CRETA1.4CRDiEX', 'NewCreta_Creta1.5CRDiATSX', 'NewCreta_Creta1.5CRDiATSX(O)', 'NewCreta_Creta1.5CRDiMTEX', 'NewCreta_Creta1.5CRDiMTSX', 'NewCreta_Creta1.5CRDiMTSX(O)', 'NewCreta_Creta1.5MPiIVTSX', 'NewCreta_Creta1.5MPiMTEX', 'Creta_CRETA1.6CRDiAUTOSX', 'Creta_CRETA1.6CRDiE+', 'Creta_CRETA1.6CRDiEX', 'Creta_CRETA1.6CRDiSX', 'Creta_CRETA1.6CRDiSX(O)Executive', 'Creta_CRETA1.6VTVTE+', 'Creta_CRETA1.6VTVTSX', 'Creta_CRETA1.6VTVTSX(O)Executive', 'Elantra_ElantraVTVTSX', 'Grandi10NIOS_Grandi10NIOS1.0TurboMTSportz', 'Grandi10NIOS_Grandi10NIOS1.2AMTKappaSportz', 'Grandi10NIOS_Grandi10NIOS1.2AMTCorporate', 'Grandi10NIOS_Grandi10NIOS1.2AMTCRDiSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTCNGSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiCorporate', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportzDT', 'Grandi10_Grandi10PrimeT1.2', 'Grandi10_Grandi10PrimeTCNG', 'Grandi10_Grandi10PrimeTCRDi', 'Grandi10_Grandi10Sportz1.2', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportzDT', 'i20Active_i20ActiveCRDiSX', 'ELITEi20_i20Sportz+CRDi', 'ELITEi20_i20Sportz+CVT', 'ELITEi20_i20Sportz+DualtoneCRDi', 'ELITEi20_i20Sportz+DualtoneVTVT', 'ELITEi20_i20Sportz+VTVT', 'Santro_Santro1.1AMTSportz', 'Santro_Santro1.1AMTSportzSE', 'Santro_Santro1.1MTCNGSportz', 'Santro_Santro1.1MTSportz', 'Santro_Santro1.1MTSportzSE', 'AllNewi20_SportzIVT', 'AllNewi20_SportzIVT(DualTone)', 'AllNewi20_SportzMT', 'AllNewi20_SportzMT (DualTone)', 'AllNewi20_SportzMT(DualTone)', 'AllNewi20_SportzTurboiMT', 'AllNewi20_SportzTurboiMT(DualTone)', 'Tucson_TUCSONCRDiAUTOGL', 'Tucson_TUCSONCRDiAUTOGLS', 'Tucson_TUCSONVTVTAUTOGL', 'Tucson_TUCSONVTVTAUTOGLS', 'Venue_VENUE1.0TurboGDIDCTSX+', 'Venue_VENUE1.0TurboGDIiMTSX(O)', 'Venue_VENUE1.0TurboGDIMTSX', 'Venue_VENUE1.0TurboGDIMTSXDualTone', 'Venue_VENUE1.0TurboGDIMTSX(O)', 'Venue_VENUE1.0TurboGDIMTSX(O)DT', 'Venue_VENUE1.0TurboGDIMTSX(O)DualTone', 'Venue_VENUE1.2KappaMTS+', 'Venue_VENUE1.4CRDiMTSX', 'Venue_VENUE1.4CRDiMTSXDualTone', 'Venue_VENUE1.4CRDiMTSX(O)', 'Venue_VENUE1.4CRDiMTSX(O)DT', 'Venue_VENUE1.5CRDiMTSX', 'Venue_VENUE1.5CRDiMTSXDualTone', 'Venue_VENUE1.5CRDiMTSX(O)', 'Venue_VENUE1.5CRDiMTSX(O)DualTone', 'NewVerna_VERNA1.5CRDiATSX', 'NewVerna_VERNA1.5CRDiATSX(O)', 'NewVerna_VERNA1.5CRDiMTSX', 'NewVerna_VERNA1.5CRDiMTSX(O)', 'NewVerna_VERNA1.5MPIIVTSX', 'NewVerna_VERNA1.5MPIIVTSX(O)', 'NewVerna_VERNA1.5MPIMTSX', 'NewVerna_VERNA1.5MPIMTSX(O)', 'NewVerna_Verna1.6CRDiSX', 'NewVerna_Verna1.6CRDiSX(O)', 'NewVerna_Verna1.6VTVTSX', 'NewVerna_Verna1.6VTVTSX(O)', 'Xcent_XcentVTVTPrimeT+CNG','Alcazar_ALCAZAR 1.5 AT Platinum(O) 6 Seater','Alcazar_ALCAZAR 1.5 MT Platinum 7 Seater','Alcazar_ALCAZAR 2.0 AT Platinum(O) 6 Seater','Alcazar_ALCAZAR 2.0 MT Platinum 7 Seater']

high = ['AllNewi20_Asta(O) MT','AllNewi20_Asta(O) MT (Dual Tone)','AllNewi20_Asta(O) Turbo DCT','AllNewi20_Asta(O) Turbo DCT (Dual Tone)','AllNewi20_i20 Asta(O) 1.0 Turbo GDI DCT','AllNewi20_i20 Asta(O) 1.5 CRDi MT''AURA_AURA1.0TurboGDIMT(SX+)', 'AURA_AURA1.2AMTCRDiSX+', 'AURA_AURA1.2AMTKappaSX+', 'NewCreta_Creta1.4TurboGDiDCTSX', 'NewCreta_Creta1.4TurboGDiDCTSX(O)', 'NewCreta_Creta1.5MPiIVTSX(O)', 'NewCreta_Creta1.5MPiMTSX', 'Creta_CRETA1.6CRDiSXDualTone', 'Creta_CRETA1.6CRDiSXSportsEdition', 'Creta_CRETA1.6CRDiSX(O)', 'Creta_CRETA1.6VTVTAUTOSX', 'Creta_CRETA1.6VTVTSXDualTone', 'Creta_CRETA1.6VTVTSXSportsEdition', 'Creta_CRETA1.6VTVTSX(O)', 'Elantra_ElantraCRDIAutoSX(O)', 'Elantra_ElantraCRDISX', 'Elantra_ElantraVTVTAutoSX', 'Elantra_ElantraVTVTAutoSX(O)', 'Grandi10NIOS_Grandi10NIOS1.2AMTKappaAsta', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiAsta', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaAsta', 'ELITEi20_i20Asta(O)CRDi', 'ELITEi20_i20Asta(O)VTVT', 'ELITEi20_i20Asta(O)CVT', 'KonaEV_KonaElectricPremium', 'KonaEV_KonaElectricPremiumDualTone', 'Santro_Santro1.1AMTAsta', 'Santro_Santro1.1MTAsta', 'Tucson_TUCSONCRDi4WDAUTOGLS', 'Venue_VENUE1.0TurboGDIDCTSX+DT', 'Venue_VENUE1.0TurboGDIiMTSXDT', 'Venue_VENUE1.0TurboGDIiMTSX(O)DT', 'NewVerna_VERNA1.0TurboGDIDCTSX(O)', 'NewVerna_Verna1.6CRDiAutoSX(O)', 'NewVerna_Verna1.6CRDiAutoSX+', 'NewVerna_Verna1.6VTVTAutoSX(O)', 'NewVerna_Verna1.6VTVTAutoSX+','Alcazar_ALCAZAR 1.5 AT Signature(O) 6 Seater','Alcazar_ALCAZAR 1.5 AT Signature(O) 6 Seater Dual Tone','Alcazar_ALCAZAR 1.5 MT Signature 6 Seater','Alcazar_ALCAZAR 1.5 MT Signature 6 Seater Dual Tone','Alcazar_ALCAZAR 2.0 AT Signature(O) 6 Seater','Alcazar_ALCAZAR 2.0 AT Signature(O) 6 Seater Dual Tone','Alcazar_ALCAZAR 2.0 MT Signature 6 Seater','Alcazar_ALCAZAR 2.0 MT Signature 6 Seater Dual Tone']

# %%
low = ['AURA_AURA1.2MTCNGS', 'AURA_AURA1.2MTCRDiS', 'AURA_AURA1.2MTKappaE', 'AURA_AURA1.2MTKappaS', 'Creta_CRETA1.4CRDiE+', 'Creta_CRETA1.4CRDiS', 'NewCreta_Creta1.5CRDiMTE', 'NewCreta_Creta1.5CRDiMTS', 'NewCreta_Creta1.5MPiMTE', 'NewCreta_Creta1.5MPiMTS', 'Elantra_ElantraVTVTS', 'Grandi10_Grandi10Magna1.2', 'Grandi10_Grandi10Magna1.2CNG', 'Grandi10NIOS_Grandi10NIOS1.2AMTKappaMagna', 'Grandi10NIOS_Grandi10NIOS1.2MTCNGMagna', 'Grandi10NIOS_Grandi10NIOS1.2MTCorporate', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiMagna', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaEra', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaMagna', 'i20Active_i20ActiveVTVTS', 'ELITEi20_i20EraCRDi', 'ELITEi20_i20EraVTVT', 'ELITEi20_i20Magna+CRDi', 'ELITEi20_i20Magna+VTVT', 'AllNewi20_MagnaMT', 'Santro_Santro1.1AMTMagna', 'Santro_Santro1.1MTCNGMagna', 'Santro_Santro1.1MTEraExecutive', 'Santro_Santro1.1MTMagna', 'Tucson_TUCSONCRDiAUTOGL(O)', 'Tucson_TUCSONCRDiL', 'Tucson_TUCSONVTVTAUTOGL(O)', 'Tucson_TUCSONVTVTAUTOGL(O)', 'Tucson_TUCSONVTVTL', 'Venue_VENUE1.0TurboGDIDCTS', 'Venue_VENUE1.0TurboGDIMTS', 'Venue_VENUE1.2KappaMTE', 'Venue_VENUE1.2KappaMTS', 'Venue_VENUE1.4CRDiMTE', 'Venue_VENUE1.4CRDiMTS', 'Venue_VENUE1.5CRDiMTE', 'Venue_VENUE1.5CRDiMTS', 'NewVerna_VERNA1.5CRDiMTS+', 'NewVerna_VERNA1.5MPIMTS', 'Xcent_XcentAUTOS']

mid = ['AllNewi20_AstaIVT', 'AllNewi20_AstaMT', 'AllNewi20_AstaTurboDCT', 'AllNewi20_Asta IVT(DualTone)', 'AllNewi20_Asta(O)MT', 'AllNewi20_Asta(O)MT(DualTone)', 'AURA_AURA1.2AMTCRDiS', 'AURA_AURA1.2AMTKappaS', 'AURA_AURA1.2MTCRDiSX(O)', 'AURA_AURA1.2MTKappaSX', 'AURA_AURA1.2MTkappaSX(O)', 'Creta_CRETA1.4CRDiEX', 'NewCreta_Creta1.5CRDiATSX', 'NewCreta_Creta1.5CRDiATSX(O)', 'NewCreta_Creta1.5CRDiMTEX', 'NewCreta_Creta1.5CRDiMTSX', 'NewCreta_Creta1.5CRDiMTSX(O)', 'NewCreta_Creta1.5MPiIVTSX', 'NewCreta_Creta1.5MPiMTEX', 'Creta_CRETA1.6CRDiAUTOSX', 'Creta_CRETA1.6CRDiE+', 'Creta_CRETA1.6CRDiEX', 'Creta_CRETA1.6CRDiSX', 'Creta_CRETA1.6CRDiSX(O)Executive', 'Creta_CRETA1.6VTVTE+', 'Creta_CRETA1.6VTVTSX', 'Creta_CRETA1.6VTVTSX(O)Executive', 'Elantra_ElantraVTVTSX', 'Grandi10NIOS_Grandi10NIOS1.0TurboMTSportz', 'Grandi10NIOS_Grandi10NIOS1.2AMTKappaSportz', 'Grandi10NIOS_Grandi10NIOS1.2AMTCorporate', 'Grandi10NIOS_Grandi10NIOS1.2AMTCRDiSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTCNGSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiCorporate', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportzDT', 'Grandi10_Grandi10PrimeT1.2', 'Grandi10_Grandi10PrimeTCNG', 'Grandi10_Grandi10PrimeTCRDi', 'Grandi10_Grandi10Sportz1.2', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportzDT', 'i20Active_i20ActiveCRDiSX', 'ELITEi20_i20Sportz+CRDi', 'ELITEi20_i20Sportz+CVT', 'ELITEi20_i20Sportz+DualtoneCRDi', 'ELITEi20_i20Sportz+DualtoneVTVT', 'ELITEi20_i20Sportz+VTVT', 'Santro_Santro1.1AMTSportz', 'Santro_Santro1.1AMTSportzSE', 'Santro_Santro1.1MTCNGSportz', 'Santro_Santro1.1MTSportz', 'Santro_Santro1.1MTSportzSE', 'AllNewi20_SportzIVT', 'AllNewi20_SportzIVT(DualTone)', 'AllNewi20_SportzMT', 'AllNewi20_SportzMT (DualTone)', 'AllNewi20_SportzMT(DualTone)', 'AllNewi20_SportzTurboiMT', 'AllNewi20_SportzTurboiMT(DualTone)', 'Tucson_TUCSONCRDiAUTOGL', 'Tucson_TUCSONCRDiAUTOGLS', 'Tucson_TUCSONVTVTAUTOGL', 'Tucson_TUCSONVTVTAUTOGLS', 'Venue_VENUE1.0TurboGDIDCTSX+', 'Venue_VENUE1.0TurboGDIiMTSX(O)', 'Venue_VENUE1.0TurboGDIMTSX', 'Venue_VENUE1.0TurboGDIMTSXDualTone', 'Venue_VENUE1.0TurboGDIMTSX(O)', 'Venue_VENUE1.0TurboGDIMTSX(O)DT', 'Venue_VENUE1.0TurboGDIMTSX(O)DualTone', 'Venue_VENUE1.2KappaMTS+', 'Venue_VENUE1.4CRDiMTSX', 'Venue_VENUE1.4CRDiMTSXDualTone', 'Venue_VENUE1.4CRDiMTSX(O)', 'Venue_VENUE1.4CRDiMTSX(O)DT', 'Venue_VENUE1.5CRDiMTSX', 'Venue_VENUE1.5CRDiMTSXDualTone', 'Venue_VENUE1.5CRDiMTSX(O)', 'Venue_VENUE1.5CRDiMTSX(O)DualTone', 'NewVerna_VERNA1.5CRDiATSX', 'NewVerna_VERNA1.5CRDiATSX(O)', 'NewVerna_VERNA1.5CRDiMTSX', 'NewVerna_VERNA1.5CRDiMTSX(O)', 'NewVerna_VERNA1.5MPIIVTSX', 'NewVerna_VERNA1.5MPIIVTSX(O)', 'NewVerna_VERNA1.5MPIMTSX', 'NewVerna_VERNA1.5MPIMTSX(O)', 'NewVerna_Verna1.6CRDiSX', 'NewVerna_Verna1.6CRDiSX(O)', 'NewVerna_Verna1.6VTVTSX', 'NewVerna_Verna1.6VTVTSX(O)', 'Xcent_XcentVTVTPrimeT+CNG']

high = ['AllNewi20_AstaMT(DualTone)', 'AllNewi20_AstaTurboDCT(DualTone)', 'AllNewi20_AstaTurboiMT', 'AllNewi20_AstaTurboiMT(DualTone)', 'AllNewi20_Asta(O)TurboDCT', 'AllNewi20_Asta(O)TurboDCT(DualTone)', 'AURA_AURA1.0TurboGDIMT(SX+)', 'AURA_AURA1.2AMTCRDiSX+', 'AURA_AURA1.2AMTKappaSX+', 'NewCreta_Creta1.4TurboGDiDCTSX', 'NewCreta_Creta1.4TurboGDiDCTSX(O)', 'NewCreta_Creta1.5MPiIVTSX(O)', 'NewCreta_Creta1.5MPiMTSX', 'Creta_CRETA1.6CRDiSXDualTone', 'Creta_CRETA1.6CRDiSXSportsEdition', 'Creta_CRETA1.6CRDiSX(O)', 'Creta_CRETA1.6VTVTAUTOSX', 'Creta_CRETA1.6VTVTSXDualTone', 'Creta_CRETA1.6VTVTSXSportsEdition', 'Creta_CRETA1.6VTVTSX(O)', 'Elantra_ElantraCRDIAutoSX(O)', 'Elantra_ElantraCRDISX', 'Elantra_ElantraVTVTAutoSX', 'Elantra_ElantraVTVTAutoSX(O)', 'Grandi10NIOS_Grandi10NIOS1.2AMTKappaAsta', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiAsta', 'Grandi10NIOS_Grandi10NIOS1.2MTCRDiSportz', 'Grandi10NIOS_Grandi10NIOS1.2MTKappaAsta', 'ELITEi20_i20Asta(O)CRDi', 'ELITEi20_i20Asta(O)VTVT', 'ELITEi20_i20Asta(O)CVT', 'KonaEV_KonaElectricPremium', 'KonaEV_KonaElectricPremiumDualTone', 'Santro_Santro1.1AMTAsta', 'Santro_Santro1.1MTAsta', 'Tucson_TUCSONCRDi4WDAUTOGLS', 'Venue_VENUE1.0TurboGDIDCTSX+DT', 'Venue_VENUE1.0TurboGDIiMTSXDT', 'Venue_VENUE1.0TurboGDIiMTSX(O)DT', 'NewVerna_VERNA1.0TurboGDIDCTSX(O)', 'NewVerna_Verna1.6CRDiAutoSX(O)', 'NewVerna_Verna1.6CRDiAutoSX+', 'NewVerna_Verna1.6VTVTAutoSX(O)', 'NewVerna_Verna1.6VTVTAutoSX+']

# %%
var_type = {"Low": low, "Mid" : mid , "High": high}
#var_dict
var_dict = {}
for k, v in var_type.items():
    for i in v:
        var_dict[i] = k
var_dict
# Out:
# {'AURA_AURA1.2MTCNGS': 'Low',
#  'AURA_AURA1.2MTCRDiS': 'Low',
#  'AURA_AURA1.2MTKappaE': 'Low',
#  'AURA_AURA1.2MTKappaS': 'Low',
#  'Creta_CRETA1.4CRDiE+': 'Low',
#  'Creta_CRETA1.4CRDiS': 'Low',
#  'NewCreta_Creta1.5CRDiMTE': 'Low',
#  'NewCreta_Creta1.5CRDiMTS': 'Low',
#  'NewCreta_Creta1.5MPiMTE': 'Low',
#  'NewCreta_Creta1.5MPiMTS': 'Low',
#  'Elantra_ElantraVTVTS': 'Low',
#  'Grandi10_Grandi10Magna1.2': 'Low',
#  'Grandi10_Grandi10Magna1.2CNG': 'Low',
#  'Grandi10NIOS_Grandi10NIOS1.2AMTKappaMagna': 'Low',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCNGMagna': 'Low',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCorporate': 'Low',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCRDiMagna': 'Low',
#  'Grandi10NIOS_Grandi10NIOS1.2MTKappaEra': 'Low',
#  'Grandi10NIOS_Grandi10NIOS1.2MTKappaMagna': 'Low',
#  'i20Active_i20ActiveVTVTS': 'Low',
#  'ELITEi20_i20EraCRDi': 'Low',
#  'ELITEi20_i20EraVTVT': 'Low',
#  'ELITEi20_i20Magna+CRDi': 'Low',
#  'ELITEi20_i20Magna+VTVT': 'Low',
#  'AllNewi20_MagnaMT': 'Low',
#  'Santro_Santro1.1AMTMagna': 'Low',
#  'Santro_Santro1.1MTCNGMagna': 'Low',
#  'Santro_Santro1.1MTEraExecutive': 'Low',
#  'Santro_Santro1.1MTMagna': 'Low',
#  'Tucson_TUCSONCRDiAUTOGL(O)': 'Low',
#  'Tucson_TUCSONCRDiL': 'Low',
#  'Tucson_TUCSONVTVTAUTOGL(O)': 'Low',
#  'Tucson_TUCSONVTVTL': 'Low',
#  'Venue_VENUE1.0TurboGDIDCTS': 'Low',
#  'Venue_VENUE1.0TurboGDIMTS': 'Low',
#  'Venue_VENUE1.2KappaMTE': 'Low',
#  'Venue_VENUE1.2KappaMTS': 'Low',
#  'Venue_VENUE1.4CRDiMTE': 'Low',
#  'Venue_VENUE1.4CRDiMTS': 'Low',
#  'Venue_VENUE1.5CRDiMTE': 'Low',
#  'Venue_VENUE1.5CRDiMTS': 'Low',
#  'NewVerna_VERNA1.5CRDiMTS+': 'Low',
#  'NewVerna_VERNA1.5MPIMTS': 'Low',
#  'Xcent_XcentAUTOS': 'Low',
#  'AllNewi20_AstaIVT': 'Mid',
#  'AllNewi20_AstaMT': 'Mid',
#  'AllNewi20_AstaTurboDCT': 'Mid',
#  'AllNewi20_Asta\xa0IVT(DualTone)': 'Mid',
#  'AllNewi20_Asta(O)MT': 'Mid',
#  'AllNewi20_Asta(O)MT(DualTone)': 'Mid',
#  'AURA_AURA1.2AMTCRDiS': 'Mid',
#  'AURA_AURA1.2AMTKappaS': 'Mid',
#  'AURA_AURA1.2MTCRDiSX(O)': 'Mid',
#  'AURA_AURA1.2MTKappaSX': 'Mid',
#  'AURA_AURA1.2MTkappaSX(O)': 'Mid',
#  'Creta_CRETA1.4CRDiEX': 'Mid',
#  'NewCreta_Creta1.5CRDiATSX': 'Mid',
#  'NewCreta_Creta1.5CRDiATSX(O)': 'Mid',
#  'NewCreta_Creta1.5CRDiMTEX': 'Mid',
#  'NewCreta_Creta1.5CRDiMTSX': 'Mid',
#  'NewCreta_Creta1.5CRDiMTSX(O)': 'Mid',
#  'NewCreta_Creta1.5MPiIVTSX': 'Mid',
#  'NewCreta_Creta1.5MPiMTEX': 'Mid',
#  'Creta_CRETA1.6CRDiAUTOSX': 'Mid',
#  'Creta_CRETA1.6CRDiE+': 'Mid',
#  'Creta_CRETA1.6CRDiEX': 'Mid',
#  'Creta_CRETA1.6CRDiSX': 'Mid',
#  'Creta_CRETA1.6CRDiSX(O)Executive': 'Mid',
#  'Creta_CRETA1.6VTVTE+': 'Mid',
#  'Creta_CRETA1.6VTVTSX': 'Mid',
#  'Creta_CRETA1.6VTVTSX(O)Executive': 'Mid',
#  'Elantra_ElantraVTVTSX': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.0TurboMTSportz': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2AMTKappaSportz': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2AMTCorporate': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2AMTCRDiSportz': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCNGSportz': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCRDiCorporate': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportz': 'Mid',
#  'Grandi10NIOS_Grandi10NIOS1.2MTKappaSportzDT': 'Mid',
#  'Grandi10_Grandi10PrimeT1.2': 'Mid',
#  'Grandi10_Grandi10PrimeTCNG': 'Mid',
#  'Grandi10_Grandi10PrimeTCRDi': 'Mid',
#  'Grandi10_Grandi10Sportz1.2': 'Mid',
#  'i20Active_i20ActiveCRDiSX': 'Mid',
#  'ELITEi20_i20Sportz+CRDi': 'Mid',
#  'ELITEi20_i20Sportz+CVT': 'Mid',
#  'ELITEi20_i20Sportz+DualtoneCRDi': 'Mid',
#  'ELITEi20_i20Sportz+DualtoneVTVT': 'Mid',
#  'ELITEi20_i20Sportz+VTVT': 'Mid',
#  'Santro_Santro1.1AMTSportz': 'Mid',
#  'Santro_Santro1.1AMTSportzSE': 'Mid',
#  'Santro_Santro1.1MTCNGSportz': 'Mid',
#  'Santro_Santro1.1MTSportz': 'Mid',
#  'Santro_Santro1.1MTSportzSE': 'Mid',
#  'AllNewi20_SportzIVT': 'Mid',
#  'AllNewi20_SportzIVT(DualTone)': 'Mid',
#  'AllNewi20_SportzMT': 'Mid',
#  'AllNewi20_SportzMT\xa0(DualTone)': 'Mid',
#  'AllNewi20_SportzMT(DualTone)': 'Mid',
#  'AllNewi20_SportzTurboiMT': 'Mid',
#  'AllNewi20_SportzTurboiMT(DualTone)': 'Mid',
#  'Tucson_TUCSONCRDiAUTOGL': 'Mid',
#  'Tucson_TUCSONCRDiAUTOGLS': 'Mid',
#  'Tucson_TUCSONVTVTAUTOGL': 'Mid',
#  'Tucson_TUCSONVTVTAUTOGLS': 'Mid',
#  'Venue_VENUE1.0TurboGDIDCTSX+': 'Mid',
#  'Venue_VENUE1.0TurboGDIiMTSX(O)': 'Mid',
#  'Venue_VENUE1.0TurboGDIMTSX': 'Mid',
#  'Venue_VENUE1.0TurboGDIMTSXDualTone': 'Mid',
#  'Venue_VENUE1.0TurboGDIMTSX(O)': 'Mid',
#  'Venue_VENUE1.0TurboGDIMTSX(O)DT': 'Mid',
#  'Venue_VENUE1.0TurboGDIMTSX(O)DualTone': 'Mid',
#  'Venue_VENUE1.2KappaMTS+': 'Mid',
#  'Venue_VENUE1.4CRDiMTSX': 'Mid',
#  'Venue_VENUE1.4CRDiMTSXDualTone': 'Mid',
#  'Venue_VENUE1.4CRDiMTSX(O)': 'Mid',
#  'Venue_VENUE1.4CRDiMTSX(O)DT': 'Mid',
#  'Venue_VENUE1.5CRDiMTSX': 'Mid',
#  'Venue_VENUE1.5CRDiMTSXDualTone': 'Mid',
#  'Venue_VENUE1.5CRDiMTSX(O)': 'Mid',
#  'Venue_VENUE1.5CRDiMTSX(O)DualTone': 'Mid',
#  'NewVerna_VERNA1.5CRDiATSX': 'Mid',
#  'NewVerna_VERNA1.5CRDiATSX(O)': 'Mid',
#  'NewVerna_VERNA1.5CRDiMTSX': 'Mid',
#  'NewVerna_VERNA1.5CRDiMTSX(O)': 'Mid',
#  'NewVerna_VERNA1.5MPIIVTSX': 'Mid',
#  'NewVerna_VERNA1.5MPIIVTSX(O)': 'Mid',
#  'NewVerna_VERNA1.5MPIMTSX': 'Mid',
#  'NewVerna_VERNA1.5MPIMTSX(O)': 'Mid',
#  'NewVerna_Verna1.6CRDiSX': 'Mid',
#  'NewVerna_Verna1.6CRDiSX(O)': 'Mid',
#  'NewVerna_Verna1.6VTVTSX': 'Mid',
#  'NewVerna_Verna1.6VTVTSX(O)': 'Mid',
#  'Xcent_XcentVTVTPrimeT+CNG': 'Mid',
#  'AllNewi20_AstaMT(DualTone)': 'High',
#  'AllNewi20_AstaTurboDCT(DualTone)': 'High',
#  'AllNewi20_AstaTurboiMT': 'High',
#  'AllNewi20_AstaTurboiMT(DualTone)': 'High',
#  'AllNewi20_Asta(O)TurboDCT': 'High',
#  'AllNewi20_Asta(O)TurboDCT(DualTone)': 'High',
#  'AURA_AURA1.0TurboGDIMT(SX+)': 'High',
#  'AURA_AURA1.2AMTCRDiSX+': 'High',
#  'AURA_AURA1.2AMTKappaSX+': 'High',
#  'NewCreta_Creta1.4TurboGDiDCTSX': 'High',
#  'NewCreta_Creta1.4TurboGDiDCTSX(O)': 'High',
#  'NewCreta_Creta1.5MPiIVTSX(O)': 'High',
#  'NewCreta_Creta1.5MPiMTSX': 'High',
#  'Creta_CRETA1.6CRDiSXDualTone': 'High',
#  'Creta_CRETA1.6CRDiSXSportsEdition': 'High',
#  'Creta_CRETA1.6CRDiSX(O)': 'High',
#  'Creta_CRETA1.6VTVTAUTOSX': 'High',
#  'Creta_CRETA1.6VTVTSXDualTone': 'High',
#  'Creta_CRETA1.6VTVTSXSportsEdition': 'High',
#  'Creta_CRETA1.6VTVTSX(O)': 'High',
#  'Elantra_ElantraCRDIAutoSX(O)': 'High',
#  'Elantra_ElantraCRDISX': 'High',
#  'Elantra_ElantraVTVTAutoSX': 'High',
#  'Elantra_ElantraVTVTAutoSX(O)': 'High',
#  'Grandi10NIOS_Grandi10NIOS1.2AMTKappaAsta': 'High',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCRDiAsta': 'High',
#  'Grandi10NIOS_Grandi10NIOS1.2MTCRDiSportz': 'High',
#  'Grandi10NIOS_Grandi10NIOS1.2MTKappaAsta': 'High',
#  'ELITEi20_i20Asta(O)CRDi': 'High',
#  'ELITEi20_i20Asta(O)VTVT': 'High',
#  'ELITEi20_i20Asta(O)CVT': 'High',
#  'KonaEV_KonaElectricPremium': 'High',
#  'KonaEV_KonaElectricPremiumDualTone': 'High',
#  'Santro_Santro1.1AMTAsta': 'High',
#  'Santro_Santro1.1MTAsta': 'High',
#  'Tucson_TUCSONCRDi4WDAUTOGLS': 'High',
#  'Venue_VENUE1.0TurboGDIDCTSX+DT': 'High',
#  'Venue_VENUE1.0TurboGDIiMTSXDT': 'High',
#  'Venue_VENUE1.0TurboGDIiMTSX(O)DT': 'High',
#  'NewVerna_VERNA1.0TurboGDIDCTSX(O)': 'High',
#  'NewVerna_Verna1.6CRDiAutoSX(O)': 'High',
#  'NewVerna_Verna1.6CRDiAutoSX+': 'High',
#  'NewVerna_Verna1.6VTVTAutoSX(O)': 'High',
#  'NewVerna_Verna1.6VTVTAutoSX+': 'High'}

# %%
BEV_Type_enq =CTB_data.copy()
BEV_Type_enq["model_var_raw"] = BEV_Type_enq["MODEL"] + "_"+BEV_Type_enq["VARIANT"]
BEV_Type_enq = BEV_Type_enq[['ORDER_ID','model_var_raw']].groupby('model_var_raw',as_index=False).count()
print("total enquiry : ",BEV_Type_enq.ORDER_ID.sum())
BEV_Type_enq["model_var"] = BEV_Type_enq.model_var_raw.str.replace(' ', '')
BEV_Type_enq.sort_values(by=['model_var'],inplace=True)
BEV_Type_enq.columns = ["model_var_raw","Enquiry Count","model_var"]
BEV_Type_enq
# Out:
# total enquiry :  81195
#                                          model_var_raw  Enquiry Count  \
# 0                     AURA_AURA 1.0 Turbo GDI MT (SX+)             69
# 1                              AURA_AURA 1.2AMT CRDi S             48
# 2                            AURA_AURA 1.2AMT CRDi SX+             52
# 3                             AURA_AURA 1.2AMT Kappa S            310
# 4                           AURA_AURA 1.2AMT Kappa SX+            296
# 5                                AURA_AURA 1.2MT CNG S           1714
# 6                               AURA_AURA 1.2MT CRDi S            127
# 7                           AURA_AURA 1.2MT CRDi SX(O)             50
# 8                              AURA_AURA 1.2MT Kappa E            593
# 9                              AURA_AURA 1.2MT Kappa S            404
# 10                            AURA_AURA 1.2MT Kappa SX            476
# 11                         AURA_AURA 1.2MT kappa SX(O)            146
# 12         Alcazar_ALCAZAR 1.5 AT Platinum(O) 6 Seater            131
# 13         Alcazar_ALCAZAR 1.5 AT Prestige(O) 7 Seater            305
# 14        Alcazar_ALCAZAR 1.5 AT Signature(O) 6 Seater            261
# 15   Alcazar_ALCAZAR 1.5 AT Signature(O) 6 Seater D...            194
# 16            Alcazar_ALCAZAR 1.5 MT Platinum 7 Seater            321
# 17            Alcazar_ALCAZAR 1.5 MT Prestige 6 Seater            106
# 18            Alcazar_ALCAZAR 1.5 MT Prestige 7 Seater            293
# 19           Alcazar_ALCAZAR 1.5 MT Signature 6 Seater             98
# 20   Alcazar_ALCAZAR 1.5 MT Signature 6 Seater Dual...             48
# 21         Alcazar_ALCAZAR 2.0 AT Platinum(O) 6 Seater            156
# 22         Alcazar_ALCAZAR 2.0 AT Prestige(O) 6 Seater            131
# 23        Alcazar_ALCAZAR 2.0 AT Signature(O) 6 Seater            401
# 24   Alcazar_ALCAZAR 2.0 AT Signature(O) 6 Seater D...            239
# 25            Alcazar_ALCAZAR 2.0 MT Platinum 7 Seater            296
# 26            Alcazar_ALCAZAR 2.0 MT Prestige 6 Seater             81
# 27            Alcazar_ALCAZAR 2.0 MT Prestige 7 Seater            192
# 28           Alcazar_ALCAZAR 2.0 MT Signature 6 Seater             78
# 29   Alcazar_ALCAZAR 2.0 MT Signature 6 Seater Dual...             29
# ..                                                 ...            ...
# 178                    Venue_VENUE 1.0 Turbo GDI DCT S            702
# 179                  Venue_VENUE 1.0 Turbo GDI DCT SX+            779
# 180               Venue_VENUE 1.0 Turbo GDI DCT SX+ DT            335
# 181                     Venue_VENUE 1.0 Turbo GDI MT S            428
# 182                    Venue_VENUE 1.0 Turbo GDI MT SX            957
# 184                 Venue_VENUE 1.0 Turbo GDI MT SX(O)            273
# 185              Venue_VENUE 1.0 Turbo GDI MT SX(O) DT             80
# 183          Venue_VENUE 1.0 Turbo GDI MT SX Dual Tone             60
# 186                    Venue_VENUE 1.0 Turbo GDI iMT S             59
# 187                   Venue_VENUE 1.0 Turbo GDI iMT SX            196
# 189                Venue_VENUE 1.0 Turbo GDI iMT SX(O)            182
# 190             Venue_VENUE 1.0 Turbo GDI iMT SX(O) DT             92
# 188                Venue_VENUE 1.0 Turbo GDI iMT SX DT            111
# 191                         Venue_VENUE 1.2 Kappa MT E           1470
# 192                         Venue_VENUE 1.2 Kappa MT S           1965
# 193                        Venue_VENUE 1.2 Kappa MT S+            747
# 194                          Venue_VENUE 1.4 CRDi MT E             23
# 195                          Venue_VENUE 1.4 CRDi MT S             26
# 196                         Venue_VENUE 1.4 CRDi MT SX             47
# 198                      Venue_VENUE 1.4 CRDi MT SX(O)             19
# 199                   Venue_VENUE 1.4 CRDi MT SX(O) DT              4
# 197               Venue_VENUE 1.4 CRDi MT SX Dual Tone             10
# 200                          Venue_VENUE 1.5 CRDi MT E            421
# 201                          Venue_VENUE 1.5 CRDi MT S            315
# 202                         Venue_VENUE 1.5 CRDi MT SX            771
# 204                      Venue_VENUE 1.5 CRDi MT SX(O)            225
# 205            Venue_VENUE 1.5 CRDi MT SX(O) Dual Tone            100
# 203               Venue_VENUE 1.5 CRDi MT SX Dual Tone            104
# 206                                 Xcent_Xcent AUTO S              1
# 207                      Xcent_Xcent VTVT Prime T+ CNG              1
#
#                                            model_var
# 0                        AURA_AURA1.0TurboGDIMT(SX+)
# 1                               AURA_AURA1.2AMTCRDiS
# 2                             AURA_AURA1.2AMTCRDiSX+
# 3                              AURA_AURA1.2AMTKappaS
# 4                            AURA_AURA1.2AMTKappaSX+
# 5                                 AURA_AURA1.2MTCNGS
# 6                                AURA_AURA1.2MTCRDiS
# 7                            AURA_AURA1.2MTCRDiSX(O)
# 8                               AURA_AURA1.2MTKappaE
# 9                               AURA_AURA1.2MTKappaS
# 10                             AURA_AURA1.2MTKappaSX
# 11                          AURA_AURA1.2MTkappaSX(O)
# 12            Alcazar_ALCAZAR1.5ATPlatinum(O)6Seater
# 13            Alcazar_ALCAZAR1.5ATPrestige(O)7Seater
# 14           Alcazar_ALCAZAR1.5ATSignature(O)6Seater
# 15   Alcazar_ALCAZAR1.5ATSignature(O)6SeaterDualTone
# 16               Alcazar_ALCAZAR1.5MTPlatinum7Seater
# 17               Alcazar_ALCAZAR1.5MTPrestige6Seater
# 18               Alcazar_ALCAZAR1.5MTPrestige7Seater
# 19              Alcazar_ALCAZAR1.5MTSignature6Seater
# 20      Alcazar_ALCAZAR1.5MTSignature6SeaterDualTone
# 21            Alcazar_ALCAZAR2.0ATPlatinum(O)6Seater
# 22            Alcazar_ALCAZAR2.0ATPrestige(O)6Seater
# 23           Alcazar_ALCAZAR2.0ATSignature(O)6Seater
# 24   Alcazar_ALCAZAR2.0ATSignature(O)6SeaterDualTone
# 25               Alcazar_ALCAZAR2.0MTPlatinum7Seater
# 26               Alcazar_ALCAZAR2.0MTPrestige6Seater
# 27               Alcazar_ALCAZAR2.0MTPrestige7Seater
# 28              Alcazar_ALCAZAR2.0MTSignature6Seater
# 29      Alcazar_ALCAZAR2.0MTSignature6SeaterDualTone
# ..                                               ...
# 178                       Venue_VENUE1.0TurboGDIDCTS
# 179                     Venue_VENUE1.0TurboGDIDCTSX+
# 180                   Venue_VENUE1.0TurboGDIDCTSX+DT
# 181                        Venue_VENUE1.0TurboGDIMTS
# 182                       Venue_VENUE1.0TurboGDIMTSX
# 184                    Venue_VENUE1.0TurboGDIMTSX(O)
# 185                  Venue_VENUE1.0TurboGDIMTSX(O)DT
# 183               Venue_VENUE1.0TurboGDIMTSXDualTone
# 186                       Venue_VENUE1.0TurboGDIiMTS
# 187                      Venue_VENUE1.0TurboGDIiMTSX
# 189                   Venue_VENUE1.0TurboGDIiMTSX(O)
# 190                 Venue_VENUE1.0TurboGDIiMTSX(O)DT
# 188                    Venue_VENUE1.0TurboGDIiMTSXDT
# 191                           Venue_VENUE1.2KappaMTE
# 192                           Venue_VENUE1.2KappaMTS
# 193                          Venue_VENUE1.2KappaMTS+
# 194                            Venue_VENUE1.4CRDiMTE
# 195                            Venue_VENUE1.4CRDiMTS
# 196                           Venue_VENUE1.4CRDiMTSX
# 198                        Venue_VENUE1.4CRDiMTSX(O)
# 199                      Venue_VENUE1.4CRDiMTSX(O)DT
# 197                   Venue_VENUE1.4CRDiMTSXDualTone
# 200                            Venue_VENUE1.5CRDiMTE
# 201                            Venue_VENUE1.5CRDiMTS
# 202                           Venue_VENUE1.5CRDiMTSX
# 204                        Venue_VENUE1.5CRDiMTSX(O)
# 205                Venue_VENUE1.5CRDiMTSX(O)DualTone
# 203                   Venue_VENUE1.5CRDiMTSXDualTone
# 206                                 Xcent_XcentAUTOS
# 207                        Xcent_XcentVTVTPrimeT+CNG
#
# [208 rows x 3 columns]

# %%
BEV_Type_enq['Enquiry Count'].sum()
# Out:
# 81195

# %%
BEV_Type_enq[['MODEL','VARIANT']] = BEV_Type_enq["model_var_raw"].str.split("_",expand=True)
BEV_Type_enq["Variant Type"] = BEV_Type_enq["model_var"].map(var_dict)
BEV_Type_enq["Body Type"] = BEV_Type_enq["MODEL"].map(body_dict) 

BEV_Type_enq["Fuel Type"] = 'Petrol'
BEV_Type_enq["Fuel Type"] = np.where(BEV_Type_enq["model_var"].str.contains(pat = 'CRDi'),'Diesel',BEV_Type_enq["Fuel Type"])
BEV_Type_enq["Fuel Type"] = np.where(BEV_Type_enq["model_var"].str.contains(pat = 'CNG'),'CNG',BEV_Type_enq["Fuel Type"])
BEV_Type_enq["Fuel Type"] = np.where(BEV_Type_enq["model_var"].str.contains(pat = 'Electric'),'Electric',BEV_Type_enq["Fuel Type"])
BEV_Type_enq


BEV_Type_enq["MODEL"]=np.where((BEV_Type_enq["MODEL"]=="New i20"),"Elite i20",BEV_Type_enq["MODEL"])
BEV_Type_enq["MODEL"]=np.where((BEV_Type_enq["MODEL"]=="Next Gen Verna"),"New Verna",BEV_Type_enq["MODEL"])

# %%
BEV_Type_enq['Enquiry Count'].sum()
# Out:
# 81195

# %%
variant_enq_final1 = Trend_Analysis1(BEV_Type_enq,['Variant Type','Enquiry Count'],'Variant Type')
body_enq_final1 = Trend_Analysis1(BEV_Type_enq,['Body Type','Enquiry Count'],'Body Type')
fuel_enq_final1 = Trend_Analysis1(BEV_Type_enq,['Fuel Type','Enquiry Count'],'Fuel Type')

model_enq_final1 = Trend_Analysis1(BEV_Type_enq,['MODEL','Enquiry Count'],'MODEL')
model_enq_final1
# Out:
#              MODEL  Enquiry Count
# 0             AURA           4285
# 1          Alcazar           3360
# 2      All New i20           7256
# 3            CRETA            175
# 4          Elantra            192
# 5        Elite i20           4193
# 6        Grand i10           1987
# 7   Grand i10 NIOS           9011
# 8       I20 ACTIVE              3
# 9          Kona EV            283
# 10       New Creta          31027
# 11       New Verna           4307
# 12          Santro           4286
# 13          Tucson            327
# 14           Venue          10501
# 15           Xcent              2

# %%
variant_enq_final1['Enquiry Count'].sum()
# Out:
# 67011

# %%
81307-67106
# Out:
# 14201

# %%
model_enq_final1["MODEL_lower"] = model_enq_final1["MODEL"].str.lower()
model_enq_final1
# Out:
#              MODEL  Enquiry Count     MODEL_lower
# 0             AURA           4285            aura
# 1          Alcazar           3360         alcazar
# 2      All New i20           7256     all new i20
# 3            CRETA            175           creta
# 4          Elantra            192         elantra
# 5        Elite i20           4193       elite i20
# 6        Grand i10           1987       grand i10
# 7   Grand i10 NIOS           9011  grand i10 nios
# 8       I20 ACTIVE              3      i20 active
# 9          Kona EV            283         kona ev
# 10       New Creta          31027       new creta
# 11       New Verna           4307       new verna
# 12          Santro           4286          santro
# 13          Tucson            327          tucson
# 14           Venue          10501           venue
# 15           Xcent              2           xcent

# %%
model_enq_final1['Enquiry Count'].sum()
# Out:
# 81195

# %%
print (fuel_enq_final1)
print (body_enq_final1)
print (variant_enq_final1)
# Out:
#   Fuel Type  Enquiry Count
# 0       CNG           3569
# 1    Diesel          18715
# 2  Electric            283
# 3    Petrol          58628
#    Body Type  Enquiry Count
# 0  HatchBack          26733
# 1        SUV          45215
# 2      Sedan           9069
#   Variant Type  Enquiry Count
# 0         High          11543
# 1          Low          28461
# 2          Mid          27007

# %%
GDMS_Booking.shape
# Out:
# (7768, 27)

# %%
GDMS_Booking.columns
# Out:
# Index(['CSPM_DLR_NAME', 'EQRY_DLR_NO', 'EQRY_ENQRY_NO', 'EQRY_DATE',
#        'EQRY_STAT', 'EQRY_STATUS_NM', 'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME',
#        'EQRY_NEWCAR_YN', 'EQRY_REF_NO', 'CTB_BOOKING_Y', 'RETAIL_DATE',
#        'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE', 'BKNG_DATE_NEW',
#        'BKNG_DATE_NEWYear', 'BKNG_DATE_NEWMonth', 'BKNG_DATE_NEWWeek',
#        'BKNG_DATE_NEWDay', 'BKNG_DATE_NEWhour', 'BKNG_DATE_NEWDayofweek',
#        'BKNG_DATE_NEWDayofyear', 'BKNG_DATE_NEWweekofyear',
#        'BKNG_DATE_NEWMonthName', 'BKNG_DATE_NEWMonthKey',
#        'BKNG_DATE_NEWWeekKey'],
#       dtype='object')

# %%
BEVM_Type_book = pd.merge(CTB_data, GDMS_Booking, left_on=['ORDER_ID'],right_on = ['EQRY_REF_NO'], how = 'outer',indicator=True)
print("BEVM_Type_book" , BEVM_Type_book.shape)
BEVM_Type_book['_merge'].value_counts()
# Out:
# BEVM_Type_book (81219, 73)
# left_only     73451
# both           7744
# right_only       24
# Name: _merge, dtype: int64

# %%
BEVM_Type_book_match = BEVM_Type_book[BEVM_Type_book['_merge']!="left_only"][["ORDER_ID","MODEL","VARIANT","EQRY_ENQRY_NO","EQCR_MODEL_NAME","BKNG_DATE_NEW","CTB_BOOKING_Y","RETAIL_DATE","EQRY_STAT","_merge"]]
BEVM_Type_book_match
# Out:
#                   ORDER_ID           MODEL  \
# 31     ORD2021011715869051       New Creta
# 41     ORD2021011211481489       New Creta
# 44     ORD2021011312548952           Venue
# 46     ORD2021011512650640       New Creta
# 50     ORD2021011814676334       New Creta
# 54     ORD2021011611328339       New Creta
# 65     ORD2021011617464144       New Creta
# 66     ORD2021011118709577       New Creta
# 112    ORD2021011517723501           Venue
# 115    ORD2021011612031740  Next Gen Verna
# 128    ORD2021011812328072       New Creta
# 135    ORD2021011311065222       New Creta
# 136    ORD2021011711898574       New Creta
# 139    ORD2021011517251717            AURA
# 144    ORD2021011311101547  Next Gen Verna
# 159    ORD2021011319892056       New Creta
# 170    ORD2021011417693548       New Creta
# 173    ORD2021011817534778           Venue
# 176    ORD2021011714703091       New Creta
# 182    ORD2021011514918401       New Creta
# 186    ORD2021011612456763       New Creta
# 189    ORD2021011814938132  Grand i10 NIOS
# 205    ORD2021012411750026       New Creta
# 206    ORD2021011812133705       New Creta
# 215    ORD2021011417209149           Venue
# 216    ORD2021011614067229  Next Gen Verna
# 237    ORD2021011215280484           Venue
# 247    ORD2021011517658432           Venue
# 251    ORD2021012415527190       New Creta
# 271    ORD2021011518449027  Next Gen Verna
# ...                    ...             ...
# 81114  ORD2021062914276631       New Creta
# 81117  ORD2021062911499324         Alcazar
# 81133  ORD2021062919737139         Alcazar
# 81150  ORD2021062911811144  Grand i10 NIOS
# 81158  ORD2021063018847694         Alcazar
# 81181  ORD2021063016796788       New Creta
# 81195                  NaN             NaN
# 81196                  NaN             NaN
# 81197                  NaN             NaN
# 81198                  NaN             NaN
# 81199                  NaN             NaN
# 81200                  NaN             NaN
# 81201                  NaN             NaN
# 81202                  NaN             NaN
# 81203                  NaN             NaN
# 81204                  NaN             NaN
# 81205                  NaN             NaN
# 81206                  NaN             NaN
# 81207                  NaN             NaN
# 81208                  NaN             NaN
# 81209                  NaN             NaN
# 81210                  NaN             NaN
# 81211                  NaN             NaN
# 81212                  NaN             NaN
# 81213                  NaN             NaN
# 81214                  NaN             NaN
# 81215                  NaN             NaN
# 81216                  NaN             NaN
# 81217                  NaN             NaN
# 81218                  NaN             NaN
#
#                                               VARIANT EQRY_ENQRY_NO  \
# 31                                 Creta 1.5 MPi MT E    E202102707
# 41                                Creta 1.5 CRDi MT E    E202102088
# 44                              VENUE 1.2 Kappa MT S+    E202100032
# 46                                Creta 1.5 CRDi MT E    E202114388
# 50                                Creta 1.5 CRDi MT E    E202109507
# 54                         Creta 1.4 Turbo GDi DCT SX    E202102589
# 65                                Creta 1.5 CRDi MT E    E202102600
# 66                                Creta 1.5 CRDi MT E    E202101953
# 112                              VENUE 1.2 Kappa MT E    E202102423
# 115                              VERNA 1.5 CRDi AT SX    E202102523
# 128                           Creta 1.5 MPi IVT SX(O)    E202103009
# 135                           Creta 1.5 CRDi AT SX(O)    E202102100
# 136                           Creta 1.5 CRDi MT SX(O)    E202102549
# 139                                  AURA 1.2MT CNG S    E202102423
# 144                               VERNA 1.5 MPI MT SX    E202102200
# 159                                Creta 1.5 MPi MT S    E202101669
# 170                               Creta 1.5 CRDi MT E    E202102049
# 173                             VENUE 1.2 Kappa MT S+    E202102442
# 176                               Creta 1.5 CRDi MT E    E202102749
# 182                               Creta 1.5 CRDi MT E    E202102258
# 186                               Creta 1.5 MPi MT EX    E202102574
# 189                 Grand i10 NIOS 1.2MT Kappa Sportz    E202103158
# 205                               Creta 1.5 CRDi MT E    E202103723
# 206                               Creta 1.5 CRDi MT E    E202102517
# 215                              VENUE 1.2 Kappa MT E    E202102267
# 216                               VERNA 1.5 MPI MT SX    E202102743
# 237                     VENUE 1.0 Turbo GDI iMT SX(O)    E202101983
# 247                             VENUE 1.2 Kappa MT S+    E202102403
# 251                               Creta 1.5 CRDi MT E    E202104189
# 271                               VERNA 1.5 MPI MT SX    E202100754
# ...                                               ...           ...
# 81114                             Creta 1.5 MPi MT SX    E202124589
# 81117                ALCAZAR 2.0 MT Platinum 7 Seater    E202124396
# 81133                ALCAZAR 1.5 MT Platinum 7 Seater    E202124344
# 81150                  Grand i10 NIOS 1.2MT CNG Magna    E202124433
# 81158  ALCAZAR 2.0 AT Signature(O) 6 Seater Dual Tone    E202124784
# 81181                            Creta 1.5 CRDi AT SX    E202124721
# 81195                                             NaN    E202015671
# 81196                                             NaN    E202013723
# 81197                                             NaN    E202014252
# 81198                                             NaN    E202020927
# 81199                                             NaN    E202015583
# 81200                                             NaN    E202015472
# 81201                                             NaN    E202015467
# 81202                                             NaN    E202014045
# 81203                                             NaN    E202015348
# 81204                                             NaN    E202014713
# 81205                                             NaN    E202015618
# 81206                                             NaN    E202026223
# 81207                                             NaN    E202014081
# 81208                                             NaN    E202014731
# 81209                                             NaN    E202015691
# 81210                                             NaN    E202014076
# 81211                                             NaN    E202012050
# 81212                                             NaN    E202027099
# 81213                                             NaN    E202025890
# 81214                                             NaN    E202021760
# 81215                                             NaN    E202014846
# 81216                                             NaN    E202025900
# 81217                                             NaN    E202011382
# 81218                                             NaN    E202027539
#
#       EQCR_MODEL_NAME BKNG_DATE_NEW CTB_BOOKING_Y  RETAIL_DATE  EQRY_STAT  \
# 31          New Creta    2021-01-27             N   20210305.0       45.0
# 41          New Creta    2021-01-12             Y          NaN       60.0
# 44              Venue    2021-02-18             N   20210218.0       45.0
# 46          New Creta    2021-03-28             Y          NaN       20.0
# 50          New Creta    2021-02-24             Y          NaN       20.0
# 54          New Creta    2021-01-16             Y          NaN       20.0
# 65          New Creta    2021-01-16             Y          NaN       20.0
# 66          New Creta    2021-01-28             N          NaN       20.0
# 112             Venue    2021-01-15             N   20210120.0       45.0
# 115    Next Gen Verna    2021-01-16             Y          NaN       60.0
# 128         New Creta    2021-01-18             N          NaN       60.0
# 135         New Creta    2021-02-27             N          NaN       60.0
# 136         New Creta    2021-01-17             Y          NaN       20.0
# 139              AURA    2021-01-15             Y          NaN       20.0
# 144    Next Gen Verna    2021-01-13             N   20210122.0       45.0
# 159         New Creta    2021-03-23             N          NaN       20.0
# 170         New Creta    2021-01-14             Y          NaN       20.0
# 173             Venue    2021-01-18             Y          NaN       20.0
# 176         New Creta    2021-01-17             Y          NaN       20.0
# 182         New Creta    2021-01-19             N          NaN       20.0
# 186         New Creta    2021-01-16             Y          NaN       20.0
# 189    Grand i10 NIOS    2021-02-17             N   20210217.0       45.0
# 205         New Creta    2021-01-27             N          NaN       20.0
# 206         New Creta    2021-01-18             Y          NaN       20.0
# 215             Venue    2021-01-14             Y   20210115.0       45.0
# 216    Next Gen Verna    2021-01-16             Y   20210304.0       45.0
# 237             Venue    2021-02-02             N          NaN       20.0
# 247             Venue    2021-01-26             Y   20210128.0       45.0
# 251         New Creta    2021-01-25             N          NaN       20.0
# 271    Next Gen Verna    2021-02-26             N   20210226.0       45.0
# ...               ...           ...           ...          ...        ...
# 81114       New Creta    2021-06-29             Y          NaN       20.0
# 81117         Alcazar    2021-06-29             Y          NaN       20.0
# 81133         Alcazar    2021-06-30             N          NaN       20.0
# 81150  Grand i10 NIOS    2021-06-29             Y          NaN       20.0
# 81158         Alcazar    2021-06-30             Y          NaN       20.0
# 81181       New Creta    2021-06-30             Y          NaN       20.0
# 81195       New Creta    2020-06-17             N          NaN       60.0
# 81196       New Creta    2020-04-18             Y          NaN       60.0
# 81197       New Creta    2020-06-21             N   20200720.0       45.0
# 81198       New Creta    2020-06-26             Y          NaN       91.0
# 81199            AURA    2020-04-26             Y          NaN       60.0
# 81200  Grand i10 NIOS    2020-06-12             N   20200612.0       45.0
# 81201         New i20    2020-06-23             N   20200623.0       45.0
# 81202       New Creta    2020-04-23             Y          NaN       60.0
# 81203       New Creta    2020-05-06             Y   20200629.0       45.0
# 81204       New Creta    2020-05-30             N   20200530.0       45.0
# 81205       New Creta    2020-04-30             N          NaN       60.0
# 81206       New Creta    2020-08-05             N          NaN       60.0
# 81207         New i20    2020-06-29             N   20200629.0       45.0
# 81208       New Creta    2020-05-24             N          NaN       60.0
# 81209       New Creta    2020-05-14             N   20200514.0       45.0
# 81210       Grand i10    2020-05-31             N          NaN       60.0
# 81211          Santro    2020-06-29             N          NaN       60.0
# 81212            AURA    2020-08-18             N   20200911.0       45.0
# 81213       New Creta    2020-08-06             N   20200822.0       45.0
# 81214           Venue    2020-08-14             N   20200814.0       45.0
# 81215            AURA    2020-07-16             N          NaN       60.0
# 81216       New Creta    2020-10-02             N          NaN       60.0
# 81217       New Creta    2020-09-21             Y          NaN       91.0
# 81218       New Creta    2020-08-27             N   20201023.0       45.0
#
#            _merge
# 31           both
# 41           both
# 44           both
# 46           both
# 50           both
# 54           both
# 65           both
# 66           both
# 112          both
# 115          both
# 128          both
# 135          both
# 136          both
# 139          both
# 144          both
# 159          both
# 170          both
# 173          both
# 176          both
# 182          both
# 186          both
# 189          both
# 205          both
# 206          both
# 215          both
# 216          both
# 237          both
# 247          both
# 251          both
# 271          both
# ...           ...
# 81114        both
# 81117        both
# 81133        both
# 81150        both
# 81158        both
# 81181        both
# 81195  right_only
# 81196  right_only
# 81197  right_only
# 81198  right_only
# 81199  right_only
# 81200  right_only
# 81201  right_only
# 81202  right_only
# 81203  right_only
# 81204  right_only
# 81205  right_only
# 81206  right_only
# 81207  right_only
# 81208  right_only
# 81209  right_only
# 81210  right_only
# 81211  right_only
# 81212  right_only
# 81213  right_only
# 81214  right_only
# 81215  right_only
# 81216  right_only
# 81217  right_only
# 81218  right_only
#
# [7768 rows x 10 columns]

# %%
BEVM_Type_book_match1 = BEVM_Type_book_match.drop_duplicates(subset=['EQRY_ENQRY_NO',"ORDER_ID"], keep='last')
BEVM_Type_book_match1.shape
# Out:
# (7768, 10)

# %%
BEVM_Type_book_match1.head()
# Out:
#                ORDER_ID      MODEL                VARIANT EQRY_ENQRY_NO  \
# 31  ORD2021011715869051  New Creta     Creta 1.5 MPi MT E    E202102707
# 41  ORD2021011211481489  New Creta    Creta 1.5 CRDi MT E    E202102088
# 44  ORD2021011312548952      Venue  VENUE 1.2 Kappa MT S+    E202100032
# 46  ORD2021011512650640  New Creta    Creta 1.5 CRDi MT E    E202114388
# 50  ORD2021011814676334  New Creta    Creta 1.5 CRDi MT E    E202109507
#
#    EQCR_MODEL_NAME BKNG_DATE_NEW CTB_BOOKING_Y  RETAIL_DATE  EQRY_STAT _merge
# 31       New Creta    2021-01-27             N   20210305.0       45.0   both
# 41       New Creta    2021-01-12             Y          NaN       60.0   both
# 44           Venue    2021-02-18             N   20210218.0       45.0   both
# 46       New Creta    2021-03-28             Y          NaN       20.0   both
# 50       New Creta    2021-02-24             Y          NaN       20.0   both

# %%
#BEVM_Type_book_match1[['MODEL','VARIANT']] = BEVM_Type_book_match1["model_var"].str.split("_",expand=True)
BEVM_Type_book_match1["model_var"] = BEVM_Type_book_match1["MODEL"] + "_"+BEVM_Type_book_match1["VARIANT"]
BEVM_Type_book_match1.model_var = BEVM_Type_book_match1.model_var.str.replace(' ', '')
BEVM_Type_book_match1["Variant Type"] = BEVM_Type_book_match1["model_var"].map(var_dict)
BEVM_Type_book_match1["Body Type"] = BEVM_Type_book_match1["EQCR_MODEL_NAME"].map(body_dict) 

BEVM_Type_book_match1["Fuel Type"] = 'Petrol'
BEVM_Type_book_match1["Fuel Type"] = np.where(BEVM_Type_book_match1["model_var"].str.contains(pat = 'CRDi'),'Diesel',BEVM_Type_book_match1["Fuel Type"])
BEVM_Type_book_match1["Fuel Type"] = np.where(BEVM_Type_book_match1["model_var"].str.contains(pat = 'CNG'),'CNG',BEVM_Type_book_match1["Fuel Type"])
BEVM_Type_book_match1["Fuel Type"] = np.where(BEVM_Type_book_match1["model_var"].str.contains(pat = 'Electric'),'Electric',BEVM_Type_book_match1["Fuel Type"])
BEVM_Type_book_match1["Fuel Type"] = np.where(BEVM_Type_book_match1["model_var"].str.contains(pat = 'NULL'),'Petrol',BEVM_Type_book_match1["Fuel Type"])

BEVM_Type_book_match1["EQCR_MODEL_NAME"]=np.where((BEVM_Type_book_match1["EQCR_MODEL_NAME"]=="New i20"),"All New i20",BEVM_Type_book_match1["EQCR_MODEL_NAME"])
BEVM_Type_book_match1["EQCR_MODEL_NAME"]=np.where((BEVM_Type_book_match1["EQCR_MODEL_NAME"]=="Next Gen Verna"),"New Verna",BEVM_Type_book_match1["EQCR_MODEL_NAME"])


BEVM_Type_book_match1
# Out:
#                   ORDER_ID           MODEL  \
# 31     ORD2021011715869051       New Creta
# 41     ORD2021011211481489       New Creta
# 44     ORD2021011312548952           Venue
# 46     ORD2021011512650640       New Creta
# 50     ORD2021011814676334       New Creta
# 54     ORD2021011611328339       New Creta
# 65     ORD2021011617464144       New Creta
# 66     ORD2021011118709577       New Creta
# 112    ORD2021011517723501           Venue
# 115    ORD2021011612031740  Next Gen Verna
# 128    ORD2021011812328072       New Creta
# 135    ORD2021011311065222       New Creta
# 136    ORD2021011711898574       New Creta
# 139    ORD2021011517251717            AURA
# 144    ORD2021011311101547  Next Gen Verna
# 159    ORD2021011319892056       New Creta
# 170    ORD2021011417693548       New Creta
# 173    ORD2021011817534778           Venue
# 176    ORD2021011714703091       New Creta
# 182    ORD2021011514918401       New Creta
# 186    ORD2021011612456763       New Creta
# 189    ORD2021011814938132  Grand i10 NIOS
# 205    ORD2021012411750026       New Creta
# 206    ORD2021011812133705       New Creta
# 215    ORD2021011417209149           Venue
# 216    ORD2021011614067229  Next Gen Verna
# 237    ORD2021011215280484           Venue
# 247    ORD2021011517658432           Venue
# 251    ORD2021012415527190       New Creta
# 271    ORD2021011518449027  Next Gen Verna
# ...                    ...             ...
# 81114  ORD2021062914276631       New Creta
# 81117  ORD2021062911499324         Alcazar
# 81133  ORD2021062919737139         Alcazar
# 81150  ORD2021062911811144  Grand i10 NIOS
# 81158  ORD2021063018847694         Alcazar
# 81181  ORD2021063016796788       New Creta
# 81195                  NaN             NaN
# 81196                  NaN             NaN
# 81197                  NaN             NaN
# 81198                  NaN             NaN
# 81199                  NaN             NaN
# 81200                  NaN             NaN
# 81201                  NaN             NaN
# 81202                  NaN             NaN
# 81203                  NaN             NaN
# 81204                  NaN             NaN
# 81205                  NaN             NaN
# 81206                  NaN             NaN
# 81207                  NaN             NaN
# 81208                  NaN             NaN
# 81209                  NaN             NaN
# 81210                  NaN             NaN
# 81211                  NaN             NaN
# 81212                  NaN             NaN
# 81213                  NaN             NaN
# 81214                  NaN             NaN
# 81215                  NaN             NaN
# 81216                  NaN             NaN
# 81217                  NaN             NaN
# 81218                  NaN             NaN
#
#                                               VARIANT EQRY_ENQRY_NO  \
# 31                                 Creta 1.5 MPi MT E    E202102707
# 41                                Creta 1.5 CRDi MT E    E202102088
# 44                              VENUE 1.2 Kappa MT S+    E202100032
# 46                                Creta 1.5 CRDi MT E    E202114388
# 50                                Creta 1.5 CRDi MT E    E202109507
# 54                         Creta 1.4 Turbo GDi DCT SX    E202102589
# 65                                Creta 1.5 CRDi MT E    E202102600
# 66                                Creta 1.5 CRDi MT E    E202101953
# 112                              VENUE 1.2 Kappa MT E    E202102423
# 115                              VERNA 1.5 CRDi AT SX    E202102523
# 128                           Creta 1.5 MPi IVT SX(O)    E202103009
# 135                           Creta 1.5 CRDi AT SX(O)    E202102100
# 136                           Creta 1.5 CRDi MT SX(O)    E202102549
# 139                                  AURA 1.2MT CNG S    E202102423
# 144                               VERNA 1.5 MPI MT SX    E202102200
# 159                                Creta 1.5 MPi MT S    E202101669
# 170                               Creta 1.5 CRDi MT E    E202102049
# 173                             VENUE 1.2 Kappa MT S+    E202102442
# 176                               Creta 1.5 CRDi MT E    E202102749
# 182                               Creta 1.5 CRDi MT E    E202102258
# 186                               Creta 1.5 MPi MT EX    E202102574
# 189                 Grand i10 NIOS 1.2MT Kappa Sportz    E202103158
# 205                               Creta 1.5 CRDi MT E    E202103723
# 206                               Creta 1.5 CRDi MT E    E202102517
# 215                              VENUE 1.2 Kappa MT E    E202102267
# 216                               VERNA 1.5 MPI MT SX    E202102743
# 237                     VENUE 1.0 Turbo GDI iMT SX(O)    E202101983
# 247                             VENUE 1.2 Kappa MT S+    E202102403
# 251                               Creta 1.5 CRDi MT E    E202104189
# 271                               VERNA 1.5 MPI MT SX    E202100754
# ...                                               ...           ...
# 81114                             Creta 1.5 MPi MT SX    E202124589
# 81117                ALCAZAR 2.0 MT Platinum 7 Seater    E202124396
# 81133                ALCAZAR 1.5 MT Platinum 7 Seater    E202124344
# 81150                  Grand i10 NIOS 1.2MT CNG Magna    E202124433
# 81158  ALCAZAR 2.0 AT Signature(O) 6 Seater Dual Tone    E202124784
# 81181                            Creta 1.5 CRDi AT SX    E202124721
# 81195                                             NaN    E202015671
# 81196                                             NaN    E202013723
# 81197                                             NaN    E202014252
# 81198                                             NaN    E202020927
# 81199                                             NaN    E202015583
# 81200                                             NaN    E202015472
# 81201                                             NaN    E202015467
# 81202                                             NaN    E202014045
# 81203                                             NaN    E202015348
# 81204                                             NaN    E202014713
# 81205                                             NaN    E202015618
# 81206                                             NaN    E202026223
# 81207                                             NaN    E202014081
# 81208                                             NaN    E202014731
# 81209                                             NaN    E202015691
# 81210                                             NaN    E202014076
# 81211                                             NaN    E202012050
# 81212                                             NaN    E202027099
# 81213                                             NaN    E202025890
# 81214                                             NaN    E202021760
# 81215                                             NaN    E202014846
# 81216                                             NaN    E202025900
# 81217                                             NaN    E202011382
# 81218                                             NaN    E202027539
#
#       EQCR_MODEL_NAME BKNG_DATE_NEW CTB_BOOKING_Y  RETAIL_DATE  EQRY_STAT  \
# 31          New Creta    2021-01-27             N   20210305.0       45.0
# 41          New Creta    2021-01-12             Y          NaN       60.0
# 44              Venue    2021-02-18             N   20210218.0       45.0
# 46          New Creta    2021-03-28             Y          NaN       20.0
# 50          New Creta    2021-02-24             Y          NaN       20.0
# 54          New Creta    2021-01-16             Y          NaN       20.0
# 65          New Creta    2021-01-16             Y          NaN       20.0
# 66          New Creta    2021-01-28             N          NaN       20.0
# 112             Venue    2021-01-15             N   20210120.0       45.0
# 115         New Verna    2021-01-16             Y          NaN       60.0
# 128         New Creta    2021-01-18             N          NaN       60.0
# 135         New Creta    2021-02-27             N          NaN       60.0
# 136         New Creta    2021-01-17             Y          NaN       20.0
# 139              AURA    2021-01-15             Y          NaN       20.0
# 144         New Verna    2021-01-13             N   20210122.0       45.0
# 159         New Creta    2021-03-23             N          NaN       20.0
# 170         New Creta    2021-01-14             Y          NaN       20.0
# 173             Venue    2021-01-18             Y          NaN       20.0
# 176         New Creta    2021-01-17             Y          NaN       20.0
# 182         New Creta    2021-01-19             N          NaN       20.0
# 186         New Creta    2021-01-16             Y          NaN       20.0
# 189    Grand i10 NIOS    2021-02-17             N   20210217.0       45.0
# 205         New Creta    2021-01-27             N          NaN       20.0
# 206         New Creta    2021-01-18             Y          NaN       20.0
# 215             Venue    2021-01-14             Y   20210115.0       45.0
# 216         New Verna    2021-01-16             Y   20210304.0       45.0
# 237             Venue    2021-02-02             N          NaN       20.0
# 247             Venue    2021-01-26             Y   20210128.0       45.0
# 251         New Creta    2021-01-25             N          NaN       20.0
# 271         New Verna    2021-02-26             N   20210226.0       45.0
# ...               ...           ...           ...          ...        ...
# 81114       New Creta    2021-06-29             Y          NaN       20.0
# 81117         Alcazar    2021-06-29             Y          NaN       20.0
# 81133         Alcazar    2021-06-30             N          NaN       20.0
# 81150  Grand i10 NIOS    2021-06-29             Y          NaN       20.0
# 81158         Alcazar    2021-06-30             Y          NaN       20.0
# 81181       New Creta    2021-06-30             Y          NaN       20.0
# 81195       New Creta    2020-06-17             N          NaN       60.0
# 81196       New Creta    2020-04-18             Y          NaN       60.0
# 81197       New Creta    2020-06-21             N   20200720.0       45.0
# 81198       New Creta    2020-06-26             Y          NaN       91.0
# 81199            AURA    2020-04-26             Y          NaN       60.0
# 81200  Grand i10 NIOS    2020-06-12             N   20200612.0       45.0
# 81201     All New i20    2020-06-23             N   20200623.0       45.0
# 81202       New Creta    2020-04-23             Y          NaN       60.0
# 81203       New Creta    2020-05-06             Y   20200629.0       45.0
# 81204       New Creta    2020-05-30             N   20200530.0       45.0
# 81205       New Creta    2020-04-30             N          NaN       60.0
# 81206       New Creta    2020-08-05             N          NaN       60.0
# 81207     All New i20    2020-06-29             N   20200629.0       45.0
# 81208       New Creta    2020-05-24             N          NaN       60.0
# 81209       New Creta    2020-05-14             N   20200514.0       45.0
# 81210       Grand i10    2020-05-31             N          NaN       60.0
# 81211          Santro    2020-06-29             N          NaN       60.0
# 81212            AURA    2020-08-18             N   20200911.0       45.0
# 81213       New Creta    2020-08-06             N   20200822.0       45.0
# 81214           Venue    2020-08-14             N   20200814.0       45.0
# 81215            AURA    2020-07-16             N          NaN       60.0
# 81216       New Creta    2020-10-02             N          NaN       60.0
# 81217       New Creta    2020-09-21             Y          NaN       91.0
# 81218       New Creta    2020-08-27             N   20201023.0       45.0
#
#            _merge                                        model_var  \
# 31           both                          NewCreta_Creta1.5MPiMTE
# 41           both                         NewCreta_Creta1.5CRDiMTE
# 44           both                          Venue_VENUE1.2KappaMTS+
# 46           both                         NewCreta_Creta1.5CRDiMTE
# 50           both                         NewCreta_Creta1.5CRDiMTE
# 54           both                   NewCreta_Creta1.4TurboGDiDCTSX
# 65           both                         NewCreta_Creta1.5CRDiMTE
# 66           both                         NewCreta_Creta1.5CRDiMTE
# 112          both                           Venue_VENUE1.2KappaMTE
# 115          both                    NextGenVerna_VERNA1.5CRDiATSX
# 128          both                     NewCreta_Creta1.5MPiIVTSX(O)
# 135          both                     NewCreta_Creta1.5CRDiATSX(O)
# 136          both                     NewCreta_Creta1.5CRDiMTSX(O)
# 139          both                               AURA_AURA1.2MTCNGS
# 144          both                     NextGenVerna_VERNA1.5MPIMTSX
# 159          both                          NewCreta_Creta1.5MPiMTS
# 170          both                         NewCreta_Creta1.5CRDiMTE
# 173          both                          Venue_VENUE1.2KappaMTS+
# 176          both                         NewCreta_Creta1.5CRDiMTE
# 182          both                         NewCreta_Creta1.5CRDiMTE
# 186          both                         NewCreta_Creta1.5MPiMTEX
# 189          both        Grandi10NIOS_Grandi10NIOS1.2MTKappaSportz
# 205          both                         NewCreta_Creta1.5CRDiMTE
# 206          both                         NewCreta_Creta1.5CRDiMTE
# 215          both                           Venue_VENUE1.2KappaMTE
# 216          both                     NextGenVerna_VERNA1.5MPIMTSX
# 237          both                   Venue_VENUE1.0TurboGDIiMTSX(O)
# 247          both                          Venue_VENUE1.2KappaMTS+
# 251          both                         NewCreta_Creta1.5CRDiMTE
# 271          both                     NextGenVerna_VERNA1.5MPIMTSX
# ...           ...                                              ...
# 81114        both                         NewCreta_Creta1.5MPiMTSX
# 81117        both              Alcazar_ALCAZAR2.0MTPlatinum7Seater
# 81133        both              Alcazar_ALCAZAR1.5MTPlatinum7Seater
# 81150        both           Grandi10NIOS_Grandi10NIOS1.2MTCNGMagna
# 81158        both  Alcazar_ALCAZAR2.0ATSignature(O)6SeaterDualTone
# 81181        both                        NewCreta_Creta1.5CRDiATSX
# 81195  right_only                                              NaN
# 81196  right_only                                              NaN
# 81197  right_only                                              NaN
# 81198  right_only                                              NaN
# 81199  right_only                                              NaN
# 81200  right_only                                              NaN
# 81201  right_only                                              NaN
# 81202  right_only                                              NaN
# 81203  right_only                                              NaN
# 81204  right_only                                              NaN
# 81205  right_only                                              NaN
# 81206  right_only                                              NaN
# 81207  right_only                                              NaN
# 81208  right_only                                              NaN
# 81209  right_only                                              NaN
# 81210  right_only                                              NaN
# 81211  right_only                                              NaN
# 81212  right_only                                              NaN
# 81213  right_only                                              NaN
# 81214  right_only                                              NaN
# 81215  right_only                                              NaN
# 81216  right_only                                              NaN
# 81217  right_only                                              NaN
# 81218  right_only                                              NaN
#
#       Variant Type  Body Type Fuel Type
# 31             Low        SUV    Petrol
# 41             Low        SUV    Diesel
# 44             Mid        SUV    Petrol
# 46             Low        SUV    Diesel
# 50             Low        SUV    Diesel
# 54            High        SUV    Petrol
# 65             Low        SUV    Diesel
# 66             Low        SUV    Diesel
# 112            Low        SUV    Petrol
# 115            NaN      Sedan    Diesel
# 128           High        SUV    Petrol
# 135            Mid        SUV    Diesel
# 136            Mid        SUV    Diesel
# 139            Low      Sedan       CNG
# 144            NaN      Sedan    Petrol
# 159            Low        SUV    Petrol
# 170            Low        SUV    Diesel
# 173            Mid        SUV    Petrol
# 176            Low        SUV    Diesel
# 182            Low        SUV    Diesel
# 186            Mid        SUV    Petrol
# 189            Mid  HatchBack    Petrol
# 205            Low        SUV    Diesel
# 206            Low        SUV    Diesel
# 215            Low        SUV    Petrol
# 216            NaN      Sedan    Petrol
# 237            Mid        SUV    Petrol
# 247            Mid        SUV    Petrol
# 251            Low        SUV    Diesel
# 271            NaN      Sedan    Petrol
# ...            ...        ...       ...
# 81114         High        SUV    Petrol
# 81117          NaN        SUV    Petrol
# 81133          NaN        SUV    Petrol
# 81150          Low  HatchBack       CNG
# 81158          NaN        SUV    Petrol
# 81181          Mid        SUV    Diesel
# 81195          NaN        SUV    Petrol
# 81196          NaN        SUV    Petrol
# 81197          NaN        SUV    Petrol
# 81198          NaN        SUV    Petrol
# 81199          NaN      Sedan    Petrol
# 81200          NaN  HatchBack    Petrol
# 81201          NaN  HatchBack    Petrol
# 81202          NaN        SUV    Petrol
# 81203          NaN        SUV    Petrol
# 81204          NaN        SUV    Petrol
# 81205          NaN        SUV    Petrol
# 81206          NaN        SUV    Petrol
# 81207          NaN  HatchBack    Petrol
# 81208          NaN        SUV    Petrol
# 81209          NaN        SUV    Petrol
# 81210          NaN  HatchBack    Petrol
# 81211          NaN  HatchBack    Petrol
# 81212          NaN      Sedan    Petrol
# 81213          NaN        SUV    Petrol
# 81214          NaN        SUV    Petrol
# 81215          NaN      Sedan    Petrol
# 81216          NaN        SUV    Petrol
# 81217          NaN        SUV    Petrol
# 81218          NaN        SUV    Petrol
#
# [7768 rows x 14 columns]

# %%
BEVM_Type_book_match2 = BEVM_Type_book_match1[BEVM_Type_book_match1['_merge']=="right_only"]
BEVM_Type_book_match2
# Out:
#       ORDER_ID MODEL VARIANT EQRY_ENQRY_NO EQCR_MODEL_NAME BKNG_DATE_NEW  \
# 81195      NaN   NaN     NaN    E202015671       New Creta    2020-06-17
# 81196      NaN   NaN     NaN    E202013723       New Creta    2020-04-18
# 81197      NaN   NaN     NaN    E202014252       New Creta    2020-06-21
# 81198      NaN   NaN     NaN    E202020927       New Creta    2020-06-26
# 81199      NaN   NaN     NaN    E202015583            AURA    2020-04-26
# 81200      NaN   NaN     NaN    E202015472  Grand i10 NIOS    2020-06-12
# 81201      NaN   NaN     NaN    E202015467     All New i20    2020-06-23
# 81202      NaN   NaN     NaN    E202014045       New Creta    2020-04-23
# 81203      NaN   NaN     NaN    E202015348       New Creta    2020-05-06
# 81204      NaN   NaN     NaN    E202014713       New Creta    2020-05-30
# 81205      NaN   NaN     NaN    E202015618       New Creta    2020-04-30
# 81206      NaN   NaN     NaN    E202026223       New Creta    2020-08-05
# 81207      NaN   NaN     NaN    E202014081     All New i20    2020-06-29
# 81208      NaN   NaN     NaN    E202014731       New Creta    2020-05-24
# 81209      NaN   NaN     NaN    E202015691       New Creta    2020-05-14
# 81210      NaN   NaN     NaN    E202014076       Grand i10    2020-05-31
# 81211      NaN   NaN     NaN    E202012050          Santro    2020-06-29
# 81212      NaN   NaN     NaN    E202027099            AURA    2020-08-18
# 81213      NaN   NaN     NaN    E202025890       New Creta    2020-08-06
# 81214      NaN   NaN     NaN    E202021760           Venue    2020-08-14
# 81215      NaN   NaN     NaN    E202014846            AURA    2020-07-16
# 81216      NaN   NaN     NaN    E202025900       New Creta    2020-10-02
# 81217      NaN   NaN     NaN    E202011382       New Creta    2020-09-21
# 81218      NaN   NaN     NaN    E202027539       New Creta    2020-08-27
#
#       CTB_BOOKING_Y  RETAIL_DATE  EQRY_STAT      _merge model_var  \
# 81195             N          NaN       60.0  right_only       NaN
# 81196             Y          NaN       60.0  right_only       NaN
# 81197             N   20200720.0       45.0  right_only       NaN
# 81198             Y          NaN       91.0  right_only       NaN
# 81199             Y          NaN       60.0  right_only       NaN
# 81200             N   20200612.0       45.0  right_only       NaN
# 81201             N   20200623.0       45.0  right_only       NaN
# 81202             Y          NaN       60.0  right_only       NaN
# 81203             Y   20200629.0       45.0  right_only       NaN
# 81204             N   20200530.0       45.0  right_only       NaN
# 81205             N          NaN       60.0  right_only       NaN
# 81206             N          NaN       60.0  right_only       NaN
# 81207             N   20200629.0       45.0  right_only       NaN
# 81208             N          NaN       60.0  right_only       NaN
# 81209             N   20200514.0       45.0  right_only       NaN
# 81210             N          NaN       60.0  right_only       NaN
# 81211             N          NaN       60.0  right_only       NaN
# 81212             N   20200911.0       45.0  right_only       NaN
# 81213             N   20200822.0       45.0  right_only       NaN
# 81214             N   20200814.0       45.0  right_only       NaN
# 81215             N          NaN       60.0  right_only       NaN
# 81216             N          NaN       60.0  right_only       NaN
# 81217             Y          NaN       91.0  right_only       NaN
# 81218             N   20201023.0       45.0  right_only       NaN
#
#       Variant Type  Body Type Fuel Type
# 81195          NaN        SUV    Petrol
# 81196          NaN        SUV    Petrol
# 81197          NaN        SUV    Petrol
# 81198          NaN        SUV    Petrol
# 81199          NaN      Sedan    Petrol
# 81200          NaN  HatchBack    Petrol
# 81201          NaN  HatchBack    Petrol
# 81202          NaN        SUV    Petrol
# 81203          NaN        SUV    Petrol
# 81204          NaN        SUV    Petrol
# 81205          NaN        SUV    Petrol
# 81206          NaN        SUV    Petrol
# 81207          NaN  HatchBack    Petrol
# 81208          NaN        SUV    Petrol
# 81209          NaN        SUV    Petrol
# 81210          NaN  HatchBack    Petrol
# 81211          NaN  HatchBack    Petrol
# 81212          NaN      Sedan    Petrol
# 81213          NaN        SUV    Petrol
# 81214          NaN        SUV    Petrol
# 81215          NaN      Sedan    Petrol
# 81216          NaN        SUV    Petrol
# 81217          NaN        SUV    Petrol
# 81218          NaN        SUV    Petrol

# %%
variant_book_final1 = Trend_Analysis2(BEVM_Type_book_match1,['Variant Type','ORDER_ID'],'Variant Type')
body_book_final1 = Trend_Analysis2(BEVM_Type_book_match1,['Body Type','EQRY_ENQRY_NO'],'Body Type')
fuel_book_final1 = Trend_Analysis2(BEVM_Type_book_match1,['Fuel Type','ORDER_ID'],'Fuel Type')
model_book_final1 = Trend_Analysis2(BEVM_Type_book_match1,['EQCR_MODEL_NAME','EQRY_ENQRY_NO'],'EQCR_MODEL_NAME')
model_book_final1
# Out:
#    EQCR_MODEL_NAME  EQRY_ENQRY_NO
# 0             AURA            353
# 1          Alcazar            735
# 2      All New i20           1286
# 3            Creta              3
# 4          Elantra              2
# 5        Grand i10             32
# 6   Grand i10 NIOS            644
# 7          Kona EV              3
# 8        New Creta           3454
# 9        New Verna            234
# 10          Santro            206
# 11          Tucson              8
# 12           Venue            807
# 13           Xcent              1

# %%
model_book_final1["MODEL_lower"] = model_book_final1["EQCR_MODEL_NAME"].str.lower()
model_book_final1
# Out:
#    EQCR_MODEL_NAME  EQRY_ENQRY_NO     MODEL_lower
# 0             AURA            353            aura
# 1          Alcazar            735         alcazar
# 2      All New i20           1286     all new i20
# 3            Creta              3           creta
# 4          Elantra              2         elantra
# 5        Grand i10             32       grand i10
# 6   Grand i10 NIOS            644  grand i10 nios
# 7          Kona EV              3         kona ev
# 8        New Creta           3454       new creta
# 9        New Verna            234       new verna
# 10          Santro            206          santro
# 11          Tucson              8          tucson
# 12           Venue            807           venue
# 13           Xcent              1           xcent

# %%
print(fuel_book_final1)
print(body_book_final1)
print(variant_book_final1)
# Out:
#   Fuel Type  ORDER_ID
# 0       CNG       300
# 1    Diesel      1930
# 2  Electric         6
# 3    Petrol      5508
#    Body Type  EQRY_ENQRY_NO
# 0  HatchBack           2168
# 1        SUV           5007
# 2      Sedan            593
#   Variant Type  ORDER_ID
# 0         High      1313
# 1          Low      2294
# 2          Mid      2666

# %%
#variant_final = Merge(variant_enq_final1,'Variant Type',variant_book_final1,'Variant Type','','','outer',False,'single')
#variant_final.columns =['Variant Type', 'Enquiry Count', 'Booking Count']

#total_enq = variant_final["Enquiry Count"].sum()
#total_book = variant_final["Booking Count"].sum()

#variant_final["Enquiry Ratio"] = (variant_final["Enquiry Count"]/total_enq)
#variant_final["Booking Ratio"] = (variant_final["Booking Count"]/total_book)
#variant_final["Enq to Booking Ratio"] = (variant_final["Booking Count"]/total_enq)
#variant_final

# %%
variant_final = Merge(variant_enq_final1,'Variant Type',variant_book_final1,'Variant Type','','','outer',False,'single')
variant_final.columns =['Variant Type', 'Enquiry Count', 'Booking Count']

total_enq = variant_final["Enquiry Count"].sum()
total_book = variant_final["Booking Count"].sum()

variant_final["Enquiry Ratio"] = (variant_final["Enquiry Count"]/total_enq)
variant_final["Booking Ratio"] = (variant_final["Booking Count"]/total_book)
variant_final["Enq to Booking Ratio"] = (variant_final["Booking Count"]/variant_final["Enquiry Count"])
variant_final
# Out:
#   Variant Type  Enquiry Count  Booking Count  Enquiry Ratio  Booking Ratio  \
# 0         High          11543           1313       0.172255       0.209310
# 1          Low          28461           2294       0.424721       0.365694
# 2          Mid          27007           2666       0.403023       0.424996
#
#    Enq to Booking Ratio
# 0              0.113749
# 1              0.080602
# 2              0.098715

# %%
body_final = Merge(body_enq_final1,'Body Type',body_book_final1,'Body Type','','','outer',False,'single')
body_final.columns =['Body Type', 'Enquiry Count', 'Booking Count']

total_enq = body_final["Enquiry Count"].sum()
total_book = body_final["Booking Count"].sum()

body_final["Enquiry Ratio"] = (body_final["Enquiry Count"]/total_enq)
body_final["Booking Ratio"] = (body_final["Booking Count"]/total_book)
body_final["Enq to Booking Ratio"] = (body_final["Booking Count"]/body_final["Enquiry Count"])
body_final
# Out:
#    Body Type  Enquiry Count  Booking Count  Enquiry Ratio  Booking Ratio  \
# 0  HatchBack          26733           2168       0.329968       0.279094
# 1        SUV          45215           5007       0.558093       0.644567
# 2      Sedan           9069            593       0.111939       0.076339
#
#    Enq to Booking Ratio
# 0              0.081098
# 1              0.110738
# 2              0.065388

# %%
fuel_final = Merge(fuel_enq_final1,'Fuel Type',fuel_book_final1,'Fuel Type','','','outer',False,'single')
fuel_final.columns =['Fuel Type', 'Enquiry Count', 'Booking Count']

total_enq = fuel_final["Enquiry Count"].sum()
total_book = fuel_final["Booking Count"].sum()

fuel_final["Enquiry Ratio"] = (fuel_final["Enquiry Count"]/total_enq)
fuel_final["Booking Ratio"] = (fuel_final["Booking Count"]/total_book)
fuel_final["Enq to Booking Ratio"] = (fuel_final["Booking Count"]/fuel_final["Enquiry Count"])
fuel_final
# Out:
#   Fuel Type  Enquiry Count  Booking Count  Enquiry Ratio  Booking Ratio  \
# 0       CNG           3569            300       0.043956       0.038740
# 1    Diesel          18715           1930       0.230494       0.249225
# 2  Electric            283              6       0.003485       0.000775
# 3    Petrol          58628           5508       0.722064       0.711260
#
#    Enq to Booking Ratio
# 0              0.084057
# 1              0.103126
# 2              0.021201
# 3              0.093948

# %%
fuel_final['Booking Count'].sum()
# Out:
# 7744

# %%
model_final_mer = Merge(model_enq_final1,'MODEL_lower',model_book_final1,'MODEL_lower','','','outer',True,'single')
model_final_mer.columns =['MODEL', 'Enquiry Count','MODEL_lower', 'EQCR_MODEL_NAME', 'Booking Count', '_merge']
model_final = model_final_mer[['MODEL','EQCR_MODEL_NAME', 'Enquiry Count', 'Booking Count', '_merge']]
model_final["Enq to Booking Ratio"] = (model_final["Booking Count"]/model_final["Enquiry Count"])
#model_final.fillna("0", inplace = True)
model_final
# Out:
#              MODEL EQCR_MODEL_NAME  Enquiry Count  Booking Count     _merge  \
# 0             AURA            AURA           4285          353.0       both
# 1          Alcazar         Alcazar           3360          735.0       both
# 2      All New i20     All New i20           7256         1286.0       both
# 3            CRETA           Creta            175            3.0       both
# 4          Elantra         Elantra            192            2.0       both
# 5        Elite i20             NaN           4193            NaN  left_only
# 6        Grand i10       Grand i10           1987           32.0       both
# 7   Grand i10 NIOS  Grand i10 NIOS           9011          644.0       both
# 8       I20 ACTIVE             NaN              3            NaN  left_only
# 9          Kona EV         Kona EV            283            3.0       both
# 10       New Creta       New Creta          31027         3454.0       both
# 11       New Verna       New Verna           4307          234.0       both
# 12          Santro          Santro           4286          206.0       both
# 13          Tucson          Tucson            327            8.0       both
# 14           Venue           Venue          10501          807.0       both
# 15           Xcent           Xcent              2            1.0       both
#
#     Enq to Booking Ratio
# 0               0.082380
# 1               0.218750
# 2               0.177233
# 3               0.017143
# 4               0.010417
# 5                    NaN
# 6               0.016105
# 7               0.071468
# 8                    NaN
# 9               0.010601
# 10              0.111322
# 11              0.054330
# 12              0.048063
# 13              0.024465
# 14              0.076850
# 15              0.500000

# %%
model_final['Booking Count'].sum()
# Out:
# 7768.0

# %%
writer = pd.ExcelWriter('CTB_monthly_report_june.xlsx', engine='xlsxwriter')

Monthly_Trend_final_added.to_excel(writer, sheet_name='Monthly_Trend_final')
Weekly_Trend_final.to_excel(writer, sheet_name='Weekly_Trend_final')
Hourly_Trend_final.to_excel(writer, sheet_name='Hourly_Trend_final')
Region_final.to_excel(writer, sheet_name='Region_final')
model_final.to_excel(writer, sheet_name='model_final')


variant_final.to_excel(writer, sheet_name='variant_final')
body_final.to_excel(writer, sheet_name='body_final')
fuel_final.to_excel(writer, sheet_name='fuel_final')
model_final.to_excel(writer, sheet_name='model_final')


GDMS_booking_north.to_excel(writer, sheet_name='GDMS_booking_north')
GDMS_booking_east.to_excel(writer, sheet_name='GDMS_booking_east')
GDMS_booking_west.to_excel(writer, sheet_name='GDMS_booking_west')
GDMS_booking_south.to_excel(writer, sheet_name='GDMS_booking_south')
GDMS_booking_central.to_excel(writer, sheet_name='GDMS_booking_central')



writer.save()

# %%
writer = pd.ExcelWriter('CTB_auto_monthly_report_may_june.xlsx', engine='xlsxwriter')

GDMS_booking_north.to_excel(writer, sheet_name='GDMS_booking_north')
GDMS_booking_east.to_excel(writer, sheet_name='GDMS_booking_east')
GDMS_booking_west.to_excel(writer, sheet_name='GDMS_booking_west')
GDMS_booking_south.to_excel(writer, sheet_name='GDMS_booking_south')
GDMS_booking_central.to_excel(writer, sheet_name='GDMS_booking_central')



writer.save()

# %%
df= pd.read_excel("CTB_monthly_report_june.xlsx", sheet_name = "Monthly_Trend_final")

# %%
df.head()
# Out:
#    Unnamed: 0 ORDER_DATEMonthKey  Year  Month  Enquiry Count  CTB_BOOKING_Y  \
# 0           0             2020_1  2020      1            191              0
# 1           4             2020_2  2020      2            350              0
# 2           5             2020_3  2020      3            688              8
# 3           6             2020_4  2020      4           4051             50
# 4           7             2020_5  2020      5           2224             40
#
#    CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 0              1             1            0           0                  0
# 1              8             3            0           0                  0
# 2             31             2            0           0                  0
# 3              9             0          114           1                  0
# 4             50            30          156          66                  0
#
#    Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 0         0               120               0                  1
# 1         0               276               0                  8
# 2         0               664               8                 39
# 3    634892              4487             164                 59
# 4     43962              1657             196                 90
#
#    Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 0              1             1            191                 0.005236
# 1              8             3            350                 0.008571
# 2             39             2            688                 0.002907
# 3            173             0           4051                 0.000000
# 4            246            96           2224                 0.043165

# %%
df['Total Booking'].sum()
# Out:
# 8160

# %%
df.to_excel("June.xlsx")

# %%
df.tail()
# Out:
#     Unnamed: 0 ORDER_DATEMonthKey  Year  Month  Enquiry Count  CTB_BOOKING_Y  \
# 13          13             2021_2  2021      2           4662            239
# 14          14             2021_3  2021      3           4606            253
# 15          15             2021_4  2021      4           3955            300
# 16          16             2021_5  2021      5           4192            192
# 17          17             2021_6  2021      6           7368            764
#
#     CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 13            328           229            0           0               1346
# 14            352           242            0           0               1441
# 15            280           209            0           0               1966
# 16            181           110            0           0                610
# 17            498           341            0           0               1077
#
#     Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 13    704709              3835             239                567
# 14   1101148              4403             253                605
# 15    894081              3768             300                580
# 16   1730711              3074             192                373
# 17   2630538              5292             764               1262
#
#     Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 13            567           229           6008                 0.049121
# 14            605           242           6047                 0.052540
# 15            580           209           5921                 0.052845
# 16            373           110           4802                 0.026240
# 17           1262           341           8445                 0.046281

# %%
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

# %%
df.head(2)
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'ORDER_DATEMonthKey', 'Year', 'Month', 'Enquiry Count',
#        'CTB_BOOKING_Y', 'CTB_BOOKING_N', 'Retail Count', 'CRM Booking',
#        'CRM Retail', 'Financial_enquiry', 'Visitors', 'CTB Registration',
#        'Online Booking', 'Total CTB Booking', 'Total Booking', 'Total Retail',
#        'Total Enquiry', 'Retail Conversion Ratio'],
#       dtype='object')

# %%
 s = df['Total Booking'] - df['Online Booking']

# %%
s.sum()
# Out:
# 4304

# %%
df['Total CTB Booking'].sum()
# Out:
# 7768

# %%
df['CTB_BOOKING_N'].sum()
# Out:
# 4304

# %%
df['Financial_enquiry'].sum()
# Out:
# 9879

# %%
df['Total Enquiry'].sum()
# Out:
# 91186

# %%
72018-132
# Out:
# 71886

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ORDER_DATEMonthKey', 'Year', 'Month', 'Enquiry Count',
#        'CTB_BOOKING_Y', 'CTB_BOOKING_N', 'Retail Count', 'CRM Booking',
#        'CRM Retail', 'Financial_enquiry', 'Visitors', 'CTB Registration',
#        'Online Booking', 'Total CTB Booking', 'Total Booking', 'Total Retail',
#        'Total Enquiry', 'Retail Conversion Ratio'],
#       dtype='object')

# %%
df.Visitors
# Out:
# 0           0
# 1           0
# 2           0
# 3      634892
# 4       43962
# 5      739592
# 6     1743236
# 7      281136
# 8      525295
# 9      966755
# 10     953487
# 11    1152471
# 12     794194
# 13     704709
# 14    1101148
# 15     894081
# 16    1730711
# 17    2630538
# Name: Visitors, dtype: int64

# %%
Offline = df['Total Booking'] - df['Online Booking']

# %%
Offline.sum()
# Out:
# 4304

# %%
df['Total Enquiry'].sum()
# Out:
# 91186

# %% [markdown]
# # CHARTS

# %%
df['Visitors'] = df['Visitors']/10

# %%
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_1'], '2020_Jan')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_2'], '2020_Feb')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_3'], '2020_Mar')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_4'], '2020_Apr')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_5'], '2020_May')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_6'], '2020_Jun')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_7'], '2020_Jul')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_8'], '2020_Aug')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_9'], '2020_Sep')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_10'], '2020_Oct')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_11'], '2020_Nov')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2020_12'], '2020_Dec')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2021_1'], '2021_Jan')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2021_2'], '2021_Feb')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2021_3'], '2021_Mar')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2021_4'], '2021_Apr')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2021_5'], '2021_May')
df['ORDER_DATEMonthKey'] = df['ORDER_DATEMonthKey'].replace(['2021_6'], '2021_Jun')

# %%
# create figure and axis objects with subplots()
#from matplotlib.pyplot import figure
fig,ax = plt.subplots()
# make a plot
#figure(num=None, figsize=(20, 16), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams["figure.figsize"] = (8,3)
plt.xticks(rotation=45)
plt.ylim(ymax=300000)
#labels = ['Jan20','Feb20','Mar20','Apr20','May20','Jun20','Jul20','Aug20','Sep20','Oct20', 'Nov20','Dec20','Jan21','Feb21']
#ax1.axes.set_xticklabels(labels)
ax.plot(df['ORDER_DATEMonthKey'],df['Visitors'], color='dodgerblue', marker='o',linewidth=3 )
# set x-axis label
#ax.set_xlabel("Month",fontsize=14)
# set y-axis label
ax.set_title('CTB Web Traffic Trend', fontsize=12)
ax.set_ylabel("CTB Web Traffic (Visitors)",color="Black",fontsize=14)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("chart5.png", bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
#from matplotlib.pyplot import figure
fig,ax = plt.subplots()
# make a plot
#figure(num=None, figsize=(20, 16), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams["figure.figsize"] = (8,3)
plt.xticks(rotation=45)
plt.ylim(ymax=10000)
#labels = ['Jan20','Feb20','Mar20','Apr20','May20','Jun20','Jul20','Aug20','Sep20','Oct20', 'Nov20','Dec20','Jan21','Feb21']
#ax1.axes.set_xticklabels(labels)
ax.plot(df['ORDER_DATEMonthKey'],df['CTB Registration'], color='grey', marker='o', linewidth=3 )
# set x-axis label
ax.set_xlabel("Month",fontsize=12)
# set y-axis label
ax.set_title('CTB Registration Trend', fontsize=12)
ax.set_ylabel("Registration Count",color="Black",fontsize=12)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("chart6.png", bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
#from matplotlib.pyplot import figure
fig,ax = plt.subplots()
# make a plot
#figure(num=None, figsize=(20, 16), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams["figure.figsize"] = (8,3)
plt.xticks(rotation=45)
plt.ylim(ymax=1500)
#labels = ['Jan20','Feb20','Mar20','Apr20','May20','Jun20','Jul20','Aug20','Sep20','Oct20', 'Nov20','Dec20','Jan21','Feb21']
#ax1.axes.set_xticklabels(labels)
ax.plot(df['ORDER_DATEMonthKey'],df['Total CTB Booking'], color='red', marker='o', linewidth=3 )
# set x-axis label
ax.set_xlabel("Month",fontsize=12)
ax.set_title('CTB Booking Trend', fontsize=12)
# set y-axis label
ax.set_ylabel("Booking Count",color="black",fontsize=12)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("chart7.png", bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
#from matplotlib.pyplot import figure
fig,ax = plt.subplots()
# make a plot
#figure(num=None, figsize=(20, 16), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams["figure.figsize"] = (8,3)
plt.xticks(rotation=45)

#labels = ['Jan20','Feb20','Mar20','Apr20','May20','Jun20','Jul20','Aug20','Sep20','Oct20', 'Nov20','Dec20','Jan21','Feb21']
#ax1.axes.set_xticklabels(labels)
ax.plot(df['ORDER_DATEMonthKey'],df['Total Retail'], color='royalblue', marker='o', linewidth=3 )
# set x-axis label
ax.set_xlabel("Month",fontsize=14)
# set y-axis label
plt.ylim(ymax = 800, ymin = 0)
ax.set_title('CTB Retail Trend', fontsize=12)
ax.set_ylabel("CTB Retail Count",color="black",fontsize=12)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("chart9.png", bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
#from matplotlib.pyplot import figure
fig,ax = plt.subplots()
# make a plot
#figure(num=None, figsize=(20, 16), dpi=80, facecolor='w', edgecolor='k')
plt.rcParams["figure.figsize"] = (8,3)
plt.xticks(rotation=45)

#labels = ['Jan20','Feb20','Mar20','Apr20','May20','Jun20','Jul20','Aug20','Sep20','Oct20', 'Nov20','Dec20','Jan21','Feb21']
#ax1.axes.set_xticklabels(labels)
ax.plot(df['ORDER_DATEMonthKey'],df['Total Enquiry'], color='orange', marker='o', linewidth=3 )
# set x-axis label
ax.set_xlabel("Month",fontsize=14)
plt.ylim(ymax=10000, ymin=0)
# set y-axis label
ax.set_title('CTB Enquiry Trend', fontsize=12)
ax.set_ylabel("Enquiry Count",color="black",fontsize=12)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("chart8.png", bbox_inches='tight')

# %%
df1_2 = df['Retail Conversion Ratio'] = df['Total Retail'] / df['Total Enquiry']

# %%
df1_2
# Out:
# 0     0.005236
# 1     0.008571
# 2     0.002907
# 3     0.000000
# 4     0.043165
# 5     0.037024
# 6     0.032436
# 7     0.045071
# 8     0.035263
# 9     0.031781
# 10    0.042834
# 11    0.031884
# 12    0.040626
# 13    0.038116
# 14    0.040020
# 15    0.035298
# 16    0.022907
# 17    0.040379
# dtype: float64

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


df.plot(kind='line',x='ORDER_DATEMonthKey',y='Visitors', color="dodgerblue",legend=False,ax=ax,marker='x',linewidth=3)
plt.ylim(ymax=300000)
plt.ylabel("CTB Traffic - Visitors", fontsize=12)
plt.xlabel("Month", fontsize = 12)
plt.xticks(np.arange(17), df['Month'][0:17], rotation=45)
#plt.ylim(ymax=300000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(['CTB Website Traffic'],loc='upper center', bbox_to_anchor=(0.71, 1.2), ncol=2)


#plt.subplots_adjust(left=0.15)



ax2 = ax.twinx()


df.plot(kind='line',x='ORDER_DATEMonthKey',y='CTB Registration', legend=False, color='grey',linewidth=3, marker='d', ax=ax2)
#df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total Enquiry', legend=False, color='Orange', linewidth=3, marker='o', ax=ax2)

plt.ylim(ymax = 50000, ymin = 0)


plt.ylabel("CTB Registration",fontsize=12)
ax2.legend(['CTB Registration'],loc='upper center', bbox_to_anchor=(0.26, 1.2), ncol=2)
#ax2.legend(["CTB Enquiry"],loc='upper center', bbox_to_anchor=(0.26, 1.3), ncol=2)
plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
        
plt.savefig("chart1.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## chart 2

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(8, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()



df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total Enquiry', color="orange",linewidth=3,legend=False,ax=ax,marker='o', markerfacecolor='grey', markersize=4)
df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total Retail', legend=False, linewidth=3,color='grey', ax=ax, marker='x', markerfacecolor='grey', markersize=4)
plt.xticks(np.arange(17), df['Month'][0:17], rotation=45)
plt.ylim(ymax=10000, ymin=0)
#plt.ylabel("CTB Total Booking \t CTB Total Retail", fontsize=12)
plt.xlabel("Month", fontsize = 12)
#plt.ylim(ymax=10000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(['CTB Enquiry','CTB Retail'],loc='upper center', bbox_to_anchor=(0.23, 1.2), ncol=2,)


#plt.subplots_adjust(left=0.15)



ax2 = ax.twinx()
#.plot(x="ORDER_DATEMonthKey", y="CTB_BOOKING_N" , ax=ax2, legend=False, color="r")

df.plot(kind='line',x='ORDER_DATEMonthKey',y='Retail Conversion Ratio', legend=False,linewidth=3, color='royalblue',marker='d', markerfacecolor='grey', markersize=4, ax=ax2)
ax2.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylim(ymax = 0.4, ymin = 0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
plt.ylabel("Ratio %",fontsize=12)
ax2.legend(loc='upper center', bbox_to_anchor=(0.65, 1.2), ncol=2,)
plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
    

#plt.savefig("chart2")
plt.savefig("chart2.png", bbox_inches='tight')               
plt.show()

# %% [markdown]
# ## Weekly

# %%
df2= pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "Weekly_Trend_final")

# %%
df2.to_excel("weekly.xlsx")

# %%
df2[['year','Week Number']] = df2['ORDER_DATEWeekKey'].str.split("_",expand=True)
df2.head()
# Out:
#    Unnamed: 0 ORDER_DATEWeekKey  Enquiry Count  CTB_BOOKING_Y  CTB_BOOKING_N  \
# 0           0           2020_10            105            0.0            9.0
# 1           1           2020_11            101            2.0           10.0
# 2           2           2020_12            160            3.0            7.0
# 3           3           2020_13            255            3.0            5.0
# 4           4           2020_14            287            6.0            0.0
#
#    Retail Count  year Week Number
# 0           NaN  2020          10
# 1           NaN  2020          11
# 2           2.0  2020          12
# 3           NaN  2020          13
# 4           NaN  2020          14

# %%
from natsort import natsorted
from natsort import natsorted, index_natsorted, order_by_index

#df2=natsorted(df2,df2['ORDER_DATEWeekKey'],)
df2 = df2.reindex(index=order_by_index(df2.index, index_natsorted(df2.ORDER_DATEWeekKey)))

# %%
df2[['year','Week Number']] = df2['ORDER_DATEWeekKey'].str.split("_",expand=True)
df2
# Out:
#     Unnamed: 0 ORDER_DATEWeekKey  Enquiry Count  CTB_BOOKING_Y  CTB_BOOKING_N  \
# 20          20            2020_3             61            NaN            NaN
# 31          31            2020_4             61            NaN            NaN
# 42          42            2020_5             62            0.0            1.0
# 47          47            2020_6             69            0.0            1.0
# 48          48            2020_7            118            0.0            2.0
# 49          49            2020_8             87            0.0            2.0
# 50          50            2020_9             89            0.0            3.0
# 0            0           2020_10            105            0.0            9.0
# 1            1           2020_11            101            2.0           10.0
# 2            2           2020_12            160            3.0            7.0
# 3            3           2020_13            255            3.0            5.0
# 4            4           2020_14            287            6.0            0.0
# 5            5           2020_15           1175           11.0            2.0
# 6            6           2020_16            697            7.0            3.0
# 7            7           2020_17           1534           16.0            1.0
# 8            8           2020_18            634           12.0            3.0
# 9            9           2020_19            452           17.0            9.0
# 10          10           2020_20            234            8.0            8.0
# 11          11           2020_21            460            4.0           20.0
# 12          12           2020_22            854            9.0           13.0
# 13          13           2020_23           1329           20.0           28.0
# 14          14           2020_24           1369           14.0           43.0
# 15          15           2020_25           1306           10.0           37.0
# 16          16           2020_26           1532           15.0           42.0
# 17          17           2020_27           1278           16.0           35.0
# 18          18           2020_28           1171           17.0           48.0
# 19          19           2020_29           1153           21.0           57.0
# 21          21           2020_30           1029           21.0           69.0
# 22          22           2020_31            904           11.0           61.0
# 23          23           2020_32           1060           24.0           63.0
# ..         ...               ...            ...            ...            ...
# 44          44           2020_51           1697           33.0           96.0
# 45          45           2020_52           1369           46.0           89.0
# 46          46           2020_53            796           32.0           48.0
# 51          51            2021_1           1309           44.0           80.0
# 62          62            2021_2           1191           51.0           65.0
# 70          70            2021_3           1154           41.0           86.0
# 71          71            2021_4           1077           34.0           88.0
# 72          72            2021_5           1070           41.0           68.0
# 74          74            2021_6           1399           80.0           76.0
# 75          75            2021_7           1167           62.0           68.0
# 76          76            2021_8           1001           56.0          116.0
# 77          77            2021_9            914           28.0           63.0
# 52          52           2021_10           1143           44.0           86.0
# 53          53           2021_11           1011           54.0           69.0
# 54          54           2021_12            989           85.0           99.0
# 55          55           2021_13           1042           78.0           64.0
# 56          56           2021_14           1135          100.0           89.0
# 57          57           2021_15           1018           26.0           31.0
# 58          58           2021_16            759            NaN            NaN
# 59          59           2021_17            700            NaN            NaN
# 60          60           2021_18            831            NaN            NaN
# 61          61           2021_19            819            NaN            NaN
# 63          63           2021_20           1059            NaN            NaN
# 64          64           2021_21           1110            NaN            NaN
# 65          65           2021_22           1079            NaN            NaN
# 66          66           2021_23           2268            NaN            NaN
# 67          67           2021_24           2174            NaN            NaN
# 68          68           2021_25           1418            NaN            NaN
# 69          69           2021_26            608            NaN            NaN
# 73          73           2021_53            522           21.0            7.0
#
#     Retail Count  year Week Number
# 20           NaN  2020           3
# 31           NaN  2020           4
# 42           1.0  2020           5
# 47           1.0  2020           6
# 48           NaN  2020           7
# 49           1.0  2020           8
# 50           1.0  2020           9
# 0            NaN  2020          10
# 1            NaN  2020          11
# 2            2.0  2020          12
# 3            NaN  2020          13
# 4            NaN  2020          14
# 5            NaN  2020          15
# 6            NaN  2020          16
# 7            NaN  2020          17
# 8            NaN  2020          18
# 9            2.0  2020          19
# 10           5.0  2020          20
# 11           9.0  2020          21
# 12          14.0  2020          22
# 13          16.0  2020          23
# 14          21.0  2020          24
# 15          34.0  2020          25
# 16          24.0  2020          26
# 17          24.0  2020          27
# 18          29.0  2020          28
# 19          25.0  2020          29
# 21          34.0  2020          30
# 22          61.0  2020          31
# 23          34.0  2020          32
# ..           ...   ...         ...
# 44          84.0  2020          51
# 45          75.0  2020          52
# 46          42.0  2020          53
# 51          54.0  2021           1
# 62          55.0  2021           2
# 70          70.0  2021           3
# 71          60.0  2021           4
# 72          49.0  2021           5
# 74          53.0  2021           6
# 75          55.0  2021           7
# 76          72.0  2021           8
# 77          36.0  2021           9
# 52          49.0  2021          10
# 53          60.0  2021          11
# 54          72.0  2021          12
# 55          34.0  2021          13
# 56          35.0  2021          14
# 57          61.0  2021          15
# 58          51.0  2021          16
# 59          53.0  2021          17
# 60          17.0  2021          18
# 61          18.0  2021          19
# 63          25.0  2021          20
# 64          36.0  2021          21
# 65          37.0  2021          22
# 66          61.0  2021          23
# 67          87.0  2021          24
# 68          89.0  2021          25
# 69          81.0  2021          26
# 73           5.0  2021          53
#
# [78 rows x 8 columns]

# %%
df2 = df2.rename(columns={'Enquiry Count': 'CTB Enquiry', 'Retail Count': 'CTB Retail'})
df2
# Out:
#     Unnamed: 0 ORDER_DATEWeekKey  CTB Enquiry  CTB_BOOKING_Y  CTB_BOOKING_N  \
# 20          20            2020_3           61            NaN            NaN
# 31          31            2020_4           61            NaN            NaN
# 42          42            2020_5           62            0.0            1.0
# 47          47            2020_6           69            0.0            1.0
# 48          48            2020_7          118            0.0            2.0
# 49          49            2020_8           87            0.0            2.0
# 50          50            2020_9           89            0.0            3.0
# 0            0           2020_10          105            0.0            9.0
# 1            1           2020_11          101            2.0           10.0
# 2            2           2020_12          160            3.0            7.0
# 3            3           2020_13          255            3.0            5.0
# 4            4           2020_14          287            6.0            0.0
# 5            5           2020_15         1175           11.0            2.0
# 6            6           2020_16          697            7.0            3.0
# 7            7           2020_17         1534           16.0            1.0
# 8            8           2020_18          634           12.0            3.0
# 9            9           2020_19          452           17.0            9.0
# 10          10           2020_20          234            8.0            8.0
# 11          11           2020_21          460            4.0           20.0
# 12          12           2020_22          854            9.0           13.0
# 13          13           2020_23         1329           20.0           28.0
# 14          14           2020_24         1369           14.0           43.0
# 15          15           2020_25         1306           10.0           37.0
# 16          16           2020_26         1532           15.0           42.0
# 17          17           2020_27         1278           16.0           35.0
# 18          18           2020_28         1171           17.0           48.0
# 19          19           2020_29         1153           21.0           57.0
# 21          21           2020_30         1029           21.0           69.0
# 22          22           2020_31          904           11.0           61.0
# 23          23           2020_32         1060           24.0           63.0
# ..         ...               ...          ...            ...            ...
# 44          44           2020_51         1697           33.0           96.0
# 45          45           2020_52         1369           46.0           89.0
# 46          46           2020_53          796           32.0           48.0
# 51          51            2021_1         1309           44.0           80.0
# 62          62            2021_2         1191           51.0           65.0
# 70          70            2021_3         1154           41.0           86.0
# 71          71            2021_4         1077           34.0           88.0
# 72          72            2021_5         1070           41.0           68.0
# 74          74            2021_6         1399           80.0           76.0
# 75          75            2021_7         1167           62.0           68.0
# 76          76            2021_8         1001           56.0          116.0
# 77          77            2021_9          914           28.0           63.0
# 52          52           2021_10         1143           44.0           86.0
# 53          53           2021_11         1011           54.0           69.0
# 54          54           2021_12          989           85.0           99.0
# 55          55           2021_13         1042           78.0           64.0
# 56          56           2021_14         1135          100.0           89.0
# 57          57           2021_15         1018           26.0           31.0
# 58          58           2021_16          759            NaN            NaN
# 59          59           2021_17          700            NaN            NaN
# 60          60           2021_18          831            NaN            NaN
# 61          61           2021_19          819            NaN            NaN
# 63          63           2021_20         1059            NaN            NaN
# 64          64           2021_21         1110            NaN            NaN
# 65          65           2021_22         1079            NaN            NaN
# 66          66           2021_23         2268            NaN            NaN
# 67          67           2021_24         2174            NaN            NaN
# 68          68           2021_25         1418            NaN            NaN
# 69          69           2021_26          608            NaN            NaN
# 73          73           2021_53          522           21.0            7.0
#
#     CTB Retail  year Week Number
# 20         NaN  2020           3
# 31         NaN  2020           4
# 42         1.0  2020           5
# 47         1.0  2020           6
# 48         NaN  2020           7
# 49         1.0  2020           8
# 50         1.0  2020           9
# 0          NaN  2020          10
# 1          NaN  2020          11
# 2          2.0  2020          12
# 3          NaN  2020          13
# 4          NaN  2020          14
# 5          NaN  2020          15
# 6          NaN  2020          16
# 7          NaN  2020          17
# 8          NaN  2020          18
# 9          2.0  2020          19
# 10         5.0  2020          20
# 11         9.0  2020          21
# 12        14.0  2020          22
# 13        16.0  2020          23
# 14        21.0  2020          24
# 15        34.0  2020          25
# 16        24.0  2020          26
# 17        24.0  2020          27
# 18        29.0  2020          28
# 19        25.0  2020          29
# 21        34.0  2020          30
# 22        61.0  2020          31
# 23        34.0  2020          32
# ..         ...   ...         ...
# 44        84.0  2020          51
# 45        75.0  2020          52
# 46        42.0  2020          53
# 51        54.0  2021           1
# 62        55.0  2021           2
# 70        70.0  2021           3
# 71        60.0  2021           4
# 72        49.0  2021           5
# 74        53.0  2021           6
# 75        55.0  2021           7
# 76        72.0  2021           8
# 77        36.0  2021           9
# 52        49.0  2021          10
# 53        60.0  2021          11
# 54        72.0  2021          12
# 55        34.0  2021          13
# 56        35.0  2021          14
# 57        61.0  2021          15
# 58        51.0  2021          16
# 59        53.0  2021          17
# 60        17.0  2021          18
# 61        18.0  2021          19
# 63        25.0  2021          20
# 64        36.0  2021          21
# 65        37.0  2021          22
# 66        61.0  2021          23
# 67        87.0  2021          24
# 68        89.0  2021          25
# 69        81.0  2021          26
# 73         5.0  2021          53
#
# [78 rows x 8 columns]

# %%
df2['Conversion Ratio'] = df2['CTB Retail'] / df2['CTB Enquiry']

# %%
df2_1 = df2.copy()

# %%
df2_1['Conversion Ratio'] = df2_1['CTB Retail'] / df2_1['CTB Enquiry']

# %%
df2_1.to_excel("weekly_ratio.xlsx")

# %%
df2.tail(5)
# Out:
#     Unnamed: 0 ORDER_DATEWeekKey  CTB Enquiry  CTB_BOOKING_Y  CTB_BOOKING_N  \
# 66          66           2021_23         2268            NaN            NaN
# 67          67           2021_24         2174            NaN            NaN
# 68          68           2021_25         1418            NaN            NaN
# 69          69           2021_26          608            NaN            NaN
# 73          73           2021_53          522           21.0            7.0
#
#     CTB Retail  year Week Number  Conversion Ratio
# 66        61.0  2021          23          0.026896
# 67        87.0  2021          24          0.040018
# 68        89.0  2021          25          0.062764
# 69        81.0  2021          26          0.133224
# 73         5.0  2021          53          0.009579

# %%
df2.to_excel("Weekly.xlsx")

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(14, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()




df2[0:67].plot(kind='line',x='Week Number',y='CTB Enquiry', linewidth=3, color="orange",legend=False,ax=ax,)
df2[0:67].plot(kind='line',x='Week Number',y='CTB_BOOKING_Y', linewidth=3,legend=False, color='red', ax=ax)
plt.ylabel("CTB Enquiry \n CTB Booking", fontsize=12)
plt.xlabel("Week Number", fontsize = 12)
#plt.ylim(ymax=10000, ymin=0)
plt.xticks(np.arange(68), df2['Week Number'][0:68], rotation=45)
ax.legend(['CTB Enquiry', ' CTB Booking'],loc='upper center', bbox_to_anchor=(0.145, 1.3), ncol=2)


#plt.subplots_adjust(left=0.15)



ax2 = ax.twinx()
#.plot(x="ORDER_DATEMonthKey", y="CTB_BOOKING_N" , ax=ax2, legend=False, color="r")

df2[0:67].plot(kind='line',x='Week Number',y='Conversion Ratio',linewidth=3, legend=False, color='grey', ax=ax2)
ax2.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylim(ymax = 0.2, ymin = 0)
plt.xticks(np.arange(67), df2['Week Number'][0:67], rotation=45)
plt.ylabel("Enquiry to Booking Ratio",fontsize=12)

ax2.legend(['Enquiry to Booking Ratio'],loc='upper center', bbox_to_anchor=(0.40, 1.3), ncol=2)
plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
        
plt.savefig("chart3.png", bbox_inches='tight')        
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


df2[0:67].plot(kind='line',x='ORDER_DATEWeekKey',y='CTB Enquiry',linewidth=3, color="orange",legend=False,ax=ax,)
#df3[0:59].plot(kind='line',x='ORDER_DATEWeekKey',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("CTB Enquiry \n CTB Booking ", fontsize=12)
plt.xlabel("Week Number", fontsize = 12)
#plt.ylim(ymax=10000, ymin=0)
plt.xticks(np.arange(69), df2['Week Number'][0:69], rotation=45)
ax.legend(['CTB Enquiry'],loc='upper center', bbox_to_anchor=(0.078, 1.3), ncol=2)


#plt.subplots_adjust(left=0.15)



ax2 = ax.twinx()
#.plot(x="ORDER_DATEMonthKey", y="CTB_BOOKING_N" , ax=ax2, legend=False, color="r")

df2[0:67].plot(kind='line',x='ORDER_DATEWeekKey',y='CTB Retail',linewidth=3, legend=False, color='royalblue', ax=ax2)
df2[0:67].plot(kind='line',x='ORDER_DATEWeekKey',y='CTB_BOOKING_Y',linewidth=3, legend=False, color='red', ax=ax2)

plt.ylim(ymax =800, ymin = 0)
plt.xticks(np.arange(67), df2['Week Number'][0:69], rotation=45)
plt.ylabel("Retail Count",fontsize=12)
ax2.legend(['CTB Retail', 'CTB Booking'],loc='upper center', bbox_to_anchor=(0.26, 1.3), ncol=2)
plt.grid(color='grey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
        
plt.savefig("chart4.png", bbox_inches='tight')         
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(11, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total CTB Booking', color="red",linewidth=3,legend=False,marker ='o',ax=ax,)
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking", fontsize=12)
plt.xlabel("Month", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=2000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(['CTB Booking'],loc='upper center', bbox_to_anchor=(0.43, 1.3), ncol=2)


#plt.subplots_adjust(left=0.15)
#plt.title("CTB Offline booking vs CTB Total Booking")


ax2 = ax.twinx()
#.plot(x="ORDER_DATEMonthKey", y="CTB_BOOKING_N" , ax=ax2, legend=False, color="r")

df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total Retail', legend=False,linewidth=3, color='royalblue',marker ='x', ax=ax2)

plt.ylim(ymax = 1200, ymin = 0)
plt.xticks(np.arange(17), df['ORDER_DATEMonthKey'][0:17],rotation=45)

plt.ylabel("Retail",fontsize=12)
ax2.legend(['CTB Retail'],loc='upper center', bbox_to_anchor=(0.65, 1.3), ncol=2)
plt.grid(color='grey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
    
plt.grid(color='grey', linewidth=0.7)
plt.show()
plt.savefig("#booking vs retail.png", bbox_inches='tight')   
#chart9")

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(11, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total CTB Booking', color="red",linewidth=3,legend=False,marker ='o',ax=ax,)
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)
plt.xlabel("Month", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=1600, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(['CTB Booking'],loc='upper center', bbox_to_anchor=(0.11, 1.4), ncol=2)


#plt.subplots_adjust(left=0.15)



ax2 = ax.twinx()
#.plot(x="ORDER_DATEMonthKey", y="CTB_BOOKING_N" , ax=ax2, legend=False, color="r")

df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total Retail', legend=False,linewidth=3, color='royalblue',marker ='x', ax=ax2)

plt.ylim(ymax = 1600, ymin = 0)
plt.xticks(np.arange(17), df['ORDER_DATEMonthKey'][0:17],rotation=45)

plt.ylabel("CTB Retail",fontsize=12)
ax2.legend(['CTB Retail'],loc='upper center', bbox_to_anchor=(0.312, 1.4), ncol=2)
plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
        
plt.savefig("#chart9.png", bbox_inches='tight')         
plt.show()

#chart9")

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(11, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


df.plot(kind='line',x='ORDER_DATEMonthKey',y='CTB_BOOKING_Y', color="blue",legend=False,marker="o",ax=ax,linewidth=2)
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)
plt.xlabel("Month", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=1500, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(['Online Booking'],loc='upper center', bbox_to_anchor=(0.09, 1.01), ncol=2)

plt.title("CTB Online booking vs CTB Total Booking")
#plt.subplots_adjust(left=0.15)



ax2 = ax.twinx()
#.plot(x="ORDER_DATEMonthKey", y="CTB_BOOKING_N" , ax=ax2, legend=False, color="r")

df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total CTB Booking', legend=False, color='red', marker="x", linewidth=2,ax=ax2)

plt.ylim(ymax = 1500, ymin = 0)
plt.xticks(np.arange(17), df['ORDER_DATEMonthKey'][0:17], rotation=45)

plt.ylabel("Offline booking",fontsize=12)
ax2.legend(loc='upper center', bbox_to_anchor=(0.29, 1.01), ncol=2)
plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
        
plt.savefig("#10.png", bbox_inches='tight')       
plt.show()
#plt.savefig("chart10.png", bbox_inches='tight')

# %%
df
# Out:
#     Unnamed: 0 ORDER_DATEMonthKey  Year  Month  Enquiry Count  CTB_BOOKING_Y  \
# 0            0           2020_Jan  2020      1            191              0
# 1            4           2020_Feb  2020      2            350              0
# 2            5           2020_Mar  2020      3            688              8
# 3            6           2020_Apr  2020      4           4051             50
# 4            7           2020_May  2020      5           2224             40
# 5            8           2020_Jun  2020      6           5888             67
# 6            9           2020_Jul  2020      7           4902             73
# 7           10           2020_Aug  2020      8           4859            101
# 8           11           2020_Sep  2020      9           6012            108
# 9            1           2020_Oct  2020     10           8590            535
# 10           2           2020_Nov  2020     11           6887            361
# 11           3           2020_Dec  2020     12           6603            182
# 12          12           2021_Jan  2021      1           5279            191
# 13          13           2021_Feb  2021      2           4662            239
# 14          14           2021_Mar  2021      3           4606            253
# 15          15           2021_Apr  2021      4           3955            300
# 16          16           2021_May  2021      5           4192            192
# 17          17           2021_Jun  2021      6           7368            764
#
#     CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 0               1             1            0           0                  0
# 1               8             3            0           0                  0
# 2              31             2            0           0                  0
# 3               9             0          114           1                  0
# 4              50            30          156          66                  0
# 5             162           106          122         112                  0
# 6             244           159            0           0                  0
# 7             275           219            0           0                  0
# 8             357           212            0           0                  0
# 9             416           273            0           0                  0
# 10            403           295            0           0                  0
# 11            383           297            0           0               2712
# 12            326           244            0           0                727
# 13            328           229            0           0               1346
# 14            352           242            0           0               1441
# 15            280           209            0           0               1966
# 16            181           110            0           0                610
# 17            498           341            0           0               1077
#
#     Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 0        0.0               120               0                  1
# 1        0.0               276               0                  8
# 2        0.0               664               8                 39
# 3    63489.2              4487             164                 59
# 4     4396.2              1657             196                 90
# 5    73959.2              5127             189                229
# 6   174323.6              5004              73                317
# 7    28113.6              4012             101                376
# 8    52529.5              5694             108                465
# 9    96675.5              8000             535                951
# 10   95348.7              5874             361                764
# 11  115247.1              6236             182                565
# 12   79419.4              4057             191                517
# 13   70470.9              3835             239                567
# 14  110114.8              4403             253                605
# 15   89408.1              3768             300                580
# 16  173071.1              3074             192                373
# 17  263053.8              5292             764               1262
#
#     Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 0               1             1            191                 0.005236
# 1               8             3            350                 0.008571
# 2              39             2            688                 0.002907
# 3             173             0           4051                 0.000000
# 4             246            96           2224                 0.043165
# 5             351           218           5888                 0.037024
# 6             317           159           4902                 0.032436
# 7             376           219           4859                 0.045071
# 8             465           212           6012                 0.035263
# 9             951           273           8590                 0.031781
# 10            764           295           6887                 0.042834
# 11            565           297           9315                 0.031884
# 12            517           244           6006                 0.040626
# 13            567           229           6008                 0.038116
# 14            605           242           6047                 0.040020
# 15            580           209           5921                 0.035298
# 16            373           110           4802                 0.022907
# 17           1262           341           8445                 0.040379

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(14, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()
plt.title("CTB Booking Trend")

df.plot(kind='line',x='ORDER_DATEMonthKey',y='CTB_BOOKING_Y', color="blue",legend=False,ax=ax,linewidth=3, marker='o')
df.plot(kind='line',x='ORDER_DATEMonthKey',y='CTB_BOOKING_N', legend=False, color='black', ax=ax,linewidth=3,marker='x')
df.plot(kind='line',x='ORDER_DATEMonthKey',y='Total CTB Booking', legend=False, color='red', ax=ax,linewidth=3,marker='s')
plt.yticks(np.arange(0, 1600, 300)) # lower limit , upper limit, range 
ax.legend(["CTB ONLINE BOOKING" , "OFFLINE BOOKING" , "TOTAL BOOKING"],loc='upper center', bbox_to_anchor=(1.095, 1.0), ncol=1)
plt.ylabel("Enquiry Count\nBooking Count", fontsize=12)
plt.xlabel("Month", fontsize = 12)

plt.xticks(np.arange(17), df['ORDER_DATEMonthKey'][0:17], rotation=45)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(loc='upper center', bbox_to_anchor=(0.26, 1.0), ncol=2)
#ax2 = ax.twinx()


#plt.yticks(np.arange(0, 1100, 100))
plt.savefig("#chart11.jpg", bbox_inches='tight') 
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.show()

# %%
df3= pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "Hourly_Trend_final")

# %%
df3['Booking Count'].sum()
# Out:
# 3469

# %%
df3
# Out:
#     Unnamed: 0 Range_name  Enquiry Count  Booking Count
# 0            0        0-2           3070             48
# 1            1      10-12           9905            503
# 2            2      12-14          10124            556
# 3            3      14-16          10283            559
# 4            4      16-18           9198            506
# 5            5      18-20           9527            405
# 6            6        2-4           1170             18
# 7            7      20-22           9522            344
# 8            8      22-24           7520            179
# 9            9        4-6           1254             17
# 10          10        6-8           3402            102
# 11          11       8-10           6220            232

# %%
df3 = df3.reindex(index=order_by_index(df3.index, index_natsorted(df3.Range_name)))

# %%
df3.shape
# Out:
# (12, 4)

# %%
df3['Enquiry Count'].sum()
# Out:
# 81195

# %%
df3['Enquiry %'] = (df3['Enquiry Count'] /73939)*100

# %%
df3['Enquiry %']
# Out:
# 0      4.152071
# 6      1.582385
# 9      1.695993
# 10     4.601090
# 11     8.412340
# 1     13.396178
# 2     13.692368
# 3     13.907410
# 4     12.439984
# 5     12.884946
# 7     12.878183
# 8     10.170546
# Name: Enquiry %, dtype: float64

# %%
df3['Enquiry %'] = df3['Enquiry %'].round(2).astype(str)+ '%'

# %%
df3
# Out:
#     Unnamed: 0 Range_name  Enquiry Count  Booking Count Enquiry %
# 0            0        0-2           3070             48     4.15%
# 6            6        2-4           1170             18     1.58%
# 9            9        4-6           1254             17      1.7%
# 10          10        6-8           3402            102      4.6%
# 11          11       8-10           6220            232     8.41%
# 1            1      10-12           9905            503     13.4%
# 2            2      12-14          10124            556    13.69%
# 3            3      14-16          10283            559    13.91%
# 4            4      16-18           9198            506    12.44%
# 5            5      18-20           9527            405    12.88%
# 7            7      20-22           9522            344    12.88%
# 8            8      22-24           7520            179    10.17%

# %%
df3['Booking Count'].sum()
# Out:
# 3469

# %%
df3['Booking %'] = (df3['Booking Count'] /2776)*100

# %%
df3['Booking %'] = df3['Booking %'].round(2).astype(str)+ '%'

# %%
df3
# Out:
#     Unnamed: 0 Range_name  Enquiry Count  Booking Count Enquiry % Booking %
# 0            0        0-2           3070             48     4.15%     1.73%
# 6            6        2-4           1170             18     1.58%     0.65%
# 9            9        4-6           1254             17      1.7%     0.61%
# 10          10        6-8           3402            102      4.6%     3.67%
# 11          11       8-10           6220            232     8.41%     8.36%
# 1            1      10-12           9905            503     13.4%    18.12%
# 2            2      12-14          10124            556    13.69%    20.03%
# 3            3      14-16          10283            559    13.91%    20.14%
# 4            4      16-18           9198            506    12.44%    18.23%
# 5            5      18-20           9527            405    12.88%    14.59%
# 7            7      20-22           9522            344    12.88%    12.39%
# 8            8      22-24           7520            179    10.17%     6.45%

# %%
df3.to_excel("Hourly_may.xlsx")

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(13, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df3.plot(kind='bar',x='Range_name',y='Enquiry Count', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Enquiry Count", fontsize=12)
plt.xlabel("Hours of the day", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=12000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["CTB Enquiry"],loc="upper center", bbox_to_anchor=(0.08, 1.0))


plt.title("Enquiry count by hours of the day")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')       
plt.savefig("#12.jpg", bbox_inches='tight')      
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(13, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df3.plot(kind='bar',x='Range_name',y='Booking Count', color="dodgerblue",legend=False,ax=ax)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')             
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)
plt.xlabel("Hours of the day", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=1000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["CTB Booking "],loc="upper center", bbox_to_anchor=(0.08, 1.0))


plt.title("Booking count by hours of the day")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')      
plt.savefig("#13.jpg", bbox_inches='tight')       
plt.show()

# %% [markdown]
# ## Dealer

# %%
df4 = pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "Region_final")

# %%
df4.head(2)
# Out:
#    Unnamed: 0 Dealer Region Name  Enquiry Count  Booking Count  Enquiry Ratio  \
# 0           0        Central RO1           6273            665       0.077258
# 1           1        Central RO2           7349            620       0.090510
#
#    Booking Ratio  Enq to Booking Ratio  Avg_Enquiry  Avg_booking
# 0       0.085608              0.106010  4776.176471   456.941176
# 1       0.079815              0.084365  4776.176471   456.941176

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

df4.plot(kind='line',x='Dealer Region Name', y='Avg_Enquiry', color='red',linewidth=2,ax=ax)
splot = df4.plot(kind='bar',x='Dealer Region Name',y='Enquiry Count', color="dodgerblue",legend=False,ax=ax)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Enquiry Count", fontsize=12)#
plt.xlabel("Regions", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=10000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(loc='upper center', bbox_to_anchor=(0.1, 1.01), ncol=2)

plt.title("Region wise CTB Enquiry", fontsize=12)
#plt.subplots_adjust(left=0.15)
#ax2 = ax.twinx()

#plt.grid(color='lightgrey', linewidth=0.7)
ax.legend([" Region Wise Average CTB Enquiry "],loc="upper center", bbox_to_anchor=(0.195, 1.0))
#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#chart18", bbox_inches='tight')      
plt.show()

# %%
df4['Enq to Booking Ratio']= df4['Enq to Booking Ratio'] * 100

# %%
df4['Enquiry to booking ratio']= df4['Enq to Booking Ratio'].round(2).astype(str)+ '%'

# %%
data = df4[['Dealer Region Name','Enquiry to booking ratio','Enquiry Count','Booking Count']]
data
# Out:
#    Dealer Region Name Enquiry to booking ratio  Enquiry Count  Booking Count
# 0         Central RO1                    10.6%           6273            665
# 1         Central RO2                    8.44%           7349            620
# 2         Central RO3                   10.11%           5710            577
# 3            East RO1                   11.22%           3717            417
# 4            East RO2                    7.42%           1375            102
# 5            East RO3                   10.02%           3043            305
# 6           North RO1                   11.01%           3468            382
# 7           North RO2                    8.03%           3364            270
# 8           North RO3                   12.59%           3932            495
# 9           South RO1                    9.58%           4406            422
# 10          South RO2                    8.02%           9116            731
# 11          South RO3                     8.2%           2561            210
# 12          South RO4                    9.57%           6518            624
# 13           West RO1                   10.24%           6502            666
# 14           West RO2                   12.34%           4256            525
# 15           West RO3                    7.79%           5815            453
# 16           West RO4                    8.02%           3790            304

# %%
data.to_excel("Region wise.xlsx")

# %%
df4['Booking Count'].sum()
# Out:
# 7768

# %%
df['Total Booking'].sum()
# Out:
# 8160

# %%
df
# Out:
#     Unnamed: 0 ORDER_DATEMonthKey  Year  Month  Enquiry Count  CTB_BOOKING_Y  \
# 0            0           2020_Jan  2020      1            191              0
# 1            4           2020_Feb  2020      2            350              0
# 2            5           2020_Mar  2020      3            688              8
# 3            6           2020_Apr  2020      4           4051             50
# 4            7           2020_May  2020      5           2224             40
# 5            8           2020_Jun  2020      6           5888             67
# 6            9           2020_Jul  2020      7           4902             73
# 7           10           2020_Aug  2020      8           4859            101
# 8           11           2020_Sep  2020      9           6012            108
# 9            1           2020_Oct  2020     10           8590            535
# 10           2           2020_Nov  2020     11           6887            361
# 11           3           2020_Dec  2020     12           6603            182
# 12          12           2021_Jan  2021      1           5279            191
# 13          13           2021_Feb  2021      2           4662            239
# 14          14           2021_Mar  2021      3           4606            253
# 15          15           2021_Apr  2021      4           3955            300
# 16          16           2021_May  2021      5           4192            192
# 17          17           2021_Jun  2021      6           7368            764
#
#     CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 0               1             1            0           0                  0
# 1               8             3            0           0                  0
# 2              31             2            0           0                  0
# 3               9             0          114           1                  0
# 4              50            30          156          66                  0
# 5             162           106          122         112                  0
# 6             244           159            0           0                  0
# 7             275           219            0           0                  0
# 8             357           212            0           0                  0
# 9             416           273            0           0                  0
# 10            403           295            0           0                  0
# 11            383           297            0           0               2712
# 12            326           244            0           0                727
# 13            328           229            0           0               1346
# 14            352           242            0           0               1441
# 15            280           209            0           0               1966
# 16            181           110            0           0                610
# 17            498           341            0           0               1077
#
#     Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 0        0.0               120               0                  1
# 1        0.0               276               0                  8
# 2        0.0               664               8                 39
# 3    63489.2              4487             164                 59
# 4     4396.2              1657             196                 90
# 5    73959.2              5127             189                229
# 6   174323.6              5004              73                317
# 7    28113.6              4012             101                376
# 8    52529.5              5694             108                465
# 9    96675.5              8000             535                951
# 10   95348.7              5874             361                764
# 11  115247.1              6236             182                565
# 12   79419.4              4057             191                517
# 13   70470.9              3835             239                567
# 14  110114.8              4403             253                605
# 15   89408.1              3768             300                580
# 16  173071.1              3074             192                373
# 17  263053.8              5292             764               1262
#
#     Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 0               1             1            191                 0.005236
# 1               8             3            350                 0.008571
# 2              39             2            688                 0.002907
# 3             173             0           4051                 0.000000
# 4             246            96           2224                 0.043165
# 5             351           218           5888                 0.037024
# 6             317           159           4902                 0.032436
# 7             376           219           4859                 0.045071
# 8             465           212           6012                 0.035263
# 9             951           273           8590                 0.031781
# 10            764           295           6887                 0.042834
# 11            565           297           9315                 0.031884
# 12            517           244           6006                 0.040626
# 13            567           229           6008                 0.038116
# 14            605           242           6047                 0.040020
# 15            580           209           5921                 0.035298
# 16            373           110           4802                 0.022907
# 17           1262           341           8445                 0.040379

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

df4.plot(kind='line',x='Dealer Region Name', y='Avg_booking', color='red',ax=ax)
splot = df4.plot(kind='bar',x='Dealer Region Name',y='Booking Count', color="dodgerblue",legend=False,ax=ax)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')

#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)
plt.xlabel("Regions", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=1000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(loc='upper center', bbox_to_anchor=(0.195, 1.01), ncol=2)

plt.title("Region wise CTB Booking", fontsize=12)
#plt.subplots_adjust(left=0.15)
#ax2 = ax.twinx()

#plt.grid(color='lightgrey', linewidth=0.7)
ax.legend([" Region Wise Average CTB Booking "],loc="upper center", bbox_to_anchor=(0.195, 1.0))
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#19.jpg", bbox_inches='tight')        
plt.show()

# %%
df4['Enquiry Count'].sum()
# Out:
# 81195

# %%
df4['Booking Count'].sum()
# Out:
# 7768

# %% [markdown]
# ## Model

# %%
df5 = pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "model_final")

# %%
df5
# Out:
#     Unnamed: 0           MODEL EQCR_MODEL_NAME  Enquiry Count  Booking Count  \
# 0            0            AURA            AURA           4285          353.0
# 1            1         Alcazar         Alcazar           3360          735.0
# 2            2     All New i20     All New i20           7256         1286.0
# 3            3           CRETA           Creta            175            3.0
# 4            4         Elantra         Elantra            192            2.0
# 5            5       Elite i20             NaN           4193            NaN
# 6            6       Grand i10       Grand i10           1987           32.0
# 7            7  Grand i10 NIOS  Grand i10 NIOS           9011          644.0
# 8            8      I20 ACTIVE             NaN              3            NaN
# 9            9         Kona EV         Kona EV            283            3.0
# 10          10       New Creta       New Creta          31027         3454.0
# 11          11       New Verna       New Verna           4307          234.0
# 12          12          Santro          Santro           4286          206.0
# 13          13          Tucson          Tucson            327            8.0
# 14          14           Venue           Venue          10501          807.0
# 15          15           Xcent           Xcent              2            1.0
#
#        _merge  Enq to Booking Ratio
# 0        both              0.082380
# 1        both              0.218750
# 2        both              0.177233
# 3        both              0.017143
# 4        both              0.010417
# 5   left_only                   NaN
# 6        both              0.016105
# 7        both              0.071468
# 8   left_only                   NaN
# 9        both              0.010601
# 10       both              0.111322
# 11       both              0.054330
# 12       both              0.048063
# 13       both              0.024465
# 14       both              0.076850
# 15       both              0.500000

# %%
df5 = df5.reindex(index=order_by_index(df5.index, index_natsorted(df5['Enquiry Count'],reverse=True)))
from matplotlib.pyplot import figure
#from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(9, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

splot = sns.barplot(data=df5[0:12], x = 'MODEL', y = 'Enquiry Count', ci = None, color="dodgerblue")
#for p in splot.patches:
        #splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               #'center', xytext = (0, 10), textcoords = 'offset points') 
        

#ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylim(ymax=35000, ymin=0)
ax.set_ylabel('Enquiry Count',fontsize=12)
#ax.legend()
plt.xticks(rotation=45)
plt.xlabel("Model",fontsize=12)
#ax.legend(["Model Wise Enquiry Count "],loc="upper center", bbox_to_anchor=(0.82, 1.0))
#plt.title("Model Wise Enquiry Count",fontsize=12)

plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#chart20.jpg", bbox_inches='tight')
plt.show()

# %%
df5['Enquiry Count'].sum()
# Out:
# 81195

# %%
df5 = df5.reindex(index=order_by_index(df5.index, index_natsorted(df5['Booking Count'],reverse=True)))
from matplotlib.pyplot import figure
#from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(9, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

splot = sns.barplot(data=df5[0:12], x = 'MODEL', y = 'Booking Count', ci = None, color="dodgerblue")
#for p in splot.patches:
       #splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               #'center', xytext = (0, 10), textcoords = 'offset points') 
        

#ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylim(ymax=5000, ymin=0)
ax.set_ylabel('Booking Count',fontsize=12)
#ax.legend()
plt.xticks(rotation=45)
plt.xlabel("Model",fontsize=12)
#ax.legend(["Booking count "],loc="upper center", bbox_to_anchor=(0.88, 1.0))
plt.title("Booking Count by Model",fontsize=12)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#21.jpg", bbox_inches='tight')
plt.show()

# %%
df5.sort_values("Enquiry Count", axis = 0, ascending = False, inplace = True, na_position ='last')

# %%
df5['Booking Count'].sum()
# Out:
# 7768.0

# %%
df_model_e2b1 = df5.copy()

# %%
df_model_e2b1.drop(df_model_e2b1.loc[df_model_e2b1['MODEL']=='Elite i20'].index,inplace=True)

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df_model_e2b1[0:11].plot(kind='bar',x='MODEL',y='Enq to Booking Ratio', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate('{:.1f}%'.format(100*p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylabel("Ratio", fontsize=12)
plt.xlabel("Model", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=0.3, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["Enquiry to Booking Ratio"],loc="upper left", bbox_to_anchor=(0.0, 1.0))


plt.title("Model Wise Enquiry to Booking Ratio")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')       
plt.savefig("#22.jpg", bbox_inches='tight')      
plt.show()

# %%
df6 = pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "variant_final")

# %%
df6['Enquiry Count'].sum()
# Out:
# 67011

# %%
df_var = {'Variant Type':['Low', 'Med', 'High'],
        'Enquiry Count':[27140,25788,10884],
        'Booking Count':[2115,2472,1211],
        'Enquiry to Booking Ratio':[0.033144,0.038739,0.018978]}

# %%
df_variant = pd.DataFrame(df_var)

# %%
df_variant
# Out:
#   Variant Type  Enquiry Count  Booking Count  Enquiry to Booking Ratio
# 0          Low          27140           2115                  0.033144
# 1          Med          25788           2472                  0.038739
# 2         High          10884           1211                  0.018978

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

splot = df_variant.plot(kind='bar',x='Variant Type',y='Enquiry Count', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')

#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Enquiry Count", fontsize=12)
plt.xlabel("Variant", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=40000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(["Variant Enquiry Count"],loc="upper left", bbox_to_anchor=(0.0, 1.0))


plt.title("Variant Wise Enquiry count")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')        
plt.savefig("#23.jpg", bbox_inches='tight')       
plt.show()

# %%
27140 + 25788 + 10884
# Out:
# 63812

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df_variant.plot(kind='bar',x='Variant Type',y='Booking Count', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)
plt.xlabel("Variant", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=5000, ymin=1000)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(["Variant Booking Count"],loc="upper left", bbox_to_anchor=(0.0, 1.0))


plt.title("Variant wise booking count")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')       
plt.savefig("#24.jpg", bbox_inches='tight')       
plt.show()

# %%
# plotting percentage in axis 


from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df_variant.plot(kind='bar',x='Variant Type',y='Enquiry to Booking Ratio', color="dodgerblue",legend=False,ax=ax,)



for p in splot.patches:
        splot.annotate('{:.1f}%'.format(100*p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylabel("Conversion Ratio", fontsize=12)
plt.xlabel("Variant", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=0.06, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(["Enquiry to Booking Ratio"],loc="upper left", bbox_to_anchor=(0.0, 1.0))


plt.title("Variant Wise Conversion Ratio")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

plt.grid(color='lightgrey', linewidth=0.7,axis='y')        
plt.savefig("#25.jpg", bbox_inches='tight')       
plt.show()

# %%
df7 = pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "body_final")

# %%
df7.head()
# Out:
#    Unnamed: 0  Body Type  Enquiry Count  Booking Count  Enquiry Ratio  \
# 0           0  HatchBack          26733           2168       0.329968
# 1           1        SUV          45215           5007       0.558093
# 2           2      Sedan           9069            593       0.111939
#
#    Booking Ratio  Enq to Booking Ratio
# 0       0.279094              0.081098
# 1       0.644567              0.110738
# 2       0.076339              0.065388

# %%
df_bod = {'Body Type':['HatchBack', 'Sedan', 'SUV'],
        'Enquiry Count':[25741,8468,39552],
        'Booking Count':[2044,522,3940],
        'Enq to Booking Ratio':[0.027711,0.007077,0.05341649807]}

# %%
df_body = pd.DataFrame(df_bod)

# %%
df_body
# Out:
#    Body Type  Enquiry Count  Booking Count  Enq to Booking Ratio
# 0  HatchBack          25741           2044              0.027711
# 1      Sedan           8468            522              0.007077
# 2        SUV          39552           3940              0.053416

# %%
# plotting percentage in axis 


from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df_body.plot(kind='bar',x='Body Type',y='Enquiry Count', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')

        
plt.ylim(ymax=50000, ymin=0)
plt.xticks(rotation=45)
plt.title("Body Type Enquiry Count")
#ax.legend(["Body Type Enquiry Count"],loc="upper left", bbox_to_anchor=(0.0, 1.0))
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#26body.jpg", bbox_inches='tight') 
plt.show()

# %%
# plotting percentage in axis 


from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df_body.plot(kind='bar',x='Body Type',y='Booking Count', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')

        
plt.ylim(ymax=4500, ymin=0)
plt.xticks(rotation=45)
plt.title("Body Type Booking Count")
#ax.legend(["Body Type Booking Count"],loc="upper left", bbox_to_anchor=(0.0, 1.0))
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#27body.jpg", bbox_inches='tight') 
plt.show()

# %%
# plotting percentage in axis 


from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = sns.barplot(data=df_body, x = 'Body Type', y = 'Enq to Booking Ratio', ci = None, color="dodgerblue")



for p in splot.patches:
        splot.annotate('{:.1f}%'.format(100*p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylabel("Conversion Ratio", fontsize=12)
plt.xlabel("Body Type", fontsize = 12)
plt.xticks(rotation=0)
plt.ylim(ymax=0.06, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(["Enquiry to Booking Ratio"],loc="upper left", bbox_to_anchor=(0.0, 1.0))


plt.title("Body Type Wise Conversion Ratio")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
        
plt.savefig("#28body.jpg", bbox_inches='tight')       
plt.show()

# %%
df7 = pd.read_excel("CTB_monthly_report_may.xlsx", sheet_name = "fuel_final")

# %%
df7.head(2)
# Out:
#    Unnamed: 0 Fuel Type  Enquiry Count  Booking Count  Enquiry Ratio  \
# 0           0       CNG           3569            300       0.043956
# 1           1    Diesel          18715           1930       0.230494
#
#    Booking Ratio  Enq to Booking Ratio
# 0       0.038740              0.084057
# 1       0.249225              0.103126

# %%
df7.sort_values("Enquiry Count", axis = 0, ascending = False, inplace = True, na_position ='last')

# %%
#df_fuel_elec.drop(df_fuel_elec.loc[df_fuel_elec['Fuel Type']=='Electric'].index,inplace=True)

# %%
# plotting percentage in axis 


from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = sns.barplot(data=df7, x = 'Fuel Type', y = 'Enquiry Count', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')

        

plt.xticks(rotation=45)
plt.ylim(ymax=60000, ymin=0)
plt.title("Fuel Type Enquiry Count")
#ax.legend(["Fuel Type Enquiry Count"],loc="upper left", bbox_to_anchor=(0.5, 1.2))
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#chart29.jpg", bbox_inches='tight')
plt.show()

# %%
# plotting percentage in axis 


from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = sns.barplot(data=df7, x = 'Fuel Type', y = 'Booking Count', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')

        

plt.xticks(rotation=45)
plt.ylim(ymax=5000, ymin=0)
plt.title("Fuel Type Booking Count")
#ax.legend(["Fuel Type Booking Count"],loc="upper left", bbox_to_anchor=(0.0, 1.0))

plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#29fuel.jpg", bbox_inches='tight')
plt.show()

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(6, 2.5), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


#plt.figure(figsize=(6, 3))
splot = sns.barplot(data=df7, x = 'Fuel Type', y = 'Booking Ratio', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate('{:.0f}%'.format(100*p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
        
plt.ylim(ymax=0.9, ymin=0)
ax.yaxis.set_major_formatter(PercentFormatter(1))
#ax.legend(["Fuel Type Booking Ratio"],loc="upper left", bbox_to_anchor=(0.0, 1.0))
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.title("Fuel Type Booking Ratio")
plt.savefig("#31fuel.jpg", bbox_inches='tight')

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(7, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


#plt.figure(figsize=(6, 3))
splot = sns.barplot(data=df7, x = 'Fuel Type', y = 'Enq to Booking Ratio', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate('{:.0f}%'.format(100*p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
        
plt.ylim(ymax=0.08, ymin=0)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.title("Fuel Type Coverstion Ratio")
plt.savefig("#31fuel.jpg", bbox_inches='tight')

# %% [markdown]
# ## Zone

# %%
GDMS_booking_north = Zone(GDMS_booking_region,"North")
GDMS_booking_east = Zone(GDMS_booking_region,"East")
GDMS_booking_west = Zone(GDMS_booking_region,"West")
GDMS_booking_south = Zone(GDMS_booking_region,"South")
GDMS_booking_central = Zone(GDMS_booking_region,"Central")
# Out:
# North :-  677 470 1147 0.5902353966870096 0.4097646033129904
# East :-  511 313 824 0.6201456310679612 0.37985436893203883
# West :-  1218 730 1948 0.6252566735112937 0.37474332648870634
# South :-  977 1010 1987 0.49169602415702063 0.5083039758429794
# Central :-  921 941 1862 0.49462943071965626 0.5053705692803437

# %%
frames = [GDMS_booking_north, GDMS_booking_east,GDMS_booking_west,GDMS_booking_south, GDMS_booking_central]

# %%
ctb_zones = pd.concat(frames)

# %%
ctb_zones
# Out:
#    BKNG_DATE_NEWMonthKey  Offline Booking  Online Booking  Total Booking
# 0                2020_10               46              71            117
# 1                2020_11               47              45             92
# 2                2020_12               40              22             62
# 3                 2020_3                2               2              4
# 4                 2020_4                3               7             10
# 5                 2020_5                9               4             13
# 6                 2020_6               23               7             30
# 7                 2020_7               28              10             38
# 8                 2020_8               30              15             45
# 9                 2020_9               45              17             62
# 10                2021_1               64              41            105
# 11                2021_2               49              35             84
# 12                2021_3               93              42            135
# 13                2021_4               69              47            116
# 14                2021_5               29              29             58
# 15                2021_6              100              76            176
# 0                2020_10               48              42             90
# 1                2020_11               55              38             93
# 2                2020_12               38              18             56
# 3                 2020_2                1               0              1
# 4                 2020_3                3               0              3
# 5                 2020_4                0               6              6
# 6                 2020_5                5               7             12
# 7                 2020_6               31              14             45
# 8                 2020_7               24              12             36
# 9                 2020_8               31              12             43
# 10                2020_9               34              11             45
# 11                2021_1               30              15             45
# 12                2021_2               41              28             69
# 13                2021_3               39              33             72
# ..                   ...              ...             ...            ...
# 5                 2020_4                2              13             15
# 6                 2020_5               12               8             20
# 7                 2020_6               31              10             41
# 8                 2020_7               65              26             91
# 9                 2020_8               72              33            105
# 10                2020_9              101              35            136
# 11                2021_1               91              38            129
# 12                2021_2               54              34             88
# 13                2021_3               60              56            116
# 14                2021_4               45              73            118
# 15                2021_5               22              44             66
# 16                2021_6               91             267            358
# 0                 2020_1                1               0              1
# 1                2020_10               94              95            189
# 2                2020_11               77              85            162
# 3                2020_12               78              51            129
# 4                 2020_2                4               0              4
# 5                 2020_3                9               0              9
# 6                 2020_4                1              11             12
# 7                 2020_5               19               7             26
# 8                 2020_6               38              14             52
# 9                 2020_7               60              10             70
# 10                2020_8               62              22             84
# 11                2020_9               76              27            103
# 12                2021_1               43              67            110
# 13                2021_2               73             102            175
# 14                2021_3               72              82            154
# 15                2021_4               63              80            143
# 16                2021_5               53              62            115
# 17                2021_6               98             226            324
#
# [85 rows x 4 columns]

# %%
df8 = pd.read_excel("CTB_auto_monthly_report_may_Zone.xlsx", sheet_name = "GDMS_booking_north")

# %%
df8.head(14)
# Out:
#     Unnamed: 0 BKNG_DATE_NEWMonthKey  Offline Booking  Online Booking  \
# 0            0               2020_10               46              71
# 1            1               2020_11               47              45
# 2            2               2020_12               40              22
# 3            3                2020_3                2               2
# 4            4                2020_4                3               7
# 5            5                2020_5                9               4
# 6            6                2020_6               23               7
# 7            7                2020_7               28              10
# 8            8                2020_8               30              15
# 9            9                2020_9               45              17
# 10          10                2021_1               64              41
# 11          11                2021_2               49              35
# 12          12                2021_3               93              42
# 13          13                2021_4               69              47
#
#     Total Booking
# 0             117
# 1              92
# 2              62
# 3               4
# 4              10
# 5              13
# 6              30
# 7              38
# 8              45
# 9              62
# 10            105
# 11             84
# 12            135
# 13            116

# %%
df8 = df8.reindex(index=order_by_index(df8.index, index_natsorted(df8.BKNG_DATE_NEWMonthKey)))

# %%
df8.BKNG_DATE_NEWMonthKey
# Out:
# 3      2020_3
# 4      2020_4
# 5      2020_5
# 6      2020_6
# 7      2020_7
# 8      2020_8
# 9      2020_9
# 0     2020_10
# 1     2020_11
# 2     2020_12
# 10     2021_1
# 11     2021_2
# 12     2021_3
# 13     2021_4
# 14     2021_5
# 15     2021_6
# Name: BKNG_DATE_NEWMonthKey, dtype: object

# %%
#df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'] .replace(['2020_1'], '2020_Jan')
#df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_2'], '2020_Feb')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_3'], '2020_Mar')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_4'], '2020_Apr')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_5'], '2020_May')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_6'], '2020_Jun')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_7'], '2020_Jul')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_8'], '2020_Aug')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_9'], '2020_Sep')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_10'], '2020_Oct')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_11'], '2020_Nov')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2020_12'], '2020_Dec')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2021_1'], '2021_Jan')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2021_2'], '2021_Feb')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2021_3'], '2021_Mar')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2021_4'], '2021_Apr')
df8['BKNG_DATE_NEWMonthKey'] = df8['BKNG_DATE_NEWMonthKey'].replace(['2021_5'], '2021_May')

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
 
# multiple line plots

plt.figure(figsize=(7,2.5))

plt.xticks(rotation=45)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Offline Booking', data=df8, marker='o', markerfacecolor='black', markersize=3, color='orange', linewidth=2)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Online Booking', data=df8, marker='d', color='grey', linestyle='dashed', label="CTB Booking",linewidth=2)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Total Booking', data=df8, marker='x', color='royalblue', linewidth=2)
plt.ylim(ymax=200, ymin=0)
plt.title("North Zone" )
plt.ylabel("Booking Count")

# show legend
#plt.legend(['Offline Booking'\n 'Online Booking'\n 'Total Booking'],loc="upper left", bbox_to_anchor=(0.0, 1.0)
plt.legend(loc='upper left')
# show graph
plt.grid(color='lightgrey', linewidth=0.7,axis='y') 
plt.savefig("#32North.jpg", bbox_inches='tight')
plt.show()

# %%
df8['Online Booking'].sum()
# Out:
# 470

# %%
df8['Offline Booking'].sum()
# Out:
# 677

# %%
df81 = pd.read_excel("CTB_auto_monthly_report_may_Zone.xlsx", sheet_name = "GDMS_booking_east")
df81 = df81.reindex(index=order_by_index(df81.index, index_natsorted(df81.BKNG_DATE_NEWMonthKey)))

# %%
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_2'], '2020_Feb')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_3'], '2020_Mar')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_4'], '2020_Apr')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_5'], '2020_May')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_6'], '2020_Jun')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_7'], '2020_Jul')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_8'], '2020_Aug')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_9'], '2020_Sep')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_10'], '2020_Oct')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_11'], '2020_Nov')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2020_12'], '2020_Dec')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2021_1'], '2021_Jan')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2021_2'], '2021_Feb')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2021_3'], '2021_Mar')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2021_4'], '2021_Apr')
df81['BKNG_DATE_NEWMonthKey'] = df81['BKNG_DATE_NEWMonthKey'].replace(['2021_5'], '2021_May')

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
 
# multiple line plots

plt.figure(figsize=(7,2.5))

plt.xticks(rotation=45)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Offline Booking', data=df81, marker='o', markerfacecolor='black', markersize=2, color='orange', linewidth=2)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Online Booking', data=df81, marker='d', color='grey', linewidth=2, linestyle='dashed', label="CTB Booking")
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Total Booking', data=df81, marker='x', color='royalblue', linewidth=2)
plt.ylim(ymax=150, ymin=0)
plt.title("East Zone" )
plt.ylabel("Booking Count")

# show legend
plt.legend(loc="upper left")
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#33East.jpg", bbox_inches='tight')
#plt.grid(color='lightgrey', linewidth=0.7)
# show graph
plt.show()

# %%
df81['Online Booking'].sum()
# Out:
# 313

# %%
df81['Offline Booking'].sum()
# Out:
# 511

# %%
df82 = pd.read_excel("CTB_auto_monthly_report_may_Zone.xlsx", sheet_name = "GDMS_booking_west")

# %%
df82 = df82.reindex(index=order_by_index(df82.index, index_natsorted(df82.BKNG_DATE_NEWMonthKey)))

# %%
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_2'], '2020_Feb')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_3'], '2020_Mar')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_4'], '2020_Apr')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_5'], '2020_May')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_6'], '2020_Jun')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_7'], '2020_Jul')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_8'], '2020_Aug')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_9'], '2020_Sep')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_10'], '2020_Oct')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_11'], '2020_Nov')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2020_12'], '2020_Dec')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2021_1'], '2021_Jan')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2021_2'], '2021_Feb')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2021_3'], '2021_Mar')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2021_4'], '2021_Apr')
df82['BKNG_DATE_NEWMonthKey'] = df82['BKNG_DATE_NEWMonthKey'].replace(['2021_5'], '2021_May')

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
 
# multiple line plots

plt.figure(figsize=(7,2.5))

plt.xticks(rotation=45)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Offline Booking', data=df82, marker='o', markerfacecolor='black', markersize=2, color='orange', linewidth=2)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Online Booking', data=df82, marker='d', color='grey', linewidth=2, linestyle='dashed', label="CTB Booking")
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Total Booking', data=df82, marker='x', color='royalblue', linewidth=2)
plt.title("West Zone" )
plt.ylabel("Booking Count")

# show legend
plt.legend(loc='upper left')

plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#33Westzone.jpg", bbox_inches='tight')
# show graph
plt.show()

# %%
df82['Online Booking'].sum()
# Out:
# 730

# %%
df82['Offline Booking'].sum()
# Out:
# 1218

# %%
df83 = pd.read_excel("CTB_auto_monthly_report_may_Zone.xlsx", sheet_name = "GDMS_booking_south")

# %%
df83 = df83.reindex(index=order_by_index(df83.index, index_natsorted(df83.BKNG_DATE_NEWMonthKey)))

# %%
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_2'], '2020_Feb')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_3'], '2020_Mar')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_4'], '2020_Apr')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_5'], '2020_May')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_6'], '2020_Jun')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_7'], '2020_Jul')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_8'], '2020_Aug')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_9'], '2020_Sep')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_10'], '2020_Oct')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_11'], '2020_Nov')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2020_12'], '2020_Dec')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2021_1'], '2021_Jan')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2021_2'], '2021_Feb')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2021_3'], '2021_Mar')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2021_4'], '2021_Apr')
df83['BKNG_DATE_NEWMonthKey'] = df83['BKNG_DATE_NEWMonthKey'].replace(['2021_5'], '2021_May')

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
 
# multiple line plots

plt.figure(figsize=(7,2.5))

plt.xticks(rotation=45)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Offline Booking', data=df83, marker='o', markerfacecolor='black', markersize=2, color='orange', linewidth=2)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Online Booking', data=df83, marker='d', color='grey', linewidth=2, linestyle='dashed', label="CTB Booking")
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Total Booking', data=df83, marker='x', color='royalblue', linewidth=2)
plt.title("South Zone" )
plt.ylabel("Booking Count")

# show legend
plt.legend()
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#34southzone.jpg", bbox_inches='tight')

# show graph
plt.show()

# %%
df83['Online Booking'].sum()
# Out:
# 1010

# %%
df83['Offline Booking'].sum()
# Out:
# 977

# %%
df84 = pd.read_excel("CTB_auto_monthly_report_may_Zone.xlsx", sheet_name = "GDMS_booking_central")

# %%
df84 = df84.reindex(index=order_by_index(df84.index, index_natsorted(df84.BKNG_DATE_NEWMonthKey)))

# %%
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_1'], '2020_Jan')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_2'], '2020_Feb')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_3'], '2020_Mar')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_4'], '2020_Apr')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_5'], '2020_May')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_6'], '2020_Jun')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_7'], '2020_Jul')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_8'], '2020_Aug')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_9'], '2020_Sep')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_10'], '2020_Oct')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_11'], '2020_Nov')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2020_12'], '2020_Dec')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2021_1'], '2021_Jan')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2021_2'], '2021_Feb')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2021_3'], '2021_Mar')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2021_4'], '2021_Apr')
df84['BKNG_DATE_NEWMonthKey'] = df84['BKNG_DATE_NEWMonthKey'].replace(['2021_5'], '2021_May')

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
 
# multiple line plots

plt.figure(figsize=(7,2.5))

plt.xticks(rotation=45)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Offline Booking', data=df84, marker='o', markerfacecolor='black', markersize=2, color='orange', linewidth=2)
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Online Booking', data=df84, marker='d', color='grey',linewidth=2, linestyle='dashed', label="CTB Booking")
plt.plot( 'BKNG_DATE_NEWMonthKey', 'Total Booking', data=df84, marker='x', color='royalblue', linewidth=2)
plt.ylim(ymax=250, ymin=0)
plt.title("Central Zone" )
plt.ylabel("Booking Count")

# show legend
plt.legend(loc='upper left')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#35Centralzone.jpg", bbox_inches='tight')
# show graph
plt.show()

# %%
df84['Online Booking'].sum()
# Out:
# 941

# %%
df84['Offline Booking'].sum()
# Out:
# 921

# %% [markdown]
# ## EBR

# %%
df
# Out:
#     Unnamed: 0 ORDER_DATEMonthKey  Year  Month  Enquiry Count  CTB_BOOKING_Y  \
# 0            0           2020_Jan  2020      1            191              0
# 1            4           2020_Feb  2020      2            350              0
# 2            5           2020_Mar  2020      3            688              8
# 3            6           2020_Apr  2020      4           4051             50
# 4            7           2020_May  2020      5           2224             40
# 5            8           2020_Jun  2020      6           5888             67
# 6            9           2020_Jul  2020      7           4902             73
# 7           10           2020_Aug  2020      8           4859            101
# 8           11           2020_Sep  2020      9           6012            108
# 9            1           2020_Oct  2020     10           8590            535
# 10           2           2020_Nov  2020     11           6887            361
# 11           3           2020_Dec  2020     12           6603            182
# 12          12           2021_Jan  2021      1           5279            191
# 13          13           2021_Feb  2021      2           4662            239
# 14          14           2021_Mar  2021      3           4606            253
# 15          15           2021_Apr  2021      4           3955            300
# 16          16           2021_May  2021      5           4192            192
# 17          17           2021_Jun  2021      6           7368            764
#
#     CTB_BOOKING_N  Retail Count  CRM Booking  CRM Retail  Financial_enquiry  \
# 0               1             1            0           0                  0
# 1               8             3            0           0                  0
# 2              31             2            0           0                  0
# 3               9             0          114           1                  0
# 4              50            30          156          66                  0
# 5             162           106          122         112                  0
# 6             244           159            0           0                  0
# 7             275           219            0           0                  0
# 8             357           212            0           0                  0
# 9             416           273            0           0                  0
# 10            403           295            0           0                  0
# 11            383           297            0           0               2712
# 12            326           244            0           0                727
# 13            328           229            0           0               1346
# 14            352           242            0           0               1441
# 15            280           209            0           0               1966
# 16            181           110            0           0                610
# 17            498           341            0           0               1077
#
#     Visitors  CTB Registration  Online Booking  Total CTB Booking  \
# 0        0.0               120               0                  1
# 1        0.0               276               0                  8
# 2        0.0               664               8                 39
# 3    63489.2              4487             164                 59
# 4     4396.2              1657             196                 90
# 5    73959.2              5127             189                229
# 6   174323.6              5004              73                317
# 7    28113.6              4012             101                376
# 8    52529.5              5694             108                465
# 9    96675.5              8000             535                951
# 10   95348.7              5874             361                764
# 11  115247.1              6236             182                565
# 12   79419.4              4057             191                517
# 13   70470.9              3835             239                567
# 14  110114.8              4403             253                605
# 15   89408.1              3768             300                580
# 16  173071.1              3074             192                373
# 17  263053.8              5292             764               1262
#
#     Total Booking  Total Retail  Total Enquiry  Retail Conversion Ratio
# 0               1             1            191                 0.005236
# 1               8             3            350                 0.008571
# 2              39             2            688                 0.002907
# 3             173             0           4051                 0.000000
# 4             246            96           2224                 0.043165
# 5             351           218           5888                 0.037024
# 6             317           159           4902                 0.032436
# 7             376           219           4859                 0.045071
# 8             465           212           6012                 0.035263
# 9             951           273           8590                 0.031781
# 10            764           295           6887                 0.042834
# 11            565           297           9315                 0.031884
# 12            517           244           6006                 0.040626
# 13            567           229           6008                 0.038116
# 14            605           242           6047                 0.040020
# 15            580           209           5921                 0.035298
# 16            373           110           4802                 0.022907
# 17           1262           341           8445                 0.040379

# %% [markdown]
# EBR COUNT FOR MARCH
#
# E - 355252
# B - 80431
# R - 53499
#
# NOTE : Pure offline = E - (CTB+FINANCE)
# FOR EG: feb
# 355239 - 6008 = 349231

# %%
xEQ_Pure_Offline = 141560 - 4802
xEQ_Pure_Offline
# Out:
# 136758

# %%
xBook_Pure_Offline = 21954- 373
xBook_Pure_Offline
# Out:
# 21581

# %%
xRetail_Pure_Offline = 15693-110
xRetail_Pure_Offline
# Out:
# 15583

# %%
import pandas as pd
  
# intialise data of lists.
df_EBR = {'Month':['Jan20', 'Feb20', 'Mar20', 'Apr20','May20','Jun20','Jul20','Aug20','Sep20','Oct20','Nov20','Dec20','Jan21','Feb21','Mar21','Apr21','May21'],
        'EQ_Pure_Offline':[331139,342730,283911,20818,95886,275224,287142,289506,336103,337111,347013,411500,353202,349231,349337,279637,136758],
        'EQ_CTB_generated':[191,350,688,4051,2224,5888,4902,4869,6012,8590,6887,9314,6006,6008,6047,5921,4802],
        'Book_Pure_Offline':[52318,51783,48670,1056,14906,46980,57238,66792,56737,73108,84866,82734,78059,78579,79826,55460,21581],
        'Book_CTB_generated':[1,8,39,59,90,229,317,376,465,951,764,565,517,567,605,580,373],
        'Retail_Pure_Offline':[41000,38498,20352,36,10792,30823,37374,43400,37958,53650,55312,56849,47283,50588,53257,41581,15583],
        'Retail_CTB_generated':[1,3,2,0,30,106,159,219,212,274,296,297,243,229,242,209,110],
         'Month_y':['2020-Jan', '2020-Feb', '2020-Mar', '2020-Apr','2020-May','2020-Jun','2020-Jul','2020-Aug','2020-Sep','2020-Oct','2020-Nov','2020-Dec','2021-Jan','2021-Feb','2021-Mar','2021-Apr','2021-May']}
  
# Create DataFrame
EBR = pd.DataFrame(df_EBR)
EBR
# Out:
#     Month  EQ_Pure_Offline  EQ_CTB_generated  Book_Pure_Offline  \
# 0   Jan20           331139               191              52318
# 1   Feb20           342730               350              51783
# 2   Mar20           283911               688              48670
# 3   Apr20            20818              4051               1056
# 4   May20            95886              2224              14906
# 5   Jun20           275224              5888              46980
# 6   Jul20           287142              4902              57238
# 7   Aug20           289506              4869              66792
# 8   Sep20           336103              6012              56737
# 9   Oct20           337111              8590              73108
# 10  Nov20           347013              6887              84866
# 11  Dec20           411500              9314              82734
# 12  Jan21           353202              6006              78059
# 13  Feb21           349231              6008              78579
# 14  Mar21           349337              6047              79826
# 15  Apr21           279637              5921              55460
# 16  May21           136758              4802              21581
#
#     Book_CTB_generated  Retail_Pure_Offline  Retail_CTB_generated   Month_y
# 0                    1                41000                     1  2020-Jan
# 1                    8                38498                     3  2020-Feb
# 2                   39                20352                     2  2020-Mar
# 3                   59                   36                     0  2020-Apr
# 4                   90                10792                    30  2020-May
# 5                  229                30823                   106  2020-Jun
# 6                  317                37374                   159  2020-Jul
# 7                  376                43400                   219  2020-Aug
# 8                  465                37958                   212  2020-Sep
# 9                  951                53650                   274  2020-Oct
# 10                 764                55312                   296  2020-Nov
# 11                 565                56849                   297  2020-Dec
# 12                 517                47283                   243  2021-Jan
# 13                 567                50588                   229  2021-Feb
# 14                 605                53257                   242  2021-Mar
# 15                 580                41581                   209  2021-Apr
# 16                 373                15583                   110  2021-May

# %%
EBR['Offline EB'] = (EBR['Book_Pure_Offline']/EBR['EQ_Pure_Offline']).round(2)
EBR['Online EB'] = (EBR['Book_CTB_generated']/EBR['EQ_CTB_generated']).round(2)
EBR['Offline ER'] = (EBR['Retail_Pure_Offline']/EBR['EQ_Pure_Offline']).round(2)
EBR['Online ER'] = (EBR['Retail_CTB_generated']/EBR['EQ_CTB_generated']).round(2)

# %%
EBR
# Out:
#     Month  EQ_Pure_Offline  EQ_CTB_generated  Book_Pure_Offline  \
# 0   Jan20           331139               191              52318
# 1   Feb20           342730               350              51783
# 2   Mar20           283911               688              48670
# 3   Apr20            20818              4051               1056
# 4   May20            95886              2224              14906
# 5   Jun20           275224              5888              46980
# 6   Jul20           287142              4902              57238
# 7   Aug20           289506              4869              66792
# 8   Sep20           336103              6012              56737
# 9   Oct20           337111              8590              73108
# 10  Nov20           347013              6887              84866
# 11  Dec20           411500              9314              82734
# 12  Jan21           353202              6006              78059
# 13  Feb21           349231              6008              78579
# 14  Mar21           349337              6047              79826
# 15  Apr21           279637              5921              55460
# 16  May21           136758              4802              21581
#
#     Book_CTB_generated  Retail_Pure_Offline  Retail_CTB_generated   Month_y  \
# 0                    1                41000                     1  2020-Jan
# 1                    8                38498                     3  2020-Feb
# 2                   39                20352                     2  2020-Mar
# 3                   59                   36                     0  2020-Apr
# 4                   90                10792                    30  2020-May
# 5                  229                30823                   106  2020-Jun
# 6                  317                37374                   159  2020-Jul
# 7                  376                43400                   219  2020-Aug
# 8                  465                37958                   212  2020-Sep
# 9                  951                53650                   274  2020-Oct
# 10                 764                55312                   296  2020-Nov
# 11                 565                56849                   297  2020-Dec
# 12                 517                47283                   243  2021-Jan
# 13                 567                50588                   229  2021-Feb
# 14                 605                53257                   242  2021-Mar
# 15                 580                41581                   209  2021-Apr
# 16                 373                15583                   110  2021-May
#
#     Offline EB  Online EB  Offline ER  Online ER
# 0         0.16       0.01        0.12       0.01
# 1         0.15       0.02        0.11       0.01
# 2         0.17       0.06        0.07       0.00
# 3         0.05       0.01        0.00       0.00
# 4         0.16       0.04        0.11       0.01
# 5         0.17       0.04        0.11       0.02
# 6         0.20       0.06        0.13       0.03
# 7         0.23       0.08        0.15       0.04
# 8         0.17       0.08        0.11       0.04
# 9         0.22       0.11        0.16       0.03
# 10        0.24       0.11        0.16       0.04
# 11        0.20       0.06        0.14       0.03
# 12        0.22       0.09        0.13       0.04
# 13        0.23       0.09        0.14       0.04
# 14        0.23       0.10        0.15       0.04
# 15        0.20       0.10        0.15       0.04
# 16        0.16       0.08        0.11       0.02

# %% [markdown]
# Offline EB = Dealer Enquiry to Booking Ratio
# Online EB = CTB Enquiry to Booking Ratio
# Offline ER  = Dealer Enquiry to Retail Ratio
# Online ER =  CTB Enquiry to Retail Ratio

# %%
EBR.to_excel("EBR_May.xlsx")

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(13, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()




EBR.plot(kind='line',x='Month',y='Offline EB', linewidth=3, color="orange",legend=False,ax=ax, marker='o', markerfacecolor='grey', markersize=6)
EBR.plot(kind='line',x='Month',y='Online EB', linewidth=3,legend=False, color='royalblue', ax=ax, marker='x', markerfacecolor='grey', markersize=6)
plt.ylabel("%Converted", fontsize=12)
plt.xlabel("Month", fontsize = 12)
#plt.ylim(ymax=10000, ymin=0)
plt.xticks(np.arange(17), EBR['Month'][0:17], rotation=0)
ax.legend(['Dealer Enquiry to Booking Ratio', 'CTB Enquiry to Booking Ratio'],loc='upper center', bbox_to_anchor=(0.28, 1.01), ncol=2)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylim(ymax = 0.3, ymin = 0)
#plt.grid(color='lightgrey', linewidth=0.4)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax.spines[pos].set_edgecolor('grey')
        
#plt.savefig("chart3.png", bbox_inches='tight')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#ebr_eb.png", bbox_inches='tight')
plt.show()

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
figure(num=None, figsize=(13, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()




EBR.plot(kind='line',x='Month',y='Offline ER', linewidth=3, color="orange",legend=False,ax=ax, marker='o', markerfacecolor='gray', markersize=6)
EBR.plot(kind='line',x='Month',y='Online ER', linewidth=3,legend=False, color='royalblue', marker='x', markerfacecolor='gray', markersize=6, ax=ax)
plt.ylabel("%Converted", fontsize=12)
plt.xlabel("Month", fontsize = 12)
#plt.ylim(ymax=10000, ymin=0)
plt.xticks(np.arange(17), EBR['Month'][0:17], rotation=0)
ax.legend(['Dealer Enquiry to Retail Ratio', 'CTB Enquiry to Retail Ratio'],loc='upper center', bbox_to_anchor=(0.265, 1.01), ncol=2)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.ylim(ymax = 0.3, ymin = 0)
#plt.grid(color='lightgrey', linewidth=0.4)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax.spines[pos].set_edgecolor('grey')
        
#plt.savefig("chart3.png", bbox_inches='tight')
#plt.savefig("#17.png", bbox_inches='tight')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#ebr_er.png", bbox_inches='tight')
plt.show()

# %%
EBR['EB_Diff'] = EBR['Offline EB'] - EBR['Online EB']
EBR['ER_Diff'] = EBR['Offline ER'] - EBR['Online ER']

# %%
EBR['EB_Diff'] = (EBR['EB_Diff'])*100
EBR['EB_Diff'] = EBR['EB_Diff'].round(2).astype(str)+ '%'

# %%
EBR['ER_Diff'] = (EBR['ER_Diff'])*100
EBR['ER_Diff'] = EBR['ER_Diff'].round(2).astype(str)+ '%'

# %%
EBR=EBR[['Month','EB_Diff','ER_Diff']]

# %%
EBR.to_excel("EBR_Diff.xlsx")

# %% [markdown]
# ## CUSTOMER INSIGHT

# %% [markdown]
# ## GCRM DATASET

# %%
## for april only

# %%
GCRMall_1 = pd.read_excel("GCRM_till_Mar21.xlsx", encoding = "ISO-8859-1")
print(GCRMall_1.shape)
GCRMall_1.head(2)
# Out:
# (224532, 6)
#    Unnamed: 0    LAST_NAME   CELL_PH_NUM             EMAIL_ADDR  AGE  \
# 0           0    Balvinder  9.992104e+09   mdeshwal95@gmail.com  NaN
# 1           1  Ctb Testing  9.970978e+09  ctbtesting1@gmail.com  NaN
#
#   OCCUPATION
# 0        NaN
# 1        NaN

# %%
#april
GCRMall_2 = pd.read_excel('CTB_Customer_data_20210510.xlsx')

# %%
now = pd.Timestamp('now')
GCRMall_2['BIRTH_DT'] = pd.to_datetime(GCRMall_2['BIRTH_DT'], errors ="coerce") 
GCRMall_2['BIRTH_DT'] = GCRMall_2['BIRTH_DT'].where(GCRMall_2['BIRTH_DT'] < now, GCRMall_2['BIRTH_DT'] -  np.timedelta64(100, 'Y'))   # 2
GCRMall_2['AGE'] = (now - GCRMall_2['BIRTH_DT']).astype('<m8[Y]')    # 3
GCRMall_2.head()
# Out:
#                     LAST_NAME   CELL_PH_NUM           EMAIL_ADDR SEX_MF  \
# 0               HIREN K. SHAH  9.000000e+00  example@example.com      M
# 1                SHUBHI GUPTA  5.910559e+08         no@email.com      W
# 2         SUMANTHSOLD THE CAR  1.212121e+09         no@email.com      M
# 3  KHALIQUZZAMAN AZMI SOLD ..  1.234568e+09   wasiazmi@gmail.com      M
# 4         SAHIL YASIN MANSURI  1.234568e+09         abc@mail.com      M
#
#   BIRTH_DT OCCUPATION  AGE
# 0      NaT        NaN  NaN
# 1      NaT        NaN  NaN
# 2      NaT        NaN  NaN
# 3      NaT        NaN  NaN
# 4      NaT        NaN  NaN

# %%
frames = [GCRMall_1,GCRMall_2]
#frames = [GCRM33]
GCRMall = pd.concat(frames)
print(GCRMall.shape)
print("AGE :", GCRMall.AGE.notna().sum())
print("OCC :", GCRMall.OCCUPATION.notna().sum())
print(GCRMall.columns)
GCRMall.head(2)
# Out:
# (230679, 8)
# AGE : 11924
# OCC : 17527
# Index(['AGE', 'BIRTH_DT', 'CELL_PH_NUM', 'EMAIL_ADDR', 'LAST_NAME',
#        'OCCUPATION', 'SEX_MF', 'Unnamed: 0'],
#       dtype='object')
#    AGE BIRTH_DT   CELL_PH_NUM             EMAIL_ADDR    LAST_NAME OCCUPATION  \
# 0  NaN      NaT  9.992104e+09   mdeshwal95@gmail.com    Balvinder        NaN
# 1  NaN      NaT  9.970978e+09  ctbtesting1@gmail.com  Ctb Testing        NaN
#
#   SEX_MF  Unnamed: 0
# 0    NaN         0.0
# 1    NaN         1.0

# %%
GCRMall.drop(['Unnamed: 0'],axis = 1, inplace = True)

# %%
GCRMall_april = GCRMall.copy()

# %%
#GCRMall_april.to_excel("GCRM_till_Apr21.xlsx")

# %%
#Gcrm may

# %%
GCRM_may =pd.read_excel("CTB_Customer_data_2021051.xltm")

# %%
GCRM_may.shape
# Out:
# (4655, 6)

# %%
now = pd.Timestamp('now')
GCRM_may['BIRTH_DT'] = pd.to_datetime(GCRM_may['BIRTH_DT'], errors ="coerce") 
GCRM_may['BIRTH_DT'] = GCRM_may['BIRTH_DT'].where(GCRMall_2['BIRTH_DT'] < now, GCRM_may['BIRTH_DT'] -  np.timedelta64(100, 'Y'))   # 2
GCRM_may['AGE'] = (now - GCRM_may['BIRTH_DT']).astype('<m8[Y]')    # 3
GCRM_may.head()
# Out:
#          LAST_NAME   CELL_PH_NUM                     EMAIL_ADDR SEX_MF  \
# 0     GANESH PATEL  0.000000e+00              noemail@yahoo.com      M
# 1    Vivek Chauhan  8.077714e+08           vc13062000@gmail.com      M
# 2      PAWAN KUMAR  6.002571e+09   pawankumarsinghjee@gmail.com    NaN
# 3   Vijay bhardwaj  6.005176e+09  vishalbhardwaj92330@gmail.com    NaN
# 4  Namandeep Singh  6.005359e+09       powerboster777@gmail.com      M
#
#   BIRTH_DT OCCUPATION  AGE
# 0      NaT        NaN  NaN
# 1      NaT        NaN  NaN
# 2      NaT        NaN  NaN
# 3      NaT        NaN  NaN
# 4      NaT        NaN  NaN

# %%
frames = [GCRMall_1,GCRMall_april,GCRM_may]
#frames = [GCRM33]
GCRMall = pd.concat(frames)
print(GCRMall.shape)
print("AGE :", GCRMall.AGE.notna().sum())
print("OCC :", GCRMall.OCCUPATION.notna().sum())
print(GCRMall.columns)
GCRMall.head(2)
# Out:
# (459866, 8)
# AGE : 23803
# OCC : 35010
# Index(['AGE', 'BIRTH_DT', 'CELL_PH_NUM', 'EMAIL_ADDR', 'LAST_NAME',
#        'OCCUPATION', 'SEX_MF', 'Unnamed: 0'],
#       dtype='object')
#    AGE BIRTH_DT   CELL_PH_NUM             EMAIL_ADDR    LAST_NAME OCCUPATION  \
# 0  NaN      NaT  9.992104e+09   mdeshwal95@gmail.com    Balvinder        NaN
# 1  NaN      NaT  9.970978e+09  ctbtesting1@gmail.com  Ctb Testing        NaN
#
#   SEX_MF  Unnamed: 0
# 0    NaN         0.0
# 1    NaN         1.0

# %%
GCRMall.to_excel("GCRM_till_May21.xlsx")

# %%
GCRMall_unq = GCRMall.drop_duplicates(subset=['CELL_PH_NUM', 'EMAIL_ADDR'], keep='last')
print(GCRMall_unq.shape)
print("AGE :", GCRMall_unq.AGE.notna().sum())
print("OCC :", GCRMall_unq.OCCUPATION.notna().sum())

print(" ")
GCRMall_unq1 = GCRMall.drop_duplicates(subset=['EMAIL_ADDR'], keep='last')
print(GCRMall_unq1.shape)
print("AGE :", GCRMall_unq1.AGE.notna().sum())
print("OCC :", GCRMall_unq1.OCCUPATION.notna().sum())
# Out:
# (166716, 8)
# AGE : 9504
# OCC : 14189
#
# (69213, 8)
# AGE : 4053
# OCC : 4686

# %%
GCRMall_unq1.dtypes
# Out:
# AGE                   float64
# BIRTH_DT       datetime64[ns]
# CELL_PH_NUM           float64
# EMAIL_ADDR             object
# LAST_NAME              object
# OCCUPATION             object
# SEX_MF                 object
# Unnamed: 0            float64
# dtype: object

# %%
AGE = GCRMall[GCRMall["AGE"].notna()]
#AGE = GCRMall[GCRMall["AGE"]>0]
print(AGE.shape)
AGE.head(2)
# Out:
# (23803, 8)
#      AGE BIRTH_DT   CELL_PH_NUM                  EMAIL_ADDR  \
# 12  32.0      NaT  8.335038e+09  sbhattacharyya37@gmail.com
# 39  35.0      NaT  9.909925e+09      cse.priyanka@gmail.com
#
#                 LAST_NAME                OCCUPATION SEX_MF  Unnamed: 0
# 12  SANTANU BHATTACHARYYA               Businessmen    NaN        12.0
# 39        PRIYANKA KUMARI  Service- Private Company    NaN        39.0

# %%
AGE["AGE_INT"] = AGE["AGE"].astype(int)

# %%
AGE.to_excel("AGE_May.xlsx")

# %%
AGE1 = AGE[AGE.AGE_INT.astype(str).str.isdigit()]
AGE1.shape
# Out:
# (23803, 9)

# %%
age_unq = AGE1.drop_duplicates(subset=['EMAIL_ADDR'], keep='last')
print(age_unq.shape)
age_unq.head(2)
# Out:
# (5954, 9)
#      AGE BIRTH_DT   CELL_PH_NUM                EMAIL_ADDR        LAST_NAME  \
# 39  35.0      NaT  9.909925e+09    cse.priyanka@gmail.com  PRIYANKA KUMARI
# 64  34.0      NaT  9.717071e+09  adeelmahmood01@gmail.com    ADEEL MAHMOOD
#
#                   OCCUPATION SEX_MF  Unnamed: 0  AGE_INT
# 39  Service- Private Company    NaN         NaN       35
# 64       Service- Government    NaN         NaN       34

# %%
age_unq18 = age_unq[(age_unq["AGE"].astype(int)>18) & (age_unq["AGE"].astype(int)<100)]
age_unq18.shape
# Out:
# (5780, 9)

# %%
apr_custonly.drop(['_merge'], axis=1,inplace = True)

# %%
CTB_age0 = pd.merge(CTB_data, age_unq18, left_on=['CUSTOMER_EMAIL'],right_on = ['EMAIL_ADDR'], how = 'outer',indicator=True)
print(CTB_age0.shape)
CTB_age0['_merge'].value_counts()
# Out:
# (84734, 55)
# left_only     78058
# right_only     3539
# both           3137
# Name: _merge, dtype: int64

# %%
age_unq18.columns
# Out:
# Index(['AGE', 'BIRTH_DT', 'CELL_PH_NUM', 'EMAIL_ADDR', 'LAST_NAME',
#        'OCCUPATION', 'SEX_MF', 'Unnamed: 0', 'AGE_INT'],
#       dtype='object')

# %%
CTB_age0.columns
# Out:
# Index(['ASSIGNED_SALES_CONSULTANT', 'BALANCE_AMOUNT', 'BOOKING',
#        'BOOKING_AMOUNT', 'BOOKING_DATE', 'CITY', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_EMAIL', 'CUSTOMER_MOBILE', 'CUSTOMER_NAME', 'DEALER_CODE',
#        'DEALER_ID', 'DEALER_NAME', 'DEAL_CODE_VALUE', 'DELR_RGON_NAME',
#        'ENGINE', 'EXTERIOR_COLOR', 'FINAL_PURCHASE_AMOUNT', 'FINANCE',
#        'FINANCE_STATUS', 'INTERIOR_COLOR', 'INVC_CNFR_YN', 'LOAN_TYPE',
#        'MODEL', 'ORDER_DATE', 'ORDER_DATEDay', 'ORDER_DATEDayofweek',
#        'ORDER_DATEDayofyear', 'ORDER_DATEMonth', 'ORDER_DATEMonthKey',
#        'ORDER_DATEMonthName', 'ORDER_DATEWeek', 'ORDER_DATEWeekKey',
#        'ORDER_DATEYear', 'ORDER_DATEhour', 'ORDER_DATEweekofyear', 'ORDER_ID',
#        'ORDER_STAGE', 'ORDER_STATUS', 'PAY_AT_DELR_YN', 'REGION_CODE', 'STATE',
#        'TRADE', 'VARIANT', '_ORDER _ID', 'AGE', 'BIRTH_DT', 'CELL_PH_NUM',
#        'EMAIL_ADDR', 'LAST_NAME', 'OCCUPATION', 'SEX_MF', 'Unnamed: 0',
#        'AGE_INT', '_merge'],
#       dtype='object')

# %%
CTB_ageBoth_enq = CTB_age0.copy()
CTB_age_enqGBY = CTB_ageBoth_enq[['ORDER_ID','AGE_INT']].groupby('AGE_INT',as_index=False).count()
print("total enquiry : ",CTB_age_enqGBY.ORDER_ID.sum())
print(CTB_age_enqGBY.shape)
CTB_age_enqGBY
# Out:
# total enquiry :  3137
# (62, 2)
#     AGE_INT  ORDER_ID
# 0      19.0         1
# 1      20.0        13
# 2      21.0        14
# 3      22.0        25
# 4      23.0        41
# 5      24.0        30
# 6      25.0        66
# 7      26.0        90
# 8      27.0        92
# 9      28.0       156
# 10     29.0       143
# 11     30.0       157
# 12     31.0       177
# 13     32.0       153
# 14     33.0       218
# 15     34.0       187
# 16     35.0       164
# 17     36.0       143
# 18     37.0        89
# 19     38.0        86
# 20     39.0        85
# 21     40.0       102
# 22     41.0        71
# 23     42.0        65
# 24     43.0        45
# 25     44.0        33
# 26     45.0        54
# 27     46.0        40
# 28     47.0        32
# 29     48.0        41
# ..      ...       ...
# 32     51.0        29
# 33     52.0        48
# 34     53.0        70
# 35     54.0        24
# 36     55.0        22
# 37     56.0        32
# 38     57.0        30
# 39     58.0        25
# 40     59.0        23
# 41     60.0        16
# 42     61.0        26
# 43     62.0         7
# 44     63.0        12
# 45     64.0         9
# 46     65.0         6
# 47     66.0         4
# 48     67.0        19
# 49     68.0         3
# 50     69.0        14
# 51     70.0         1
# 52     71.0         4
# 53     72.0         2
# 54     73.0         4
# 55     75.0         0
# 56     76.0         1
# 57     77.0         0
# 58     78.0         3
# 59     81.0         0
# 60     82.0         0
# 61     84.0         1
#
# [62 rows x 2 columns]

# %%
CTB_GDMS.drop(['_merge'], axis=1,inplace = True)
book_age = pd.merge(CTB_GDMS, age_unq18, left_on=['CUSTOMER_EMAIL'] ,right_on = ['EMAIL_ADDR'], how = 'outer', indicator= True)
print(book_age.shape)
book_age['_merge'].value_counts()
# Out:
# (84757, 82)
# left_only     78058
# right_only     3538
# both           3161
# Name: _merge, dtype: int64

# %%
book_ageBoth = book_age[book_age["_merge"]=="both"]
print(book_ageBoth.shape)
book_ageBoth.head(2)
# Out:
# (3161, 82)
#    ASSIGNED_SALES_CONSULTANT  BALANCE_AMOUNT BOOKING  BOOKING_AMOUNT  \
# 17             DEEPAK SHARMA       1123913.0       N             0.0
# 67               Pooja Singh       1789422.0       N             0.0
#
#    BOOKING_DATE     CITY CONSULTANT_ASSISGN_Y_N         CUSTOMER_EMAIL  \
# 17          NaT    Delhi                      Y  sushil.alld@gmail.com
# 67          NaT  Raigarh                      Y       vu2rje@yahoo.com
#
#     CUSTOMER_MOBILE                 CUSTOMER_NAME  ...   AGE BIRTH_DT  \
# 17     8.860558e+09  Sushil kumar singh undefined  ...  38.0      NaT
# 67     8.800271e+09        Rajesh kumar undefined  ...  33.0      NaT
#
#      CELL_PH_NUM             EMAIL_ADDR           LAST_NAME OCCUPATION SEX_MF  \
# 17  8.860558e+09  sushil.alld@gmail.com  Sushil Kumar Singh        NaN    NaN
# 67  8.800271e+09       vu2rje@yahoo.com            R. KUMAR        NaN    NaN
#
#     Unnamed: 0 AGE_INT _merge
# 17         NaN    38.0   both
# 67         NaN    33.0   both
#
# [2 rows x 82 columns]

# %%
book_ageBoth1 = book_ageBoth.drop_duplicates(subset=['EMAIL_ADDR'], keep='last')
book_ageBoth1.shape
# Out:
# (2242, 82)

# %%
book_ageBoth1.columns
# Out:
# Index(['ASSIGNED_SALES_CONSULTANT', 'BALANCE_AMOUNT', 'BOOKING',
#        'BOOKING_AMOUNT', 'BOOKING_DATE', 'CITY', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_EMAIL', 'CUSTOMER_MOBILE', 'CUSTOMER_NAME', 'DEALER_CODE',
#        'DEALER_ID', 'DEALER_NAME', 'DEAL_CODE_VALUE', 'DELR_RGON_NAME',
#        'ENGINE', 'EXTERIOR_COLOR', 'FINAL_PURCHASE_AMOUNT', 'FINANCE',
#        'FINANCE_STATUS', 'INTERIOR_COLOR', 'INVC_CNFR_YN', 'LOAN_TYPE',
#        'MODEL', 'ORDER_DATE', 'ORDER_DATEDay', 'ORDER_DATEDayofweek',
#        'ORDER_DATEDayofyear', 'ORDER_DATEMonth', 'ORDER_DATEMonthKey',
#        'ORDER_DATEMonthName', 'ORDER_DATEWeek', 'ORDER_DATEWeekKey',
#        'ORDER_DATEYear', 'ORDER_DATEhour', 'ORDER_DATEweekofyear', 'ORDER_ID',
#        'ORDER_STAGE', 'ORDER_STATUS', 'PAY_AT_DELR_YN', 'REGION_CODE', 'STATE',
#        'TRADE', 'VARIANT', '_ORDER _ID', 'CSPM_DLR_NAME', 'EQRY_DLR_NO',
#        'EQRY_ENQRY_NO', 'EQRY_DATE', 'EQRY_STAT', 'EQRY_STATUS_NM',
#        'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME', 'EQRY_NEWCAR_YN', 'EQRY_REF_NO',
#        'CTB_BOOKING_Y', 'RETAIL_DATE', 'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE',
#        'BKNG_DATE_NEW', 'BKNG_DATE_NEWYear', 'BKNG_DATE_NEWMonth',
#        'BKNG_DATE_NEWWeek', 'BKNG_DATE_NEWDay', 'BKNG_DATE_NEWhour',
#        'BKNG_DATE_NEWDayofweek', 'BKNG_DATE_NEWDayofyear',
#        'BKNG_DATE_NEWweekofyear', 'BKNG_DATE_NEWMonthName',
#        'BKNG_DATE_NEWMonthKey', 'BKNG_DATE_NEWWeekKey', 'AGE', 'BIRTH_DT',
#        'CELL_PH_NUM', 'EMAIL_ADDR', 'LAST_NAME', 'OCCUPATION', 'SEX_MF',
#        'Unnamed: 0', 'AGE_INT', '_merge'],
#       dtype='object')

# %%
book_ageBothGBY = book_ageBoth1[['EQRY_ENQRY_NO','AGE_INT']].groupby('AGE_INT',as_index=False).count()
print("total enquiry : ",book_ageBothGBY["EQRY_ENQRY_NO"].sum())
print(book_ageBothGBY.shape)
book_ageBothGBY
# Out:
# total enquiry :  514
# (58, 2)
#     AGE_INT  EQRY_ENQRY_NO
# 0      19.0              1
# 1      20.0              3
# 2      21.0              0
# 3      22.0              2
# 4      23.0              5
# 5      24.0              5
# 6      25.0             16
# 7      26.0             12
# 8      27.0             25
# 9      28.0             31
# 10     29.0             20
# 11     30.0             20
# 12     31.0             29
# 13     32.0             16
# 14     33.0             32
# 15     34.0             26
# 16     35.0             22
# 17     36.0             26
# 18     37.0             21
# 19     38.0             14
# 20     39.0             16
# 21     40.0             18
# 22     41.0             10
# 23     42.0              9
# 24     43.0              5
# 25     44.0              7
# 26     45.0              8
# 27     46.0             11
# 28     47.0              6
# 29     48.0              7
# 30     49.0              5
# 31     50.0              6
# 32     51.0             11
# 33     52.0              5
# 34     53.0              7
# 35     54.0              6
# 36     55.0              7
# 37     56.0              4
# 38     57.0              3
# 39     58.0              6
# 40     59.0              7
# 41     60.0              4
# 42     61.0              6
# 43     62.0              3
# 44     63.0              1
# 45     64.0              1
# 46     65.0              2
# 47     66.0              0
# 48     67.0              3
# 49     68.0              0
# 50     69.0              0
# 51     70.0              1
# 52     71.0              2
# 53     72.0              0
# 54     73.0              1
# 55     76.0              0
# 56     78.0              0
# 57     84.0              0

# %%
Age_Trend = pd.merge(CTB_age_enqGBY, book_ageBothGBY, left_on=['AGE_INT'],right_on = ['AGE_INT'], how = 'outer',indicator=True,)
Age_Trend["EQRY_ENQRY_NO"].fillna(0,inplace=True)
print(Age_Trend['_merge'].value_counts())
Age_Trend
# Out:
# both          58
# left_only      4
# right_only     0
# Name: _merge, dtype: int64
#     AGE_INT  ORDER_ID  EQRY_ENQRY_NO     _merge
# 0      19.0         1            1.0       both
# 1      20.0        13            3.0       both
# 2      21.0        14            0.0       both
# 3      22.0        25            2.0       both
# 4      23.0        41            5.0       both
# 5      24.0        30            5.0       both
# 6      25.0        66           16.0       both
# 7      26.0        90           12.0       both
# 8      27.0        92           25.0       both
# 9      28.0       156           31.0       both
# 10     29.0       143           20.0       both
# 11     30.0       157           20.0       both
# 12     31.0       177           29.0       both
# 13     32.0       153           16.0       both
# 14     33.0       218           32.0       both
# 15     34.0       187           26.0       both
# 16     35.0       164           22.0       both
# 17     36.0       143           26.0       both
# 18     37.0        89           21.0       both
# 19     38.0        86           14.0       both
# 20     39.0        85           16.0       both
# 21     40.0       102           18.0       both
# 22     41.0        71           10.0       both
# 23     42.0        65            9.0       both
# 24     43.0        45            5.0       both
# 25     44.0        33            7.0       both
# 26     45.0        54            8.0       both
# 27     46.0        40           11.0       both
# 28     47.0        32            6.0       both
# 29     48.0        41            7.0       both
# ..      ...       ...            ...        ...
# 32     51.0        29           11.0       both
# 33     52.0        48            5.0       both
# 34     53.0        70            7.0       both
# 35     54.0        24            6.0       both
# 36     55.0        22            7.0       both
# 37     56.0        32            4.0       both
# 38     57.0        30            3.0       both
# 39     58.0        25            6.0       both
# 40     59.0        23            7.0       both
# 41     60.0        16            4.0       both
# 42     61.0        26            6.0       both
# 43     62.0         7            3.0       both
# 44     63.0        12            1.0       both
# 45     64.0         9            1.0       both
# 46     65.0         6            2.0       both
# 47     66.0         4            0.0       both
# 48     67.0        19            3.0       both
# 49     68.0         3            0.0       both
# 50     69.0        14            0.0       both
# 51     70.0         1            1.0       both
# 52     71.0         4            2.0       both
# 53     72.0         2            0.0       both
# 54     73.0         4            1.0       both
# 55     75.0         0            0.0  left_only
# 56     76.0         1            0.0       both
# 57     77.0         0            0.0  left_only
# 58     78.0         3            0.0       both
# 59     81.0         0            0.0  left_only
# 60     82.0         0            0.0  left_only
# 61     84.0         1            0.0       both
#
# [62 rows x 4 columns]

# %%
Age_Trend.to_excel("Age_Trend_till_May.xlsx")

# %%
OCC = GCRMall[GCRMall["OCCUPATION"].notna()]
print(OCC.shape)
OCC.head(2)
# Out:
# (35010, 8)
#      AGE BIRTH_DT   CELL_PH_NUM                  EMAIL_ADDR  \
# 12  32.0      NaT  8.335038e+09  sbhattacharyya37@gmail.com
# 39  35.0      NaT  9.909925e+09      cse.priyanka@gmail.com
#
#                 LAST_NAME                OCCUPATION SEX_MF  Unnamed: 0
# 12  SANTANU BHATTACHARYYA               Businessmen    NaN        12.0
# 39        PRIYANKA KUMARI  Service- Private Company    NaN        39.0

# %%
occ_unq = OCC.drop_duplicates(subset=['EMAIL_ADDR'], keep='last')
print(occ_unq.shape)
occ_unq.head(2)
# Out:
# (6645, 8)
#      AGE BIRTH_DT   CELL_PH_NUM                EMAIL_ADDR        LAST_NAME  \
# 39  35.0      NaT  9.909925e+09    cse.priyanka@gmail.com  PRIYANKA KUMARI
# 64  34.0      NaT  9.717071e+09  adeelmahmood01@gmail.com    ADEEL MAHMOOD
#
#                   OCCUPATION SEX_MF  Unnamed: 0
# 39  Service- Private Company    NaN         NaN
# 64       Service- Government    NaN         NaN

# %%
CTB_occ = pd.merge(CTB_data, occ_unq, left_on=['CUSTOMER_EMAIL'],right_on = ['EMAIL_ADDR'], how = 'outer',indicator=True)
CTB_occ.shape
# Out:
# (85358, 54)

# %%
CTB_occ['_merge'].value_counts()
# Out:
# left_only     77654
# right_only     4163
# both           3541
# Name: _merge, dtype: int64

# %%
CTB_occBoth_enq = CTB_occ[CTB_occ["_merge"]=="both"]
print(CTB_occBoth_enq.shape)
CTB_occBoth_enq.head(2)
# Out:
# (3541, 54)
#    ASSIGNED_SALES_CONSULTANT  BALANCE_AMOUNT BOOKING  BOOKING_AMOUNT  \
# 31       Vishal Vijay Patole       1153997.0       N             0.0
# 32             Jagdish Jedhe       1527850.0       N             0.0
#
#    BOOKING_DATE        CITY CONSULTANT_ASSISGN_Y_N          CUSTOMER_EMAIL  \
# 31          NaT  Ahmednagar                      Y  ratna.don007@gmail.com
# 32          NaT  Ahmednagar                      Y  ratna.don007@gmail.com
#
#     CUSTOMER_MOBILE       CUSTOMER_NAME  ... _ORDER _ID AGE BIRTH_DT  \
# 31     7.387886e+09  Ratnasagar Dongare  ...        NaN NaN      NaT
# 32     7.387886e+09  Ratnasagar Dongare  ...        NaN NaN      NaT
#
#      CELL_PH_NUM              EMAIL_ADDR           LAST_NAME      OCCUPATION  \
# 31  7.387886e+09  ratna.don007@gmail.com  Ratnasagar Dongare  Skilled Worker
# 32  7.387886e+09  ratna.don007@gmail.com  Ratnasagar Dongare  Skilled Worker
#
#     SEX_MF Unnamed: 0 _merge
# 31     NaN        NaN   both
# 32     NaN        NaN   both
#
# [2 rows x 54 columns]

# %%
CTB_occBoth_enq1 =  CTB_occBoth_enq.drop_duplicates(subset=['EMAIL_ADDR'], keep='last')
CTB_occBoth_enq1.shape
# Out:
# (2482, 54)

# %%
CTB_occ_enqGBY = CTB_occBoth_enq1[['ORDER_ID','OCCUPATION']].groupby('OCCUPATION',as_index=False).count()
print("total enquiry : ",CTB_occ_enqGBY.ORDER_ID.sum())
print(CTB_occ_enqGBY.shape)
CTB_occ_enqGBY
# Out:
# total enquiry :  2482
# (50, 2)
#                                 OCCUPATION  ORDER_ID
# 0   Business men- indust w/ 10 or more Emp         9
# 1              Business with 1-9 employees         3
# 2                              Businessmen       541
# 3                 Busmen Indust W/ 1~9 Emp         2
# 4                Busmen- indust w/ 1~9 Emp         7
# 5                 Busmen- indust w/ No emp        18
# 6                     Chartered Accountant         1
# 7                        Clerical/Salesmen         2
# 8                          College Teacher         3
# 9     Corporate- Junior /Middle Management         3
# 10            Corporate Senior Management         1
# 11            Corporate– Senior Management         1
# 12                                  Doctor         1
# 13                               Employeed         1
# 14                                Engineer         1
# 15                                  Farmer        31
# 16  Government  Junior/ Middle Management         1
# 17                              Home Maker        59
# 18                               Homemaker         1
# 19       Information Technology - Engineer         7
# 20                                      MO         1
# 21                                     NRI         1
# 22         Officer/ExecutivesMiddle/Senior         3
# 23                                   Other       178
# 24                           Petty Traders         3
# 25                      Profession- Artist         4
# 26                          Profession- CA        16
# 27                      Profession- Doctor        90
# 28                          Profession- IT       188
# 29                      Profession- Lawyer         8
# 30                      Profession- Sports         7
# 31                     Profession- Teacher        62
# 32                Professional – Architect         1
# 33                                 Retired        37
# 34                        Retired Employee         1
# 35                          School Teacher         1
# 36                           Self Employed        27
# 37                  Self Employed- Traders         2
# 38                     Service- Government       301
# 39                         Service- Others         5
# 40                         Service- Police         9
# 41                Service- Private Company       546
# 42                         Service-Defence        34
# 43                             Shop Owners        66
# 44                          Skilled Worker       139
# 45                         Skilled Workers        19
# 46                                 Student        19
# 47                       Supervisory Level        12
# 48                       Unskilled Workers         8
# 49                                  doctor         1

# %%
book_occ = pd.merge(CTB_GDMS, occ_unq, left_on=['CUSTOMER_EMAIL'],right_on = ['EMAIL_ADDR'], how = 'outer',indicator=True)
print(book_occ.shape)
book_occ['_merge'].value_counts()
# Out:
# (85381, 81)
# left_only     77654
# right_only     4162
# both           3565
# Name: _merge, dtype: int64

# %%
book_occBoth = book_occ[book_occ["_merge"]=="both"]
print(book_occBoth.shape)
book_occBoth.head(2)
# Out:
# (3565, 81)
#    ASSIGNED_SALES_CONSULTANT  BALANCE_AMOUNT BOOKING  BOOKING_AMOUNT  \
# 31       Vishal Vijay Patole       1153997.0       N             0.0
# 32             Jagdish Jedhe       1527850.0       N             0.0
#
#    BOOKING_DATE        CITY CONSULTANT_ASSISGN_Y_N          CUSTOMER_EMAIL  \
# 31          NaT  Ahmednagar                      Y  ratna.don007@gmail.com
# 32          NaT  Ahmednagar                      Y  ratna.don007@gmail.com
#
#     CUSTOMER_MOBILE       CUSTOMER_NAME  ... BKNG_DATE_NEWWeekKey AGE  \
# 31     7.387886e+09  Ratnasagar Dongare  ...                  NaN NaN
# 32     7.387886e+09  Ratnasagar Dongare  ...                  NaN NaN
#
#    BIRTH_DT   CELL_PH_NUM              EMAIL_ADDR           LAST_NAME  \
# 31      NaT  7.387886e+09  ratna.don007@gmail.com  Ratnasagar Dongare
# 32      NaT  7.387886e+09  ratna.don007@gmail.com  Ratnasagar Dongare
#
#         OCCUPATION  SEX_MF Unnamed: 0 _merge
# 31  Skilled Worker     NaN        NaN   both
# 32  Skilled Worker     NaN        NaN   both
#
# [2 rows x 81 columns]

# %%
book_occBoth.columns
# Out:
# Index(['ASSIGNED_SALES_CONSULTANT', 'BALANCE_AMOUNT', 'BOOKING',
#        'BOOKING_AMOUNT', 'BOOKING_DATE', 'CITY', 'CONSULTANT_ASSISGN_Y_N',
#        'CUSTOMER_EMAIL', 'CUSTOMER_MOBILE', 'CUSTOMER_NAME', 'DEALER_CODE',
#        'DEALER_ID', 'DEALER_NAME', 'DEAL_CODE_VALUE', 'DELR_RGON_NAME',
#        'ENGINE', 'EXTERIOR_COLOR', 'FINAL_PURCHASE_AMOUNT', 'FINANCE',
#        'FINANCE_STATUS', 'INTERIOR_COLOR', 'INVC_CNFR_YN', 'LOAN_TYPE',
#        'MODEL', 'ORDER_DATE', 'ORDER_DATEDay', 'ORDER_DATEDayofweek',
#        'ORDER_DATEDayofyear', 'ORDER_DATEMonth', 'ORDER_DATEMonthKey',
#        'ORDER_DATEMonthName', 'ORDER_DATEWeek', 'ORDER_DATEWeekKey',
#        'ORDER_DATEYear', 'ORDER_DATEhour', 'ORDER_DATEweekofyear', 'ORDER_ID',
#        'ORDER_STAGE', 'ORDER_STATUS', 'PAY_AT_DELR_YN', 'REGION_CODE', 'STATE',
#        'TRADE', 'VARIANT', '_ORDER _ID', 'CSPM_DLR_NAME', 'EQRY_DLR_NO',
#        'EQRY_ENQRY_NO', 'EQRY_DATE', 'EQRY_STAT', 'EQRY_STATUS_NM',
#        'EQCR_MODEL_CODE', 'EQCR_MODEL_NAME', 'EQRY_NEWCAR_YN', 'EQRY_REF_NO',
#        'CTB_BOOKING_Y', 'RETAIL_DATE', 'INVC_CNFM_YN', 'BKNG_NO', 'BKNG_DATE',
#        'BKNG_DATE_NEW', 'BKNG_DATE_NEWYear', 'BKNG_DATE_NEWMonth',
#        'BKNG_DATE_NEWWeek', 'BKNG_DATE_NEWDay', 'BKNG_DATE_NEWhour',
#        'BKNG_DATE_NEWDayofweek', 'BKNG_DATE_NEWDayofyear',
#        'BKNG_DATE_NEWweekofyear', 'BKNG_DATE_NEWMonthName',
#        'BKNG_DATE_NEWMonthKey', 'BKNG_DATE_NEWWeekKey', 'AGE', 'BIRTH_DT',
#        'CELL_PH_NUM', 'EMAIL_ADDR', 'LAST_NAME', 'OCCUPATION', 'SEX_MF',
#        'Unnamed: 0', '_merge'],
#       dtype='object')

# %%
book_occBoth1 = book_occBoth.drop_duplicates(subset=['EQRY_REF_NO'], keep='last')
book_occBoth1.shape
# Out:
# (673, 81)

# %%
book_occBoth2 = book_occBoth.drop_duplicates(subset=['CUSTOMER_EMAIL'], keep='last')
book_occBoth2.shape
# Out:
# (2483, 81)

# %%
book_occBothGBY = book_occBoth1[['EQRY_REF_NO','OCCUPATION']].groupby('OCCUPATION',as_index=False).count()
print("total Booking : ",book_occBothGBY["EQRY_REF_NO"].sum())
print(book_occBothGBY.shape)
book_occBothGBY
# Out:
# total Booking :  672
# (31, 2)
#                                 OCCUPATION  EQRY_REF_NO
# 0   Business men- indust w/ 10 or more Emp            2
# 1                              Businessmen          134
# 2                 Busmen Indust W/ 1~9 Emp            1
# 3                 Busmen- indust w/ No emp            3
# 4                          College Teacher            2
# 5                                   Farmer           14
# 6                               Home Maker           11
# 7        Information Technology - Engineer            2
# 8                                      NRI            1
# 9          Officer/ExecutivesMiddle/Senior            2
# 10                                   Other           30
# 11                      Profession- Artist            1
# 12                          Profession- CA            7
# 13                      Profession- Doctor           27
# 14                          Profession- IT           70
# 15                      Profession- Lawyer            4
# 16                     Profession- Teacher           22
# 17                                 Retired            7
# 18                           Self Employed            7
# 19                  Self Employed- Traders            3
# 20                     Service- Government           87
# 21                         Service- Others            1
# 22                         Service- Police            3
# 23                Service- Private Company          163
# 24                         Service-Defence            6
# 25                             Shop Owners           12
# 26                          Skilled Worker           34
# 27                         Skilled Workers            3
# 28                                 Student           10
# 29                       Supervisory Level            1
# 30                       Unskilled Workers            2

# %%
occ_Trend = pd.merge(CTB_occ_enqGBY, book_occBothGBY, left_on=['OCCUPATION'],right_on = ['OCCUPATION'], how = 'outer',indicator=True,)
occ_Trend["EQRY_REF_NO"].fillna(0,inplace=True)
print(book_occ['_merge'].value_counts())
occ_Trend
# Out:
# left_only     77654
# right_only     4162
# both           3565
# Name: _merge, dtype: int64
#                                 OCCUPATION  ORDER_ID  EQRY_REF_NO     _merge
# 0   Business men- indust w/ 10 or more Emp         9          2.0       both
# 1              Business with 1-9 employees         3          0.0  left_only
# 2                              Businessmen       541        134.0       both
# 3                 Busmen Indust W/ 1~9 Emp         2          1.0       both
# 4                Busmen- indust w/ 1~9 Emp         7          0.0  left_only
# 5                 Busmen- indust w/ No emp        18          3.0       both
# 6                     Chartered Accountant         1          0.0  left_only
# 7                        Clerical/Salesmen         2          0.0  left_only
# 8                          College Teacher         3          2.0       both
# 9     Corporate- Junior /Middle Management         3          0.0  left_only
# 10            Corporate Senior Management         1          0.0  left_only
# 11            Corporate– Senior Management         1          0.0  left_only
# 12                                  Doctor         1          0.0  left_only
# 13                               Employeed         1          0.0  left_only
# 14                                Engineer         1          0.0  left_only
# 15                                  Farmer        31         14.0       both
# 16  Government  Junior/ Middle Management         1          0.0  left_only
# 17                              Home Maker        59         11.0       both
# 18                               Homemaker         1          0.0  left_only
# 19       Information Technology - Engineer         7          2.0       both
# 20                                      MO         1          0.0  left_only
# 21                                     NRI         1          1.0       both
# 22         Officer/ExecutivesMiddle/Senior         3          2.0       both
# 23                                   Other       178         30.0       both
# 24                           Petty Traders         3          0.0  left_only
# 25                      Profession- Artist         4          1.0       both
# 26                          Profession- CA        16          7.0       both
# 27                      Profession- Doctor        90         27.0       both
# 28                          Profession- IT       188         70.0       both
# 29                      Profession- Lawyer         8          4.0       both
# 30                      Profession- Sports         7          0.0  left_only
# 31                     Profession- Teacher        62         22.0       both
# 32                Professional – Architect         1          0.0  left_only
# 33                                 Retired        37          7.0       both
# 34                        Retired Employee         1          0.0  left_only
# 35                          School Teacher         1          0.0  left_only
# 36                           Self Employed        27          7.0       both
# 37                  Self Employed- Traders         2          3.0       both
# 38                     Service- Government       301         87.0       both
# 39                         Service- Others         5          1.0       both
# 40                         Service- Police         9          3.0       both
# 41                Service- Private Company       546        163.0       both
# 42                         Service-Defence        34          6.0       both
# 43                             Shop Owners        66         12.0       both
# 44                          Skilled Worker       139         34.0       both
# 45                         Skilled Workers        19          3.0       both
# 46                                 Student        19         10.0       both
# 47                       Supervisory Level        12          1.0       both
# 48                       Unskilled Workers         8          2.0       both
# 49                                  doctor         1          0.0  left_only

# %%
occ_Trend.to_excel("occ_Trend_May.xlsx")

# %%
df_age = pd.read_excel("Age_Trend_till_May.xlsx", sheet_name="Sheet1")

# %%
df_age.head(2)
# Out:
#    Unnamed: 0  AGE_INT  ORDER_ID  EQRY_ENQRY_NO _merge
# 0           0       19         1              1   both
# 1           1       20        13              3   both

# %%
df_age = df_age.rename(columns={'ORDER_ID': 'CTB Enquiry', 'EQRY_ENQRY_NO': 'CTB Booking'})
df_age
# Out:
#     Unnamed: 0  AGE_INT  CTB Enquiry  CTB Booking     _merge
# 0            0       19            1            1       both
# 1            1       20           13            3       both
# 2            2       21           14            0       both
# 3            3       22           25            2       both
# 4            4       23           41            5       both
# 5            5       24           30            5       both
# 6            6       25           66           16       both
# 7            7       26           90           12       both
# 8            8       27           92           25       both
# 9            9       28          156           31       both
# 10          10       29          143           20       both
# 11          11       30          157           20       both
# 12          12       31          177           29       both
# 13          13       32          153           16       both
# 14          14       33          218           32       both
# 15          15       34          187           26       both
# 16          16       35          164           22       both
# 17          17       36          143           26       both
# 18          18       37           89           21       both
# 19          19       38           86           14       both
# 20          20       39           85           16       both
# 21          21       40          102           18       both
# 22          22       41           71           10       both
# 23          23       42           65            9       both
# 24          24       43           45            5       both
# 25          25       44           33            7       both
# 26          26       45           54            8       both
# 27          27       46           40           11       both
# 28          28       47           32            6       both
# 29          29       48           41            7       both
# ..         ...      ...          ...          ...        ...
# 32          32       51           29           11       both
# 33          33       52           48            5       both
# 34          34       53           70            7       both
# 35          35       54           24            6       both
# 36          36       55           22            7       both
# 37          37       56           32            4       both
# 38          38       57           30            3       both
# 39          39       58           25            6       both
# 40          40       59           23            7       both
# 41          41       60           16            4       both
# 42          42       61           26            6       both
# 43          43       62            7            3       both
# 44          44       63           12            1       both
# 45          45       64            9            1       both
# 46          46       65            6            2       both
# 47          47       66            4            0       both
# 48          48       67           19            3       both
# 49          49       68            3            0       both
# 50          50       69           14            0       both
# 51          51       70            1            1       both
# 52          52       71            4            2       both
# 53          53       72            2            0       both
# 54          54       73            4            1       both
# 55          55       75            0            0  left_only
# 56          56       76            1            0       both
# 57          57       77            0            0  left_only
# 58          58       78            3            0       both
# 59          59       81            0            0  left_only
# 60          60       82            0            0  left_only
# 61          61       84            1            0       both
#
# [62 rows x 5 columns]

# %%
df_age['CTB Enquiry'].sum()
# Out:
# 3137

# %%
df_age['CTB Booking'].sum()
# Out:
# 514

# %%
3115/793939
# Out:
# 0.003923475229205267

# %%
0.0039*100
# Out:
# 0.38999999999999996

# %%
df_age['Enquiry Ratio'] = (df_age['CTB Enquiry']/3115)*100
df_age['Enquiry Ratio'] = df_age['Enquiry Ratio'].round(2).astype(str)+ '%'

# %%
df_age['Booking Ratio'] = (df_age['CTB Booking']/513)*100
df_age['Booking Ratio'] = df_age['Booking Ratio'].round(2).astype(str)+ '%'

# %%
df_age['Enquiry To Booking Ratio'] = (df_age['CTB Booking'] / df_age['CTB Enquiry'])*100
df_age['Enquiry To Booking Ratio'] = df_age['Enquiry To Booking Ratio'].round(2).astype(str)+ '%'
df_age.head(5)
# Out:
#    Unnamed: 0  AGE_INT  CTB Enquiry  CTB Booking _merge Enquiry Ratio  \
# 0           0       19            1            1   both         0.03%
# 1           1       20           13            3   both         0.42%
# 2           2       21           14            0   both         0.45%
# 3           3       22           25            2   both          0.8%
# 4           4       23           41            5   both         1.32%
#
#   Booking Ratio Enquiry To Booking Ratio
# 0         0.19%                   100.0%
# 1         0.58%                   23.08%
# 2          0.0%                     0.0%
# 3         0.39%                     8.0%
# 4         0.97%                    12.2%

# %%
df_age_sort = df_age[(24-18):(35-18)]

# %%
df_age_sort
# Out:
#     Unnamed: 0  AGE_INT  CTB Enquiry  CTB Booking _merge Enquiry Ratio  \
# 6            6       25           66           16   both         2.12%
# 7            7       26           90           12   both         2.89%
# 8            8       27           92           25   both         2.95%
# 9            9       28          156           31   both         5.01%
# 10          10       29          143           20   both         4.59%
# 11          11       30          157           20   both         5.04%
# 12          12       31          177           29   both         5.68%
# 13          13       32          153           16   both         4.91%
# 14          14       33          218           32   both          7.0%
# 15          15       34          187           26   both          6.0%
# 16          16       35          164           22   both         5.26%
#
#    Booking Ratio Enquiry To Booking Ratio
# 6          3.12%                   24.24%
# 7          2.34%                   13.33%
# 8          4.87%                   27.17%
# 9          6.04%                   19.87%
# 10          3.9%                   13.99%
# 11          3.9%                   12.74%
# 12         5.65%                   16.38%
# 13         3.12%                   10.46%
# 14         6.24%                   14.68%
# 15         5.07%                    13.9%
# 16         4.29%                   13.41%

# %%
a = df_age_sort['CTB Enquiry'].sum()
b = df_age_sort['CTB Booking'].sum()
c = (b/a)*100
print(c)
# Out:
# 15.53337492202121

# %%
df_age_sort2 = df_age[(35-18):(45-18)]

# %%
df_age_sort2
# Out:
#     Unnamed: 0  AGE_INT  CTB Enquiry  CTB Booking _merge Enquiry Ratio  \
# 17          17       36          143           26   both         4.59%
# 18          18       37           89           21   both         2.86%
# 19          19       38           86           14   both         2.76%
# 20          20       39           85           16   both         2.73%
# 21          21       40          102           18   both         3.27%
# 22          22       41           71           10   both         2.28%
# 23          23       42           65            9   both         2.09%
# 24          24       43           45            5   both         1.44%
# 25          25       44           33            7   both         1.06%
# 26          26       45           54            8   both         1.73%
#
#    Booking Ratio Enquiry To Booking Ratio
# 17         5.07%                   18.18%
# 18         4.09%                    23.6%
# 19         2.73%                   16.28%
# 20         3.12%                   18.82%
# 21         3.51%                   17.65%
# 22         1.95%                   14.08%
# 23         1.75%                   13.85%
# 24         0.97%                   11.11%
# 25         1.36%                   21.21%
# 26         1.56%                   14.81%

# %%
x = df_age_sort2['CTB Enquiry'].sum()
y = df_age_sort2['CTB Booking'].sum()
z = (y/x)*100
print(z)
# Out:
# 17.335058214747736

# %%
df_age.to_excel("Age_may.xlsx")

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = df_age[0:55].plot(kind='bar',x='AGE_INT',y='CTB Enquiry', color="dodgerblue",legend=False,ax=ax,)
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Enquiry", fontsize=12)
plt.xlabel("AGE", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=280, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["Enquiry count by Age"],loc="upper right", bbox_to_anchor=(1.0, 1.0))


plt.title("Age Wise Enquiry Count")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
#for pos in (['top', 'bottom', 'right', 'left']):
   # ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')      
plt.savefig("#14_18%.jpg", bbox_inches='tight')       
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(15, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()


splot = sns.barplot(data=df_age[0:55], x = 'AGE_INT', y = 'CTB Booking', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df_age[0:55].plot(kind='bar',x='AGE_INT',y='CTB Booking', color="royalblue",legend=False,ax=ax,)
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking", fontsize=12)
plt.xlabel("AGE", fontsize = 12)
#plt.xticks(np.arange(0, len(df_age['AGE_INT'])+1, 5))
plt.xticks(rotation=45)
plt.ylim(ymax=50, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["Booking count by Age"],loc="upper right", bbox_to_anchor=(1.0, 1.0))

#ax2 =ax.twinx()
plt.title("Age wise booking count", fontsize=12)
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
#for pos in (['top', 'bottom', 'right', 'left']):
    #ax2.spines[pos].set_edgecolor('grey') 
    
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#chart15.jpg", bbox_inches='tight')   

plt.show()

# %%
df_occ=pd.read_excel("occ_Trend_May.xlsx", sheet_name= "Sheet1")

# %%
df_occ
# Out:
#     Unnamed: 0                              OCCUPATION  ORDER_ID  EQRY_REF_NO  \
# 0            0  Business men- indust w/ 10 or more Emp         9            2
# 1            1             Business with 1-9 employees         3            0
# 2            2                             Businessmen       541          134
# 3            3                Busmen Indust W/ 1~9 Emp         2            1
# 4            4               Busmen- indust w/ 1~9 Emp         7            0
# 5            5                Busmen- indust w/ No emp        18            3
# 6            6                    Chartered Accountant         1            0
# 7            7                       Clerical/Salesmen         2            0
# 8            8                         College Teacher         3            2
# 9            9    Corporate- Junior /Middle Management         3            0
# 10          10            Corporate Senior Management         1            0
# 11          11            Corporate– Senior Management         1            0
# 12          12                                  Doctor         1            0
# 13          13                               Employeed         1            0
# 14          14                                Engineer         1            0
# 15          15                                  Farmer        31           14
# 16          16  Government  Junior/ Middle Management         1            0
# 17          17                              Home Maker        59           11
# 18          18                               Homemaker         1            0
# 19          19       Information Technology - Engineer         7            2
# 20          20                                      MO         1            0
# 21          21                                     NRI         1            1
# 22          22         Officer/ExecutivesMiddle/Senior         3            2
# 23          23                                   Other       178           30
# 24          24                           Petty Traders         3            0
# 25          25                      Profession- Artist         4            1
# 26          26                          Profession- CA        16            7
# 27          27                      Profession- Doctor        90           27
# 28          28                          Profession- IT       188           70
# 29          29                      Profession- Lawyer         8            4
# 30          30                      Profession- Sports         7            0
# 31          31                     Profession- Teacher        62           22
# 32          32                Professional – Architect         1            0
# 33          33                                 Retired        37            7
# 34          34                        Retired Employee         1            0
# 35          35                          School Teacher         1            0
# 36          36                           Self Employed        27            7
# 37          37                  Self Employed- Traders         2            3
# 38          38                     Service- Government       301           87
# 39          39                         Service- Others         5            1
# 40          40                         Service- Police         9            3
# 41          41                Service- Private Company       546          163
# 42          42                         Service-Defence        34            6
# 43          43                             Shop Owners        66           12
# 44          44                          Skilled Worker       139           34
# 45          45                         Skilled Workers        19            3
# 46          46                                 Student        19           10
# 47          47                       Supervisory Level        12            1
# 48          48                       Unskilled Workers         8            2
# 49          49                                  doctor         1            0
#
#        _merge
# 0        both
# 1   left_only
# 2        both
# 3        both
# 4   left_only
# 5        both
# 6   left_only
# 7   left_only
# 8        both
# 9   left_only
# 10  left_only
# 11  left_only
# 12  left_only
# 13  left_only
# 14  left_only
# 15       both
# 16  left_only
# 17       both
# 18  left_only
# 19       both
# 20  left_only
# 21       both
# 22       both
# 23       both
# 24  left_only
# 25       both
# 26       both
# 27       both
# 28       both
# 29       both
# 30  left_only
# 31       both
# 32  left_only
# 33       both
# 34  left_only
# 35  left_only
# 36       both
# 37       both
# 38       both
# 39       both
# 40       both
# 41       both
# 42       both
# 43       both
# 44       both
# 45       both
# 46       both
# 47       both
# 48       both
# 49  left_only

# %%
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Profession- CA'], 'CA')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Self Employed- Agriculturist/Farm'], 'Farmer')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Professional – Architect'], 'Architect')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['NRI'], 'Others')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Profession- Sports'], 'Sports')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Professional – Writer/Author'], 'Writer')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Profession- Artist', 'Professional – Artist'], 'Artist')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Profession- Lawyer', 'Professional – Lawyer'], 'Lawyer')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Service- Others', 'Other'], 'Others')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Teacher/Lecturer/Reader/Scientist', 'College Teacher', 'Profession- Teacher'], 'Teacher')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Profession- Doctor', 'Professional – Doctor'], 'Doctor')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Profession- IT', 'Professional – Software Developers'], 'IT Sector')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Service- Private Company', 'Supervisory Level','Clerical/Salesmen',
                                            'Corporate- Junior /Middle Management', 'Corporate– Senior Management'], 'Private Sector')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Service- Government', 'Service-Defence', 'Government – Junior/ Middle Management',
                                            'Govt Executive – Senior Management', 'Armed Forces'], 'Govt. Job')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Service- Police', 'Armed Forces',
                                            'Service-Defence'], 'Police/Defence')
df_occ['OCCUPATION'] = df_occ['OCCUPATION'].replace(['Businessmen', 'Shop Owners','Busmen- indust w/ 1~9 Emp' ,'Busmen- indust w/ No emp', 'Petty Traders',
                                            'Business with 1-9 employees', 'Self Employed', 'Self Employed- Traders',
                                            'Business >50 employees', 'Business with 10-50 employees'], 'Businessman')

# %%
df_occ.sort_values("Enquiry", axis = 0, ascending = False, inplace = True, na_position ='last') 
#df_occ = df_occ.reindex(index=order_by_index(df_occ.index, index_natsorted(df_occ.Enquiry)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-467-69e829287769> in <module>
# ----> 1 df_occ.sort_values("Enquiry", axis = 0, ascending = False, inplace = True, na_position ='last')
#       2 #df_occ = df_occ.reindex(index=order_by_index(df_occ.index, index_natsorted(df_occ.Enquiry)))
#
# /usr/local/src/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# /usr/local/src/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'Enquiry'

# %%
df_occ.rename(columns = {'ORDER_ID':'Enquiry', 'EQRY_REF_NO':'Booking'}, inplace = True)

# %%
df_occ['Enquiry'].sum()

# %%
df_occ['Booking'].sum()

# %%
df_occ.Enquiry.sum()

# %%
df_occ.to_excel("May_occuption.xlsx")

# %%
#df_occ.drop(df_occ.loc[df_occ['Occupation']=='Other'].index, inplace=True)
df_occ.sort_values("OCCUPATION", axis = 0, ascending = True, inplace = False, na_position ='last')

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

splot = sns.barplot(data=df_occ[0:16], x = 'OCCUPATION', y = 'Enquiry', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df_occ.plot(kind='bar',x='Occupation',y='CTB Enquiry', color="royalblue",legend=False,ax=ax,)
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Enquiry Count", fontsize=12)
plt.xlabel("Occupation", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=800, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["Enquiry count by occupation"],loc="upper right", bbox_to_anchor=(1.0, 1.0))


plt.title("Occupation Wise Enquiry Count")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')        
plt.savefig("#16.jpg", bbox_inches='tight')        
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(7.5, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

splot = sns.barplot(data=df_occ[0:16], x = 'OCCUPATION', y = 'Booking', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df_occ.plot(kind='bar',x='Occupation',y='CTB Enquiry', color="royalblue",legend=False,ax=ax,)
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)
plt.xlabel("Occupation", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=250, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(["Booking count by occupation"],loc="upper right", bbox_to_anchor=(1.0, 1.0))


plt.title("Occupation Wise Booking Count")
#plt.subplots_adjust(left=0.15)
#plt.grid(color='lightgrey', linewidth=0.7)

#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.grid(color='lightgrey', linewidth=0.7,axis='y')       
plt.savefig("#17.png", bbox_inches='tight')
plt.show()

# %%
df_occ['Enquiry:Booking (Same Occupation)'] = (df_occ['Booking'] / df_occ['Enquiry'])*100
df_occ['Enquiry:Booking (Same Occupation)'] = df_occ['Enquiry:Booking (Same Occupation)'].round(2).astype(str)+ '%'

# %%
df_occ['Enq.:Booking (All Enquiries)'] = (df_occ['Booking'] / 2396)*100
df_occ['Enq.:Booking (All Enquiries)'] = df_occ['Enq.:Booking (All Enquiries)'].round(2).astype(str)+ '%'

# %%
df_occ.to_excel("occ_tabl.xlsx")

# %%
### dealer - region sep > apr changes

# %%
CTB_data

# %%
tb_data_region_kapil=CTB_data[(CTB_data['ORDER_DATE']<='2021-05-31')]
tb_data_region_kapil.shape
#&(CTB_data['ORDER_DATE']<='2021-05-31')]

# %%
CTB_data.to_excel("ctb_ord_may21.xlsx")

# %%
73939-8147

# %%
#Dealer wise region count from sep'20 to Apr'21
#Ctb_data_region=CTB_data[(CTB_data['ORDER_DATE']>='2020-09-01')&(CTB_data['ORDER_DATE']<='2021-04-30')|(CTB_data['ORDER_DATEMonthKey']=='2021_4')]

# %%
#tb_data_region=CTB_data[(CTB_data['ORDER_DATE']>='2020-01-01')&(CTB_data['ORDER_DATE']<='2021-05-31')]

# %%
Ctb_data_region.head(3).T

# %%
Ctb_data_region=CTB_data.copy()

# %%
Ctb_data_region.ORDER_DATEMonthKey.value_counts()

# %%
Region_enq1 = Trend_Analysis_gb(Ctb_data_region,['ORDER_ID','DELR_RGON_NAME'],'','DELR_RGON_NAME','Weekly')
print("total enquiry : ",Region_enq1.ORDER_ID.sum())
Region_enq1

# %%
Region_list1 = CTB_data[["DELR_RGON_NAME","DEALER_ID"]]
Region_list_uniq1 = Region_list1.drop_duplicates(subset=['DELR_RGON_NAME', 'DEALER_ID'], keep='last')
Region_list_uniq1.head(2)

# %%
Region_enq1

# %%
GDMS_Booking.shape

# %%
GDMS_Booking['BKNG_DATE'].head(3)

# %%
GDMS_booking_add_region1 = pd.merge(GDMS_booking, Region_list_uniq1, left_on=['EQRY_DLR_NO'],right_on = ['DEALER_ID'], how = 'outer',indicator=True)
print("GDMS_add_region" , GDMS_booking_add_region1.shape)
GDMS_booking_add_region1['_merge'].value_counts()

# %%
#GDMS_Booking_new_1=GDMS_Booking[(GDMS_Booking['BKNG_DATE']>=20200901.0)&(GDMS_Booking['BKNG_DATE']<=20210430.0)|(GDMS_Booking['BKNG_DATE_NEWMonthKey']=='2021_4')]
#GDMS_Booking_new_1.shape

# %%
GDMS_Booking_new_1=GDMS_Booking[(GDMS_Booking['BKNG_DATE']>=20200101.0)&(GDMS_Booking['BKNG_DATE']<=20210531.0)|(GDMS_Booking['BKNG_DATE_NEWMonthKey']=='2021_4')]
GDMS_Booking_new_1.shape

# %%
GDMS_Booking_new_1['BKNG_DATE_NEWMonthKey'].value_counts()

# %%
GDMS_Booking_new_1.head(3)

# %%
#Ctb_data_region.columns
GDMS_Booking_new_1.columns

# %%
GDMS_booking_add_region_1 = pd.merge(GDMS_Booking_new_1, Region_list_uniq, left_on=['EQRY_DLR_NO'],right_on = ['DEALER_ID'], how = 'outer',indicator=True)
print("GDMS_add_region" , GDMS_booking_add_region_1.shape)
GDMS_booking_add_region_1['_merge'].value_counts()

# %%
#Region_booking = GDMS_booking_add_region_1[GDMS_booking_add_region_1["_merge"]!="both"]

# %%
Region_booking = GDMS_booking_add_region_1[GDMS_booking_add_region_1["_merge"]!="both"]

# %%
Region_booking = Trend_Analysis_gb(GDMS_booking_add_region_1,['EQRY_REF_NO','DELR_RGON_NAME'],'','DELR_RGON_NAME','Monthly')
Region_booking

# %%
#Region_Final1 = pd.merge(Region_booking, Region_enq1, left_on=['DELR_RGON_NAME'],right_on = ['DELR_RGON_NAME'], how = 'outer',indicator=True)
#print("GDMS_add_region" , GDMS_booking_add_region_1.shape)
#Region_Final1['_merge'].value_counts()

# %%
Region_Final1 = pd.merge(Region_booking, Region_enq1, left_on=['DELR_RGON_NAME'],right_on = ['DELR_RGON_NAME'], how = 'outer',indicator=True)
#print("GDMS_add_region" , GDMS_booking_add_region_1.shape)
Region_Final1['_merge'].value_counts()

# %%
Region_Final1 = Region_Final1[Region_Final1["_merge"]=="both"]

# %%
Region_Final1

# %%
Region_Final1 = Region_Final1[["DELR_RGON_NAME","ORDER_ID","EQRY_REF_NO"]]
Region_Final1.columns = ['Dealer Region Name','Enquiry Count','Booking Count']
Region_enq1 = Region_Final1["Enquiry Count"].sum()
Region_book1 = Region_Final1["Booking Count"].sum()
Region_Final1["Enquiry Ratio"] = (Region_Final1["Enquiry Count"]/Region_enq1)
Region_Final1["Booking Ratio"] = (Region_Final1["Booking Count"]/Region_book1)
Region_Final1["Enq to Booking Ratio"] = (Region_Final1["Booking Count"]/Region_Final1["Enquiry Count"])
Region_Final1["Avg_Enquiry"]=Region_enq1/Region_Final1["Dealer Region Name"].count()
Region_Final1["Avg_booking"]=Region_book1/Region_Final1["Dealer Region Name"].count()
Region_Final1

# %%
Region_Final1['Enquiry Count'].sum()

# %%
Region_Final1['Booking Count'].sum()

# %%
Region_Final1.sort_values("Booking Count", axis = 0, ascending = False, na_position ='last')

# %%
Region_Final1.to_excel("REGION_till_May.xlsx")

# %%
regn_book = pd.merge(GDMS_Booking_new_1, Region_list_uniq, left_on=['EQRY_DLR_NO'],right_on = ['DEALER_ID'], how = 'outer',indicator=True)
print("GDMS_add_region" , regn_book.shape)
regn_book['_merge'].value_counts()

# %%
regn_book = regn_book[regn_book["_merge"]=="both"]

# %%
regn_book.columns

# %%
Ctb_data_region.drop('_ORDER _ID',axis=1,inplace=True)

# %%
def regn(dataset_enq,dataset_book,element):
    var_enq = dataset_enq[dataset_enq["DELR_RGON_NAME"] == element]
    var_book = dataset_book[dataset_book["DELR_RGON_NAME"] == element]
    Region_enq = Trend_Analysis_gb(var_enq,['ORDER_ID','DEALER_NAME'],'','DEALER_NAME','Weekly')
    #print("total enquiry : ",Region_enq.ORDER_ID.sum())
    #Region_enq
    Region_Booking = Trend_Analysis_gb(var_book,['EQRY_REF_NO','CSPM_DLR_NAME'],'','CSPM_DLR_NAME','weekly')
   # Region_Booking
    #GDMS_booking_add_region = pd.merge(, Region_list_uniq, left_on=['EQRY_DLR_NO'],right_on = ['DEALER_ID'], how = 'outer',indicator=True)
    #print("GDMS_add_region" , GDMS_booking_add_region.shape)
    #GDMS_booking_add_region['_merge'].value_counts()
    #GDMS_booking_add_region_bl = GDMS_booking_add_region[GDMS_booking_add_region["_merge"]!="right_only"]
    #GDMS_booking_add_region_bl.shape

    Region_final_merg_1 = Merge(Region_enq,'DEALER_NAME',Region_Booking,'CSPM_DLR_NAME','','','outer',True,'single')
    Region_final_merg_1 = Region_final_merg_1[["DEALER_NAME","ORDER_ID","EQRY_REF_NO"]]
   
    Region_final_merg_1 = Region_final_merg_1.rename(columns={'ORDER_ID': 'Enquiry Count', 'EQRY_REF_NO': 'Booking Count'})
    Region_final_merg_1.fillna(0,inplace=True)
    Region_final_merg_1.sort_values("Enquiry Count", axis = 0, ascending = False, inplace = True, na_position ='last') 
    #Region_final = Region_final_merg[["DELR_RGON_NAME","ORDER_ID","EQRY_REF_NO"]]
    #Region_final.columns = ['Dealer Region Name','Enquiry Count','Booking Count']
    
    return Region_final_merg_1

# %%
Delr_region_SRO2 = regn(Ctb_data_region,regn_book,"South RO2")
Delr_region_SRO4 = regn(Ctb_data_region,regn_book,"South RO4")
Delr_region_CRO1 = regn(Ctb_data_region,regn_book,"Central RO1")
Delr_region_CRO2 = regn(Ctb_data_region,regn_book,"Central RO2")
Delr_region_WRO1 = regn(Ctb_data_region,regn_book,"West RO1")



Delr_region_ERO1 = regn(Ctb_data_region,regn_book,"East RO1")
Delr_region_ERO2 = regn(Ctb_data_region,regn_book,"East RO2")
Delr_region_ERO3 = regn(Ctb_data_region,regn_book,"East RO1")
Delr_region_WRO2 = regn(Ctb_data_region,regn_book,"West RO2")
Delr_region_WRO3 = regn(Ctb_data_region,regn_book,"West RO3")



Delr_region_SRO1 = regn(Ctb_data_region,regn_book,"South RO1")
Delr_region_SRO3 = regn(Ctb_data_region,regn_book,"South RO3")
Delr_region_CRO3 = regn(Ctb_data_region,regn_book,"Central RO3")
Delr_region_NRO1 = regn(Ctb_data_region,regn_book,"North RO1")
Delr_region_NRO2 = regn(Ctb_data_region,regn_book,"North RO2")

Delr_region_NRO3 = regn(Ctb_data_region,regn_book,"North RO3")
Delr_region_WRO4 = regn(Ctb_data_region,regn_book,"West RO4")

# %%
Delr_region_SRO4.to_excel("SRO4.xlsx")

# %%
Delr_region_CRO1.to_excel("CRO1.xlsx")

# %%
Delr_region_WRO1.to_excel("WRO1.xlsx")

# %%
Delr_region_CRO2.to_excel("CRO2.xlsx")

# %%
Delr_region_ERO1.to_excel("ERO1.xlsx")

# %%
Delr_region_ERO2.to_excel("ERO2.xlsx")

# %%
Delr_region_ERO3.to_excel("ERO3.xlsx")

# %%
Delr_region_WRO2.to_excel("WRO2.xlsx")

# %%
Delr_region_WRO4.to_excel("WRO4.xlsx")

# %%
Delr_region_WRO4.to_excel("WRO3.xlsx")

# %%
Delr_region_SRO1.to_excel("SRO1.xlsx")

# %%
Delr_region_SRO3.to_excel("SRO3.xlsx")

# %%
Delr_region_SRO4.to_excel("SRO4.xlsx")

# %%
Delr_region_NRO1.to_excel("NRO1.xlsx")

# %%
Delr_region_NRO2.to_excel("NRO2.xlsx")

# %%
Delr_region_NRO3.to_excel("NRO3.xlsx")

# %%
Delr_region_SRO2.to_excel("SRO2.xlsx")

# %%
Delr_region_CRO3.to_excel("CRO3.xlsx")

# %%
Region_booking.sort_values("EQRY_REF_NO", axis = 0, ascending = False, inplace = True, na_position ='last')

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

#Region_enq1.plot(kind='line',x='Dealer Region Name', y='Avg_Enquiry', color='red',linewidth=2,ax=ax)
splot = Region_booking.plot(kind='bar',x='DELR_RGON_NAME',y='EQRY_REF_NO', color="dodgerblue",legend=False,ax=ax)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)#
plt.xlabel("Regions", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=700, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(loc='upper center', bbox_to_anchor=(0.1, 1.01), ncol=2)

#plt.title("Region wise CTB Booking From Sep-20 to Apr-21", fontsize=12)
#plt.subplots_adjust(left=0.15)
#ax2 = ax.twinx()

#plt.grid(color='lightgrey', linewidth=0.7)
#ax.legend(["Total CTB Booking "],loc="upper center", bbox_to_anchor=(0.13, 1.0))
#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')
plt.savefig("#18.jpg", bbox_inches='tight') 
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#REGION COMPARISON - BOOKING.jpg", bbox_inches='tight') 
plt.show()

# %%
Region_enq1

# %%
#Region_enq1.sort_values(by="ORDER_ID", axis = 0, ascending = False, inplace = True, na_position ='last')

# %%
Region_enq1 = Region_enq1.reindex(index=order_by_index(Region_enq1.index, index_natsorted(Region_enq1.ORDER_ID)))

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

#Region_enq1.plot(kind='line',x='Dealer Region Name', y='Avg_Enquiry', color='red',linewidth=2,ax=ax)
splot = Region_enq1.plot(kind='bar',x='DELR_RGON_NAME',y='ORDER_ID', color="dodgerblue",legend=False,ax=ax)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Booking Count", fontsize=12)#
plt.xlabel("Regions", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=10000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
#ax.legend(loc='upper center', bbox_to_anchor=(0.1, 1.01), ncol=2)

#plt.title("Region wise CTB Enquiry From Sep-20 to Apr-21", fontsize=12)
#plt.subplots_adjust(left=0.15)
#ax2 = ax.twinx()

#plt.grid(color='lightgrey', linewidth=0.7)
#ax.legend(["Total CTB Enquiry "],loc="upper center", bbox_to_anchor=(0.13, 1.0))
#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')

plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("REGION COMPARISON ENQUIRY", bbox_inches='tight')  
plt.show()

# %%
CTB_GDMS.CUSTOMER_NAME

# %%
# sample gender code

# %%
CTB_GDMS['CSTM_NAME_first'] =CTB_GDMS['CSTM_NAME'].str.split().str[0]

CTB_GDMS['CSTM_NAME_sec'] =CTB_GDMS['CSTM_NAME'].str.split().str[1]

 

CTB_GDMS['len_first'] =CTB_GDMS['CSTM_NAME_first'].str.len()

CTB_GDMS['len_sec'] =CTB_GDMS['CSTM_NAME_sec'].str.len()

 

CTB_Reg['len_first'].value_counts()

CTB_Reg['len_sec'].value_counts()

CTB_Reg[CTB_Reg['len_first']==1]['len_sec'].value_counts()

 

CTB_Reg['actual_name'] = np.where(CTB_Reg['len_first']==1,CTB_Reg['CSTM_NAME_sec'],CTB_Reg['CSTM_NAME_first'])

CTB_Reg['actual_name_len'] = CTB_Reg['actual_name'].str.len()

CTB_Reg['actual_name_len'].value_counts()

# %%
CTB_Reg['actual_name_srm'] = CTB_Reg['actual_name'].str.replace('\W', '')
CTB_Reg['actual_name_srm_len'] = CTB_Reg['actual_name_srm'].str.len()
CTB_Reg['actual_name_srm_len'].value_counts()
CTB_Reg['name_lword'] = CTB_Reg['actual_name_srm'].str[-1:]
CTB_Reg['name_lword'] = CTB_Reg['name_lword'].str.lower()
CTB_Reg[['name_lword','actual_name_srm']].head()
CTB_Reg['Gender'] = np.where((CTB_Reg.name_lword=='a')|(CTB_Reg.name_lword=='e')|(CTB_Reg.name_lword=='i')|(CTB_Reg.name_lword=='o')|(CTB_Reg.name_lword=='u'),"Female","Male")
CTB_Reg['Gender'].value_counts()
CTB_Reg[CTB_Reg['Gender']=="Female"['name_lword'].value_counts()]

# %%
## Gender

# %%
def Trend_Analysis_pi1(dataset, Variables,CountVariable,DateVariable, GroupbyVariable, TrendType):
    
    Trend = dataset[Variables].pivot_table(index=GroupbyVariable, columns=CountVariable, aggfunc=len, fill_value=0)
    Trend.reset_index(inplace=True)
        
    if TrendType =="Monthly":
        #Trend['Month_name']= Trend[DateVariable].astype(int).apply(lambda x: calendar.month_abbr[x])
        pass
        
    if TrendType =="Weekly":    
        pass
    
    if TrendType =="Hourly":
        Hourly_Labels = ['22-24','0-2','0-2','2-4','2-4','4-6','4-6','6-8','6-8','8-10','8-10','10-12','10-12','12-14','12-14','14-16','14-16','16-18','16-18','18-20','18-20','20-22','20-22','22-24']
        interval_range = pd.interval_range(start=0, freq=2, end=24)
        Trend['Range'] = pd.cut(Trend[DateVariable], bins=interval_range)
        Trend['Range_name']= pd.DataFrame(Hourly_Labels)
        Trend_Hr_range = Trend[['ORDER_ID','Range_name']].groupby('Range_name',as_index=False).sum()
        Trend = Trend_Hr_range.copy()
        
        
    return Trend

# %%
CTB_GDMS['CSTM_NAME_first'] =CTB_GDMS['CUSTOMER_NAME'].str.split().str[0]
CTB_GDMS['CSTM_NAME_sec'] =CTB_GDMS['CUSTOMER_NAME'].str.split().str[1]
CTB_GDMS['len_first'] =CTB_GDMS['CSTM_NAME_first'].str.len()
CTB_GDMS['len_sec'] =CTB_GDMS['CSTM_NAME_sec'].str.len()

# %%
CTB_GDMS['len_first'].value_counts()

# %%
CTB_GDMS['len_sec'].value_counts()

# %%
CTB_GDMS[CTB_GDMS['len_first']==1]['len_sec'].value_counts()

# %%
CTB_GDMS['actual_name'] = np.where(CTB_GDMS['len_first']==1,CTB_GDMS['CSTM_NAME_sec'],CTB_GDMS['CSTM_NAME_first'])

CTB_GDMS['actual_name_len'] = CTB_GDMS['actual_name'].str.len()

CTB_GDMS['actual_name_len'].value_counts()

# %%
CTB_GDMS['actual_name_srm'] = CTB_GDMS['actual_name'].str.replace('\W', '')
CTB_GDMS['actual_name_srm_len'] = CTB_GDMS['actual_name_srm'].str.len()

CTB_GDMS['actual_name_srm_len'].value_counts()

# %%
CTB_GDMS['name_lword'] = CTB_GDMS['actual_name_srm'].str[-1:]
CTB_GDMS['name_lword'] = CTB_GDMS['name_lword'].str.lower()
CTB_GDMS[['name_lword','actual_name_srm']].head()

# %%
CTB_GDMS['Gender'] = np.where((CTB_GDMS.name_lword=='a')|(CTB_GDMS.name_lword=='e')|(CTB_GDMS.name_lword=='i')|(CTB_GDMS.name_lword=='o')|(CTB_GDMS.name_lword=='u'),"Female","Male")
CTB_GDMS['Gender'].value_counts()

# %%
58991+14972

# %%
CTB_GDMS[CTB_GDMS['Gender']=="Female"]['name_lword'].value_counts()

# %%
CTB_GDMS.Gender.value_counts()

# %%
CTB_GDMS.columns

# %%
Gender_enq = Trend_Analysis_gb(CTB_GDMS,['ORDER_ID','Gender'],'','Gender','Weekly')
print("total enquiry : ",Gender_enq.ORDER_ID.sum())
Gender_enq

# %%
# month wise enquiry

# %%
Gender_enq1 = Trend_Analysis_pi(CTB_GDMS,['ORDER_ID','Gender','ORDER_DATEWeekKey'],'Gender','Gender','Monthly')
print("total enquiry : ",Gender_enq1.ORDER_ID.sum())
Gender_enq1


#Monthly_trend_Booking = Trend_Analysis_pi(GDMS_Booking,['CTB_BOOKING_Y','BKNG_DATE_NEWMonthKey'],'CTB_BOOKING_Y','BKNG_DATE_NEWMonthKey','BKNG_DATE_NEWMonthKey','Monthly')
#Monthly_trend_Booking.columns = ['BKNG_DATE_NEWMonthKey', 'CTB_BOOKING_N', 'CTB_BOOKING_Y']

# %%
# enquiry overall 
Gender_enq = Trend_Analysis_gb(CTB_GDMS,['ORDER_ID','Gender'],'','Gender','Weekly')
print("total enquiry : ",Gender_enq.ORDER_ID.sum())
Gender_enq

# %%
## overall book

# %%
Gender_book = Trend_Analysis_gb(CTB_GDMS,['EQRY_REF_NO','Gender'],'','Gender','Weekly')
Gender_book

# %%
## month wise booking

# %%
Gender_book1 = Trend_Analysis_pi(CTB_GDMS,['EQRY_REF_NO','Gender','BKNG_DATE'],'Gender','Gender','BKNG_DATE','Monthly')
print("total enquiry : ",Gender_book1.EQRY_REF_NO.sum())
Gender_book1

# %%
Gender_book1 = Gender_book1.reindex(index=order_by_index(Gender_book1.index, index_natsorted(Gender_book1.BKNG_DATE)))

# %%
Gender_book1

Gender_book1['BKNG_DATE'] = Gender_book1['BKNG_DATE'].map(lambda x: str(x)[0:4]) + "-" +Gender_book1['BKNG_DATE'].map(lambda x: str(x)[4:6])+ "-" +Gender_book1['BKNG_DATE'].map(lambda x: str(x)[6:8])
Gender_book1['BKNG_DATE'].head(2)

# %%
Gender_book1

# %%
Gender_book1.to_excel("Gender Bookin.xlsx")

# %%
Gender_enq1.to_excel("Gender Enquiry.xlsx")

# %%
Gender_merg_final = Merge(Gender_enq1,'Gender',Gender_book1,'Gender','','','outer',True,'single')
#Region_final = Hourly_Trend_final[["Range_name","Enquiry Count","Booking Count"]]
Gender_merg_final

# %%
Gender_merg_final111 = Merge(Gender_enq,'Gender',Gender_book,'Gender','','','outer',True,'single')
#Region_final = Hourly_Trend_final[["Range_name","Enquiry Count","Booking Count"]]
Gender_merg_final111

# %%
Gender_final = Gender_merg_final[["Gender","ORDER_ID","EQRY_REF_NO"]]
Gender_final.columns = ['Gender','Enquiry Count','Booking Count']
#Region_enq = Gender_final["Enquiry Count"].sum()
#Region_book = Gender_final["Booking Count"].sum()
Gender_final["Enquiry Ratio"] = (Gender_final["Enquiry Count"]/Gender_final["Enquiry Count"].sum())
Gender_final["Booking Ratio"] = (Gender_final["Booking Count"]/Gender_final["Booking Count"].sum())
Gender_final["Enq to Booking Ratio"] = (Gender_final["Booking Count"]/Gender_final["Enquiry Count"])
#Region_final["Avg_Enquiry"]=Region_enq/Region_final["Dealer Region Name"].count()
#Region_final["Avg_booking"]=Region_book/Region_final["Dealer Region Name"].count()
Gender_final

# %%
Gender_final['Booking Count'].sum()

# %%
#CHART

# %%
from matplotlib.pyplot import figure
from matplotlib.ticker import PercentFormatter
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()
plt.xticks(rotation=45)

#plt.figure(figsize=(6, 3))
splot = sns.barplot(data=Gender_final, x = 'Gender', y = 'Enq to Booking Ratio', ci = None, color="dodgerblue")
for p in splot.patches:
        splot.annotate('{:.0f}%'.format(100*p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
plt.ylabel("Enquiry to booking %", fontsize=12)#
plt.xlabel("Gender", fontsize = 12)        
plt.ylim(ymax=0.15, ymin=0)
ax.yaxis.set_major_formatter(PercentFormatter(1))
plt.title("Gender wise Enquiry to booking Ratio")
plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("#GENDER E2B.jpg", bbox_inches='tight')

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 3), dpi=80, facecolor='w', edgecolor='k')
ax = plt.gca()

#Region_enq1.plot(kind='line',x='Dealer Region Name', y='Avg_Enquiry', color='red',linewidth=2,ax=ax)
splot = Gender_final.plot(kind='bar',x='Gender',y='Enquiry Count', color="dodgerblue",legend=False,ax=ax)
for p in splot.patches:
        splot.annotate('{:.0f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 
               'center', xytext = (0, 10), textcoords = 'offset points')
#df.plot(kind='line',x='Month',y='CTB BOOKING', legend=False, color='red', ax=ax)
plt.ylabel("Enquiry Count", fontsize=12)#
plt.xlabel("Gender", fontsize = 12)
plt.xticks(rotation=45)
plt.ylim(ymax=70000, ymin=0)
#plt.xticks(np.arange(59), df3['Week Number'][0:59], rotation=45)
ax.legend(loc='upper center', bbox_to_anchor=(0.1, 1.01), ncol=2)

plt.title("Gender wise CTB Enquiry From Sep-20 to Apr-21", fontsize=12)
#plt.subplots_adjust(left=0.15)
#ax2 = ax.twinx()

#plt.grid(color='lightgrey', linewidth=0.7)
ax.legend(["CTB Enquiry "],loc="upper center", bbox_to_anchor=(0.123, 1.0))
#ax2.spines['top'].set_edgecolor('grey')
for pos in (['top', 'bottom', 'right', 'left']):
    ax2.spines[pos].set_edgecolor('grey')

plt.grid(color='lightgrey', linewidth=0.7,axis='y')
plt.savefig("Gender Enquiry.jpg", bbox_inches='tight')
plt.show()

# %%
GDMS_Booking.EQRY_REF_NO.count()

# %%
df

# %%
dealer = pd.read_excel("Sales_dealer.xltm")

# %%
dealer

# %%
GDMS_Booking

# %%
ctb_book = pd.merge(GDMS_Booking,dealer,left_on='EQRY_DLR_NO',right_on='DEALER_CODE', how='outer', indicator=True)

# %%
ctb_book.EQRY_REF_NO.count()

# %%
ctb_book.to_excel("ctb_booking.xlsx")

# %%
df['CRM Retail'].sum()

# %%
6133 + 392

# %%
2536+179

# %%
2525+179

# %%
CTB_data.CUSTOMER_MOBILE.nunique()

# %%
73676 + 8192 + 610

# %%
## Conventional

# %%
May_info = pd.merge(CTB_data, GDMS_Booking_new, left_on=['ORDER_ID'],right_on = ['EQRY_REF_NO'], how = 'outer',indicator=True)
print(CTB_GDMS.shape)
CTB_GDMS['_merge'].value_counts()

# %%
sales_dealer = pd.read_excel("Sales_dealer.xltm")

# %%
May_info = pd.merge(GDMS_Booking_new,sales_dealer, left_on=['EQRY_DLR_NO'],right_on=['DEALER_CODE'], how = 'outer', indicator=True)
print(May_info.shape)
May_info['_merge'].value_counts()

# %%
May_info = May_info.loc[(May_info['_merge'] == 'both')]
print(May_info.shape)

# %%
May_info.to_excel("May_bookings.xlsx")

# %%
CTB_GDMS1 = pd.read_excel("CTB_GDMS_merge_may_31.xlsx")`

# %%
CTB_GDMS1['RETAIL_DATE'] = CTB_GDMS1['RETAIL_DATE'].map(lambda x: str(x)[0:4]) + "-" +CTB_GDMS1['RETAIL_DATE'].map(lambda x: str(x)[4:6])+ "-" +CTB_GDMS1['RETAIL_DATE'].map(lambda x: str(x)[6:8])
CTB_GDMS1['RETAIL_DATE'].head(2)

# %%
ctb

# %%
CTB_GDMS1.to_excel("CTB_GDMS_NEW.xlsx")

# %%
CTB_GDMS1['RETAIL_DATE_NEW'] = pd.to_datetime(CTB_GDMS1['RETAIL_DATE']) 
#used_car_rcrepm['vinm_selling_date'] = pd.to_datetime(used_car_rcrepm['vinm_selling_date'].astype(str), format='%Y%m%d')

# %%
CTB_GDMS1["RETAIL_DATE_NEW"] = np.where((CTB_GDMS1['vinm_sale_date'].notna()), CTB_GDMS1['vinm_sale_date'].map(lambda x: str(x)[0:4]) + "-" +CTB_GDMS1['vinm_sale_date'].map(lambda x: str(x)[4:6])+ "-" +CTB_GDMS1['vinm_sale_date'].map(lambda x: str(x)[6:8]),CTB_GDMS1['vinm_sale_date'])
CTB_GDMS1["vinm_sale_date_new"] = pd.to_datetime(CTB_GDMS1["vinm_sale_date_new"].astype(str), format = '%Y-%m-%d')

# %%
GDMS_retail_Age = GDMS_retail.copy()

# %%
GDMS_retail_Age.drop('_merge',axis=1,inplace=True)

# %%
age_retail = pd.merge(GDMS_retail_Age,AGE1,left_on="CUSTOMER_MOBILE",right_on="CELL_PH_NUM",how='outer',indicator=True)

# %%
age_retail.shape

# %%
age_retail['_merge'].value_counts()

# %%
age_retail = age_retail.loc[(age_retail['_merge'] == 'both')]
print(age_retail.shape)

# %%
age_retail.drop_duplicates(subset='CUSTOMER_MOBILE',inplace=True)
print(age_retail.shape)

# %%
age_retail.columns

# %%
age_retail = age_retail[(age_retail["AGE_INT"].astype(int)>18) & (age_retail["AGE_INT"].astype(int)<100)]
age_retail.shape

# %%
age_retail.to_excel("AGE_retail_till_may.xlsx")

# %%
GDMS_Booking_age = CTB_GDMS.copy()

# %%
GDMS_Booking_age.columns

# %%
GDMS_Booking_age.drop('_merge',axis=1,inplace=True)

# %%
age_booking = pd.merge(GDMS_Booking_age,AGE1,left_on="CUSTOMER_MOBILE",right_on="CELL_PH_NUM",how='outer',indicator=True)
age_booking['_merge'].value_counts()

# %%
age_booking = age_booking.loc[(age_booking['_merge'] == 'both')]
print(age_booking.shape)

# %%
age_booking.drop_duplicates(subset='CUSTOMER_MOBILE',inplace=True)
print(age_booking.shape)

# %%
age_booking = age_booking[(age_booking["AGE_INT"].astype(int)>18) & (age_booking["AGE_INT"].astype(int)<100)]
age_booking.shape

# %%
age_booking.to_excel("age_booking.xlsx")
